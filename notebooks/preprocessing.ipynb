# %% [markdown]
# # Table of Contents <a class = "anchor" id = "toc"></a>
# * [Data Importation](#data_impo)
# * [Data Preprocessing](#preprocessing)
# * [Data Cleaning](#data_clean)
# * [Feature Engineering](#featureeng)
# * [Classification Models](#models)
# * [Evaluation](#evaluation)

# %% [markdown]
# # Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('punkt')
nltk.download('opinion_lexicon')
nltk.download('wordnet')
nltk.download('stopwords')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import spacy

from tqdm import tqdm
from gensim.models import Word2Vec

from sklearn.metrics import roc_curve, roc_auc_score, f1_score, classification_report, auc
from sklearn.model_selection import cross_val_predict, StratifiedKFold, train_test_split, GridSearchCV, KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader, TensorDataset, RandomSampler, SequentialSampler
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, LSTM, Embedding, Dropout
from keras.models import Model

from sentence_transformers import SentenceTransformer
from langdetect import detect
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import emoji
import langid
import regex
import string

import re
from tqdm import tqdm
import regex
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/catarinasilva/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/catarinasilva/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/catarinasilva/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/catarinasilva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Data Importation <a class = "anchor" id = "data_impo"></a>
# [Back to the Table of Contents](#toc)

# %%
# %%time
airbnb_train = pd.read_excel('../data/Project Corpora/train.xlsx')
airbnb_train_reviews = pd.read_excel('../data/Project Corpora/train_reviews.xlsx')
airbnb_test = pd.read_excel('../data/Project Corpora/test.xlsx')
airbnb_test_reviews = pd.read_excel('../data/Project Corpora/test_reviews.xlsx')
# Out:
# CPU times: user 8.28 s, sys: 5.27 s, total: 13.6 s
# Wall time: 20.5 s

# %%
airbnb_train.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 airbnb_train.head(2)
#
# NameError: name 'airbnb_train' is not defined

# %%
airbnb_train_reviews.head(5)
# Out:
#    index                                           comments
# 0      1  this is a very cozy and comfortable house to s...
# 1      1                                          good<br/>
# 2      1  My first hostel experience, and all I have to ...
# 3      1  Das Hostel war neu und deshalb funktionierte a...
# 4      1  It was fine for a dorm, but I think for the pe...

# %%
airbnb_test.head(2)
# Out:
#    index                                        description  \
# 0      1  <b>The space</b><br />Apartment located in the...
# 1      2  IMPORTANT: In response to COVID-19, this prope...
# 2      3  Bright, beautiful, and spacious. This four-bed...
# 3      4  Charming Apartment Close to the Bay of Cascais...
# 4      5  Se procura umas férias perto da praia, casino ...
#
#                                           host_about
# 0  Gosto de viajar, de conhecer pessoas, gosto de...
# 1  We are the be@home Team!\n\nYou can count on u...
# 2  Hi there!\n\nWe're GuestReady, a professional ...
# 3                                                 :)
# 4  Bem vindos a Portugal!_x000D_\nAdoro o meu Paí...

# %%
airbnb_test_reviews.head(2)
# Out:
#    index                                           comments
# 0      1  Thank you very much Antonio ! All has been per...
# 1      1  Very nice appartment in the old town of Lissab...
# 2      1  When travelling we're looking for kids friendl...
# 3      1  We've been in Lisbon in march 2013 (3 adults a...
# 4      1  Our host Antonio was very helpful with informa...

# %% [markdown]
# * The results above show that we have comments in languages other than English (e.g., Portuguese, French, and German). We can install paid (e.g., Google and Microsoft) and free (e.g., LibreTranslate) APIs to translate those comments into English. However, I don't know if we can use them.

# %%
print(f"The data frame airbnb_train has : {len(airbnb_train)} rows")
print(f"The data frame airbnb_train_reviews has : {len(airbnb_train_reviews)} rows")
print()
print(f"The data frame airbnb_test has : {len(airbnb_test)} rows")
print(f"The data frame airbnb_test_reviews has : {len(airbnb_test_reviews)} rows")
# Out:
# The data frame airbnb_train has : 6248 rows
# The data frame airbnb_train_reviews has : 361281 rows
#
# The data frame airbnb_test has : 695 rows
# The data frame airbnb_test_reviews has : 41866 rows

# %% [markdown]
# # Data Preprocessing <a class = "anchor" id = "preprocessing"></a>
# [Back to the Table of Contents](#toc)

# %% [markdown]
# ### Lowercasing

# %%
def lowercasing(text_list):
    updates = []
    
    for text in tqdm(text_list):
        # Lowercase text
        text = text.lower()
        
        # Remove unnecessary tags
        text = re.sub(r"<[^>]+>", " ", text)
        
        
        # Remove all non-alphabetic characters (including underscores and digits)
        text = regex.sub(r"[^\p{L}\s]", " ", text)  # \s is for space to preserve spacing between words
        # Remove 'x' and 'd' when they appear alone
        text = re.sub(r"(^|\s)(x|d)(\s|$)", " ", text)
        text = regex.sub(r"\s+", " ", text)  # Replace multiple spaces with a single space
        
        updates.append(text.strip())  # Strip leading/trailing spaces
    
    return updates

# %% [markdown]
# ### Train

# %% [markdown]
# #### Comments

# %%
lowercased_train_reviews = lowercasing(airbnb_train_reviews['comments'])
# Out:
# 100%|████████████████████████████████| 361279/361279 [00:09<00:00, 39709.44it/s]

# %%
airbnb_train_reviews['comments'][17]
# Out:
# 'Everything is correct, like the photos said. But it is important to know that the kitchen is close from 22 a.p. till 8 a.m.<br/>Regards.'

# %%
lowercased_train_reviews[17]
# Out:
# 'everything is correct like the photos said but it is important to know that the kitchen is close from a p till a m regards'

# %% [markdown]
# #### Property details

# %%
lowercased_train_description = lowercasing(airbnb_train['description'])
# Out:
# 100%|████████████████████████████████████| 6248/6248 [00:00<00:00, 14828.00it/s]

# %%
lowercased_train_host = lowercasing(airbnb_train['host_about'])
# Out:
# 100%|████████████████████████████████████| 6248/6248 [00:00<00:00, 24432.60it/s]

# %%
airbnb_train['description'][1]
# Out:
# 'O meu espaço fica perto de Parque Eduardo VII, Saldanha, estefanea, IST, Nova university ,. O meu espaço é bom para aventuras individuais.'

# %%
lowercased_train_description[1]
# Out:
# 'o meu espaço fica perto de parque eduardo vii saldanha estefanea ist nova university o meu espaço é bom para aventuras individuais'

# %%
airbnb_train['host_about'][17]
# Out:
# 'Cool&Easy.\nGoing to the beach minded'

# %%
lowercased_train_host[17]
# Out:
# 'cool easy going to the beach minded'

# %% [markdown]
# ### Test

# %% [markdown]
# #### Comments

# %%
lowercased_test_reviews = lowercasing(airbnb_test_reviews['comments'])
# Out:
# 100%|██████████████████████████████████| 41866/41866 [00:01<00:00, 35867.39it/s]

# %%
airbnb_test_reviews['comments'][12]
# Out:
# "The flat is a lovely space with everything you need and some lovely old character features. Its centrally located but still far enough away from the hubbub of the barrio. They were kind enough to let us shelter there for a few hours until our flight left. _x000D_<br/>Book this one it's perfect shame the weather was so awful. "

# %%
lowercased_test_reviews[12]
# Out:
# 'the flat is a lovely space with everything you need and some lovely old character features its centrally located but still far enough away from the hubbub of the barrio they were kind enough to let us shelter there for a few hours until our flight left book this one it s perfect shame the weather was so awful'

# %% [markdown]
# #### Property details

# %%
lowercased_test_description = lowercasing(airbnb_test['description'])
# Out:
# 100%|██████████████████████████████████████| 695/695 [00:00<00:00, 11657.55it/s]

# %%
lowercased_test_host = lowercasing(airbnb_test['host_about'])
# Out:
# 100%|██████████████████████████████████████| 695/695 [00:00<00:00, 20029.97it/s]

# %%
airbnb_test['description'][4]
# Out:
# 'Se procura umas férias perto da praia, casino e  outras atracções turísticas, escolha esta agradável casa, com um pitoresco pátio, onde poderá ler um livro, descansar, ou ainda encomendar uma deliciosa prova gastronómica ao anfitrião. Experimente<br /><br /><b>License number</b><br />86364/AL'

# %%
lowercased_test_description[4]
# Out:
# 'se procura umas férias perto da praia casino e outras atracções turísticas escolha esta agradável casa com um pitoresco pátio onde poderá ler um livro descansar ou ainda encomendar uma deliciosa prova gastronómica ao anfitrião experimente license number al'

# %%
airbnb_test['host_about'][3]
# Out:
# ':)'

# %%
lowercased_test_host[3]
# Out:
# ''

# %% [markdown]
# ## Detect review's languages

# %%
def detect_language(text):
    try:
        # Primary language detection with langdetect
        prim_language = detect(text)
        # Secondary language detection with langid
        sec_language, confidence = langid.classify(text)
        if confidence > 0.85:  # Threshold to determine which language to choose
            return sec_language
        return prim_language
    except Exception as e:
        return 'unknown'

# %% [markdown]
# ### Train

# %% [markdown]
# #### Comments

# %% [raw]
# lowercased_train_reviews = pd.DataFrame(lowercased_train_reviews, columns=['comments'])
#
# # Apply the detect_language function to the 'comments' column
# %time lowercased_train_reviews['language'] = lowercased_train_reviews['comments'].apply(detect_language)
#
# train_reviews = lowercased_train_reviews.copy()
# train_reviews['language'] = lowercased_train_reviews['language']
#
# # Get the language counts
# language_counts = train_reviews['language'].value_counts()
#
# # Print the language counts
# print(language_counts)

# %% [raw]
# CPU times: user 2h 22min 6s, sys: 44min 10s, total: 3h 6min 16s
# Wall time: 27min 7s
# language
# en         233052
# fr          53363
# pt          22493
# es          19293
# de          14106
# it           5988
# nl           3610
# ko           1672
# ru           1509
# unknown       943
# zh-cn         909
# pl            571
# da            481
# ca            398
# ro            388
# sv            385
# no            341
# cs            294
# af            250
# fi            191
# hu            125
# ja            108
# he             91
# cy             77
# lt             67
# so             67
# tr             56
# hr             54
# sl             52
# sk             49
# el             49
# uk             44
# tl             38
# id             33
# lv             31
# et             30
# sw             24
# zh-tw          14
# bg             11
# ar              9
# sq              5
# vi              5
# mk              1
# ur              1
# zh              1
# Name: count, dtype: int64

# %%
train_reviews = pd.read_csv('../data/reviews_language/airbnb_train_reviews_languages.csv')
train_reviews.drop('Unnamed: 0',axis=1, inplace=True)

# %%
train_reviews.head()
# Out:
#                                             comments language
# 0  this is a very cozy and comfortable house to s...       en
# 1                                               good       en
# 2  my first hostel experience and all i have to s...       en
# 3  das hostel war neu und deshalb funktionierte a...       de
# 4  it was fine for a dorm but i think for the peo...       en

# %%
train_reviews[train_reviews['language'] == 'en']
# Out:
#                                                  comments language
# 0       this is a very cozy and comfortable house to s...       en
# 1                                                    good       en
# 2       my first hostel experience and all i have to s...       en
# 4       it was fine for a dorm but i think for the peo...       en
# 5       our stay in lisbon tip hostel was very good th...       en
# ...                                                   ...      ...
# 360326  ana s place is just what you need for a quick ...       en
# 360330  definetly good location apartment was cozy and...       en
# 360331  the location was perfect the apartment was ver...       en
# 360332  ana s place is exactly as described and even b...       en
# 360334  no wifi nor answer the wifi can t be connected...       en
#
# [233052 rows x 2 columns]

# %%
unknown_train_reviews = train_reviews[train_reviews['language'] == 'unknown']

# %%
unknown_train_reviews['comments'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
train_reviews.drop(unknown_train_reviews.index, inplace= True)
train_reviews['language'].value_counts()
# Out:
# language
# en       233052
# fr        53363
# pt        22493
# es        19293
# de        14106
# it         5988
# nl         3610
# ko         1672
# ru         1509
# zh-cn       909
# pl          571
# da          481
# ca          398
# ro          388
# sv          385
# no          341
# cs          294
# af          250
# fi          191
# hu          125
# ja          108
# he           91
# cy           77
# so           67
# lt           67
# tr           56
# hr           54
# sl           52
# sk           49
# el           49
# uk           44
# tl           38
# id           33
# lv           31
# et           30
# sw           24
# zh-tw        14
# bg           11
# ar            9
# sq            5
# vi            5
# mk            1
# ur            1
# zh            1
# Name: count, dtype: int64

# %% [raw]
# train_reviews.to_csv('airbnb_train_reviews_languages.csv')

# %% [markdown]
# #### Property details

# %% [raw]
# lowercased_train_description = pd.DataFrame(lowercased_train_description, columns=['description'])
# lowercased_train_host = pd.DataFrame(lowercased_train_host, columns=['host_about'])
#
# # Apply the detect_language function to the 'comments' column
# %time lowercased_train_description['description_language'] = lowercased_train_description['description'].apply(detect_language)
# %time lowercased_train_host['host_language'] = lowercased_train_host['host_about'].apply(detect_language)
#
#
# # Get the language counts
# language_counts_description = lowercased_train_description['description_language'].value_counts()
# language_counts_host = lowercased_train_host['host_language'].value_counts()
# # Print the language counts
# print(language_counts_description, end = '\n\n')
# print(language_counts_host)

# %% [raw]
# CPU times: user 3min 7s, sys: 56.2 s, total: 4min 3s
# Wall time: 33.2 s
# CPU times: user 2min 55s, sys: 1min, total: 3min 56s
# Wall time: 32.9 s
# description_language
# en       5086
# pt        910
# fr         84
# ro         81
# de         45
# es         29
# zh-cn       4
# nl          3
# it          2
# ca          2
# no          1
# sv          1
# Name: count, dtype: int64
#
# host_language
# en         4467
# pt         1260
# fr          137
# es           92
# unknown      79
# it           69
# de           36
# ca           23
# zh-cn        15
# no           13
# ko           13
# af            7
# et            6
# nl            5
# ro            5
# cy            3
# zh-tw         3
# sl            3
# so            2
# sv            2
# da            1
# fi            1
# lt            1
# sw            1
# he            1
# tr            1
# hr            1
# ru            1
# Name: count, dtype: int64

# %%
lowercased_train_host = pd.read_csv('../data/train_property(lower + language)/lowercased_train_host.csv')
lowercased_train_host.drop('Unnamed: 0',axis=1, inplace=True)

# %%
lowercased_train_description = pd.read_csv('../data/train_property(lower + language)/lowercased_train_description.csv')
lowercased_train_description.drop('Unnamed: 0',axis=1, inplace=True)

# %%
train_property = pd.read_csv('../data/train_property.csv')
train_property.drop('Unnamed: 0',axis=1, inplace=True)

# %%
train_property = lowercased_train_description.join(lowercased_train_host)

# %%
train_property['index']= airbnb_train['index']
train_property.head()
# Out:
#                                          description description_language  \
# 0  this is a shared mixed room in our hostel with...                   en
# 1  o meu espaço fica perto de parque eduardo vii ...                   pt
# 2  trafaria s house is a cozy and familiar villa ...                   en
# 3  apartamento charmoso no chiado entre o largo d...                   pt
# 4  joli appartement en bordure de mer min a pied ...                   fr
#
#                                           host_about host_language  index
# 0                       alojamento local registro al            es      1
# 1  i am friendly host and i will try to always be...            en      2
# 2  i am a social person liking to communicate rea...            en      3
# 3  hello i m portuguese and i love to meet people...            en      4
# 4  nous sommes une famille avec deux enfants de e...            fr      5

# %%
train_property[train_property['host_language'] == 'unknown']
# Out:
#                                             description description_language  \
# 18    the lovely casa do sobral is located in the li...                   en
# 85    apartment has bedrooms a living room a fitted ...                   en
# 92    other things to note for your information we a...                   en
# 110   quarto individual acolhedor com mesa de trabal...                   pt
# 185   bica apartments is located in one of the most ...                   en
# ...                                                 ...                  ...
# 5553  duplex in the heart of old lisbon in alfama on...                   en
# 5792  apartment with m consisting of bedrooms living...                   en
# 5942  a águamel é uma casa de finais do séc xix que ...                   pt
# 5955  brand new studio right in the heart of lisbon ...                   en
# 5985  innloco lisbon guesthouse minutes walk from th...                   en
#
#      host_about host_language  index
# 18          NaN       unknown     19
# 85          NaN       unknown     86
# 92          NaN       unknown     93
# 110         NaN       unknown    111
# 185         NaN       unknown    186
# ...         ...           ...    ...
# 5553        NaN       unknown   5554
# 5792        NaN       unknown   5793
# 5942        NaN       unknown   5943
# 5955        NaN       unknown   5956
# 5985        NaN       unknown   5986
#
# [79 rows x 5 columns]

# %%
train_property.loc[(train_property['host_language'] == 'unknown') & (train_property['host_about'].str.strip() == ''),\
'host_about'] = "no description provided"

# %%
train_property[train_property['host_language'] == 'unknown']
# Out:
#                                             description description_language  \
# 18    the lovely casa do sobral is located in the li...                   en
# 85    apartment has bedrooms a living room a fitted ...                   en
# 92    other things to note for your information we a...                   en
# 110   quarto individual acolhedor com mesa de trabal...                   pt
# 185   bica apartments is located in one of the most ...                   en
# ...                                                 ...                  ...
# 5553  duplex in the heart of old lisbon in alfama on...                   en
# 5792  apartment with m consisting of bedrooms living...                   en
# 5942  a águamel é uma casa de finais do séc xix que ...                   pt
# 5955  brand new studio right in the heart of lisbon ...                   en
# 5985  innloco lisbon guesthouse minutes walk from th...                   en
#
#      host_about host_language  index
# 18          NaN       unknown     19
# 85          NaN       unknown     86
# 92          NaN       unknown     93
# 110         NaN       unknown    111
# 185         NaN       unknown    186
# ...         ...           ...    ...
# 5553        NaN       unknown   5554
# 5792        NaN       unknown   5793
# 5942        NaN       unknown   5943
# 5955        NaN       unknown   5956
# 5985        NaN       unknown   5986
#
# [79 rows x 5 columns]

# %% [markdown]
# #### saving  the results

# %% [raw]
# train_property.to_csv('train_property.csv')

# %% [raw]
# lowercased_train_description.to_csv('lowercased_train_description.csv')

# %% [raw]
# lowercased_train_host.to_csv('lowercased_train_host.csv')

# %% [markdown]
# ### Test

# %% [markdown]
# #### Comments

# %% [raw]
# lowercased_test_reviews = pd.DataFrame(lowercased_test_reviews, columns=['comments'])
#
# # Apply the detect_language function to the 'comments' column
# %time lowercased_test_reviews['language'] = lowercased_test_reviews['comments'].apply(detect_language)
#
# test_reviews = lowercased_test_reviews.copy()
# test_reviews['language'] = lowercased_test_reviews['language']
#
# # Get the language counts
# language_counts = test_reviews['language'].value_counts()
#
# # Print the language counts
# print(language_counts)

# %% [raw]
# CPU times: user 16min 4s, sys: 4min 45s, total: 20min 50s
# Wall time: 2min 49s
# language
# en         27639
# fr          5952
# pt          2179
# es          2176
# de          1732
# it           662
# nl           431
# ko           221
# ru           151
# unknown      128
# zh-cn        100
# pl            55
# da            48
# ca            45
# no            44
# sv            42
# ro            37
# cs            32
# af            25
# fi            25
# hu            22
# ja            19
# he            13
# el             9
# tr             9
# so             8
# cy             8
# lt             7
# id             5
# hr             5
# sl             5
# et             5
# sq             4
# lv             4
# zh-tw          3
# sw             3
# bg             3
# ar             2
# tl             2
# sk             2
# uk             2
# mk             1
# vi             1
# Name: count, dtype: int64

# %%
test_reviews = pd.read_csv('../data/reviews_language/airbnb_test_reviews_languages.csv')
test_reviews.drop('Unnamed: 0',axis=1, inplace=True)

# %%
test_reviews.head()
# Out:
#                                             comments language
# 0  thank you very much antonio all has been perfe...       en
# 1  very nice appartment in the old town of lissab...       en
# 2  when travelling we re looking for kids friendl...       en
# 3  we ve been in lisbon in march adults and child...       en
# 4  our host antonio was very helpful with informa...       en

# %%
unknown_test_reviews = test_reviews[test_reviews['language'] == 'unknown']

# %%
unknown_test_reviews['comments'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
unknown_test_reviews
# Out:
#       comments language
# 1077       NaN  unknown
# 1174       NaN  unknown
# 1890       NaN  unknown
# 2166       NaN  unknown
# 2717       NaN  unknown
# ...        ...      ...
# 40526      NaN  unknown
# 41047      NaN  unknown
# 41128      NaN  unknown
# 41648      NaN  unknown
# 41654      NaN  unknown
#
# [128 rows x 2 columns]

# %% [raw]
# test_reviews.drop(unknown_test_reviews.index, inplace= True)
# test_reviews['language'].value_counts()

# %% [markdown]
# #### saving the results

# %% [raw]
# test_reviews.to_csv('airbnb_test_reviews_languages.csv')

# %% [markdown]
# #### Property details

# %% [raw]
# lowercased_test_description = pd.DataFrame(lowercased_test_description, columns=['description'])
# lowercased_test_host = pd.DataFrame(lowercased_test_host, columns=['host_about'])
#
# # Apply the detect_language function to the 'comments' column
# %time lowercased_test_description['description_language'] = lowercased_test_description['description'].apply(detect_language)
# %time lowercased_test_host['host_language'] = lowercased_test_host['host_about'].apply(detect_language)
#
#
# # Get the language counts
# language_counts_description = lowercased_test_description['description_language'].value_counts()
# language_counts_host = lowercased_test_host['host_language'].value_counts()
# # Print the language counts
# print(language_counts_description, end = '\n\n')
# print(language_counts_host)

# %% [raw]
# CPU times: user 22.1 s, sys: 5.78 s, total: 27.9 s
# Wall time: 3.88 s
# CPU times: user 19 s, sys: 5.82 s, total: 24.8 s
# Wall time: 3.31 s
# description_language
# en    577
# pt     94
# ro     11
# fr      6
# de      2
# es      2
# nl      1
# it      1
# ca      1
# Name: count, dtype: int64
#
# host_language
# en         505
# pt         133
# fr          18
# unknown     10
# es           8
# it           7
# de           5
# ca           2
# nl           2
# et           1
# no           1
# ru           1
# he           1
# zh-cn        1
# Name: count, dtype: int64

# %%
lowercased_test_description = pd.read_csv('../data/test_property(lower + language) /lowercased_test_description.csv')
lowercased_test_description.drop('Unnamed: 0',axis=1, inplace=True)

# %%
lowercased_test_host = pd.read_csv('../data/test_property(lower + language) /lowercased_test_host.csv')
lowercased_test_host.drop('Unnamed: 0',axis=1, inplace=True)

# %%
test_property = pd.read_csv('../data/test_property.csv')
test_property.drop('Unnamed: 0',axis=1, inplace=True)

# %%
test_property = lowercased_test_description.join(lowercased_test_host)

# %%
test_property['index']= airbnb_test['index']
test_property.head()
# Out:
#                                          description description_language  \
# 0  the space apartment located in the historic ce...                   en
# 1  important in response to covid this property h...                   en
# 2  bright beautiful and spacious this four bedroo...                   en
# 3  charming apartment close to the bay of cascais...                   en
# 4  se procura umas férias perto da praia casino e...                   pt
#
#                                           host_about host_language  index
# 0  gosto de viajar de conhecer pessoas gosto de r...            pt      1
# 1  we are the be home team you can count on us to...            en      2
# 2  hi there we re guestready a professional prope...            en      3
# 3                                                NaN       unknown      4
# 4  bem vindos a portugal adoro o meu país mas tam...            pt      5

# %%
test_property[test_property['host_language'] == 'unknown']
# Out:
#                                            description description_language  \
# 3    charming apartment close to the bay of cascais...                   en
# 32   temos a descrição do anúncio em vários idiomas...                   pt
# 102  this is the most adorable and sweet apartment ...                   en
# 106  studio in the heart of old lisbon in alfama on...                   en
# 351  temos a descrição do anúncio em português engl...                   pt
# 364  the space águamel sintra is a family run bouti...                   en
# 527  charming apartment in the historical village o...                   en
# 559  em piso térreo todo mobilado cozinha rústica c...                   pt
# 605  o meu espaço fica perto de hotel cr chiado ros...                   pt
# 627  sailing and sleeping on board is one of the ex...                   en
#
#     host_about host_language  index
# 3          NaN       unknown      4
# 32         NaN       unknown     33
# 102        NaN       unknown    103
# 106        NaN       unknown    107
# 351        NaN       unknown    352
# 364        NaN       unknown    365
# 527        NaN       unknown    528
# 559        NaN       unknown    560
# 605        NaN       unknown    606
# 627        NaN       unknown    628

# %%
test_property.loc[(test_property['host_language'] == 'unknown') & (test_property['host_about'].str.strip() == ''),\
'host_about'] = "no description provided"

# %%
test_property[test_property['host_language'] == 'unknown']
# Out:
#                                            description description_language  \
# 3    charming apartment close to the bay of cascais...                   en
# 32   temos a descrição do anúncio em vários idiomas...                   pt
# 102  this is the most adorable and sweet apartment ...                   en
# 106  studio in the heart of old lisbon in alfama on...                   en
# 351  temos a descrição do anúncio em português engl...                   pt
# 364  the space águamel sintra is a family run bouti...                   en
# 527  charming apartment in the historical village o...                   en
# 559  em piso térreo todo mobilado cozinha rústica c...                   pt
# 605  o meu espaço fica perto de hotel cr chiado ros...                   pt
# 627  sailing and sleeping on board is one of the ex...                   en
#
#     host_about host_language  index
# 3          NaN       unknown      4
# 32         NaN       unknown     33
# 102        NaN       unknown    103
# 106        NaN       unknown    107
# 351        NaN       unknown    352
# 364        NaN       unknown    365
# 527        NaN       unknown    528
# 559        NaN       unknown    560
# 605        NaN       unknown    606
# 627        NaN       unknown    628

# %% [markdown]
# #### saving the results

# %% [raw]
# test_property.to_csv('test_property.csv')

# %% [raw]
# lowercased_test_description.to_csv('lowercased_test_description.csv')

# %% [raw]
# lowercased_test_host.to_csv('lowercased_test_host.csv')

# %% [markdown]
# ## Checking if we have NaNs

# %%
print(train_reviews.isna().sum(), end = '\n\n')
print(lowercased_train_description.isna().sum(), end = '\n\n')
print(lowercased_train_host.isna().sum(), end = '\n\n')
print(test_reviews.isna().sum(), end = '\n\n')
print(lowercased_test_description.isna().sum(), end = '\n\n')
print(lowercased_test_host.isna().sum())
# Out:
# comments    1
# language    0
# dtype: int64
#
# description             0
# description_language    0
# dtype: int64
#
# host_about       79
# host_language     0
# dtype: int64
#
# comments    128
# language      0
# dtype: int64
#
# description             0
# description_language    0
# dtype: int64
#
# host_about       10
# host_language     0
# dtype: int64

# %%
train_reviews[train_reviews.isna().any(axis=1)]
# Out:
#        comments language
# 358704      NaN       en

# %%
train_reviews.dropna(inplace=True)

# %%
lowercased_train_host[lowercased_train_host.isna().any(axis=1)]
# Out:
#      host_about host_language
# 18          NaN       unknown
# 85          NaN       unknown
# 92          NaN       unknown
# 110         NaN       unknown
# 185         NaN       unknown
# ...         ...           ...
# 5553        NaN       unknown
# 5792        NaN       unknown
# 5942        NaN       unknown
# 5955        NaN       unknown
# 5985        NaN       unknown
#
# [79 rows x 2 columns]

# %%
lowercased_train_host.fillna('empty', inplace=True)

# %%
lowercased_test_host.fillna('empty', inplace=True)

# %%
print(train_reviews.isna().sum(), end = '\n\n')
print(lowercased_train_description.isna().sum(), end = '\n\n')
print(lowercased_train_host.isna().sum(), end = '\n\n')
print(test_reviews.isna().sum(), end = '\n\n')
print(lowercased_test_description.isna().sum(), end = '\n\n')
print(lowercased_test_host.isna().sum())
# Out:
# comments    0
# language    0
# dtype: int64
#
# description             0
# description_language    0
# dtype: int64
#
# host_about       0
# host_language    0
# dtype: int64
#
# comments    128
# language      0
# dtype: int64
#
# description             0
# description_language    0
# dtype: int64
#
# host_about       0
# host_language    0
# dtype: int64

# %% [markdown]
# # Data Cleaning <a class = "anchor" id = "data_clean"></a>
# [Back to the Table of Contents](#toc)

# %%
# stopwords for various languages
stopwords_dict = {
    'en': set(stopwords.words('english')),
    'fr': set(stopwords.words('french')),
    'pt': set(stopwords.words('portuguese')),
    'es': set(stopwords.words('spanish')),
    'de': set(stopwords.words('german')),
    'it': set(stopwords.words('italian')),
    'nl': set(stopwords.words('dutch')),
    'ru': set(stopwords.words('russian'))
}

# Load lemmatizers for different languages
nlp_fr = spacy.load("fr_core_news_sm")  # French
nlp_es = spacy.load("es_core_news_sm")  # Spanish
nlp_de = spacy.load("de_core_news_sm")  # German
nlp_it = spacy.load("it_core_news_sm")  # Italian
nlp_nl = spacy.load("nl_core_news_sm")  # Dutch
nlp_pt = spacy.load("pt_core_news_sm")  # Portuguese
nlp_ru = spacy.load("ru_core_news_sm")  # Russian

lemmatizers_dict = {
    'en': WordNetLemmatizer(),  # English uses WordNetLemmatizer from NLTK
    'fr': nlp_fr,
    'es': nlp_es,
    'de': nlp_de,
    'it': nlp_it,
    'nl': nlp_nl,
    'pt': nlp_pt,
    'ru': nlp_ru
}

# %%
def clean_text(text, language, stopwords_dict, lemmatizers_dict):
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Retrieve the appropriate stopwords and lemmatizer for the language
    stopwords_set = stopwords_dict.get(language, set())
    lemmatizer = lemmatizers_dict.get(language, None)

    # Remove stopwords
    if stopwords_set:
        tokens = [word for word in tokens if word.lower() not in stopwords_set]

    # Lemmatize
    if lemmatizer:
        if isinstance(lemmatizer, WordNetLemmatizer):
            tokens = [lemmatizer.lemmatize(word) for word in tokens]
        else:
            doc = lemmatizer(" ".join(tokens))
            tokens = [token.lemma_ for token in doc]

    # Join tokens back to string
    text = " ".join(tokens)
    return text

def clean_column(df, column_name, language_column, cleaned_column_name, stopwords_dict, lemmatizers_dict):
    tqdm.pandas()
    # Employ the previous function to the specific column
    df[cleaned_column_name] = df.progress_apply(lambda row: clean_text(row[column_name], row[language_column], stopwords_dict, lemmatizers_dict), 
                                                axis = 1)
    return df

# %% [markdown]
# #### Comments

# %% [raw]
# train_reviews = clean_column(train_reviews, 'comments', 'language', 'cleaned_comments', stopwords_dict, lemmatizers_dict)
# train_reviews

# %% [raw]
# test_reviews = clean_column(test_reviews, 'comments', 'language', 'cleaned_comments', stopwords_dict, lemmatizers_dict)
# test_reviews

# %% [markdown]
# #### saving the results

# %% [raw]
# train_reviews.to_csv('airbnb_train_reviews_cleaned.csv')
# test_reviews.to_csv('airbnb_test_reviews_cleaned.csv')

# %% [markdown]
# #### Property details - description

# %% [raw]
# train_description = clean_column(lowercased_train_description, 'description', 'description_language', 'cleaned_description',
#                                  stopwords_dict, lemmatizers_dict)
# train_description

# %% [raw]
# test_description = clean_column(lowercased_test_description, 'description', 'description_language', 'cleaned_description',
#                                  stopwords_dict, lemmatizers_dict)
# test_description

# %% [markdown]
# #### saving the results

# %% [raw]
# train_description.to_csv('train_description_cleaned.csv')
# test_description.to_csv('test_description_cleaned.csv')

# %% [markdown]
# #### Property details - host

# %% [raw]
# train_host = clean_column(lowercased_train_host, 'host_about', 'host_language', 'cleaned_host', stopwords_dict, lemmatizers_dict)
# train_host

# %% [raw]
# test_host = clean_column(lowercased_test_host, 'host_about', 'host_language', 'cleaned_host', stopwords_dict, lemmatizers_dict)
# test_host

# %% [markdown]
# #### saving the results

# %% [raw]
# train_host.to_csv('train_host_cleaned.csv')
# test_host.to_csv('test_host_cleaned.csv')

# %% [markdown]
# #### Importing the cleaned data

# %%
train_reviews = pd.read_csv('../data/cleaned_data/airbnb_train_reviews_cleaned.csv')
train_description = pd.read_csv('../data/cleaned_data/train_description_cleaned.csv')
train_host = pd.read_csv('../data/cleaned_data/train_host_cleaned.csv')

train_reviews.drop('Unnamed: 0', axis=1, inplace=True)
train_description.drop('Unnamed: 0', axis=1, inplace=True)
train_host.drop('Unnamed: 0', axis=1, inplace=True)

# %%
test_reviews = pd.read_csv('../data/cleaned_data/airbnb_test_reviews_cleaned.csv')
test_description = pd.read_csv('../data/cleaned_data/test_description_cleaned.csv')
test_host = pd.read_csv('../data/cleaned_data/test_host_cleaned.csv')

test_reviews.drop('Unnamed: 0', axis=1, inplace=True)
test_description.drop('Unnamed: 0', axis=1, inplace=True)
test_host.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #### checkinh again for Nan values

# %%
print(train_reviews.isna().sum(), end = '\n\n')
print(train_description.isna().sum(), end = '\n\n')
print(train_host.isna().sum(), end = '\n\n')
print(test_reviews.isna().sum(), end = '\n\n')
print(test_description.isna().sum(), end = '\n\n')
print(test_host.isna().sum())
# Out:
# comments             0
# language             0
# cleaned_comments    78
# dtype: int64
#
# description             0
# description_language    0
# cleaned_description     0
# dtype: int64
#
# host_about       0
# host_language    0
# cleaned_host     2
# dtype: int64
#
# comments            128
# language              0
# cleaned_comments    142
# dtype: int64
#
# description             0
# description_language    0
# cleaned_description     0
# dtype: int64
#
# host_about       0
# host_language    0
# cleaned_host     0
# dtype: int64

# %%
train_host[train_host.isna().any(axis=1)]
# Out:
#      host_about host_language cleaned_host
# 372           s            en          NaN
# 2981          a            en          NaN

# %%
train_host['cleaned_host'].fillna('empty', inplace = True)

# %%
test_reviews[test_reviews.isna().any(axis=1)]
# Out:
#       comments language cleaned_comments
# 1077       NaN  unknown              NaN
# 1174       NaN  unknown              NaN
# 1890       NaN  unknown              NaN
# 2166       NaN  unknown              NaN
# 2717       NaN  unknown              NaN
# ...        ...      ...              ...
# 40526      NaN  unknown              NaN
# 41047      NaN  unknown              NaN
# 41128      NaN  unknown              NaN
# 41648      NaN  unknown              NaN
# 41654      NaN  unknown              NaN
#
# [142 rows x 3 columns]

# %%
test_reviews.dropna(inplace=True)

# %%
train_reviews[train_reviews.isna().any(axis=1)]
# Out:
#                     comments language cleaned_comments
# 26      you have to be there       en              NaN
# 316                        i       en              NaN
# 4675                       o       en              NaN
# 7771                       a       en              NaN
# 20266             все хорошо       ru              NaN
# ...                      ...      ...              ...
# 326702                     a       en              NaN
# 339058                     a       en              NaN
# 343018                     a       en              NaN
# 346698             as before       en              NaN
# 352674                     i       en              NaN
#
# [78 rows x 3 columns]

# %%
train_reviews.dropna(inplace=True)

# %%
print(train_reviews.isna().sum(), end = '\n\n')
print(train_description.isna().sum(), end = '\n\n')
print(train_host.isna().sum(), end = '\n\n')
print(test_reviews.isna().sum(), end = '\n\n')
print(test_description.isna().sum(), end = '\n\n')
print(test_host.isna().sum())
# Out:
# comments            0
# language            0
# cleaned_comments    0
# dtype: int64
#
# description             0
# description_language    0
# cleaned_description     0
# dtype: int64
#
# host_about       0
# host_language    0
# cleaned_host     0
# dtype: int64
#
# comments            0
# language            0
# cleaned_comments    0
# dtype: int64
#
# description             0
# description_language    0
# cleaned_description     0
# dtype: int64
#
# host_about       0
# host_language    0
# cleaned_host     0
# dtype: int64

# %%
print(train_reviews[train_reviews['language'] == 'unknown'], end = '\n\n')
print(train_description[train_description['description_language'] == 'unknown'], end = '\n\n')
print(train_host[train_host['host_language'] == 'unknown'], end = '\n\n')
print(test_reviews[test_reviews['language'] == 'unknown'], end = '\n\n')
print(test_description[test_description['description_language'] == 'unknown'], end = '\n\n')
print(test_host[test_host['host_language'] == 'unknown'])
# Out:
# Empty DataFrame
# Columns: [comments, language, cleaned_comments]
# Index: []
#
# Empty DataFrame
# Columns: [description, description_language, cleaned_description]
# Index: []
#
#      host_about host_language cleaned_host
# 18        empty       unknown        empty
# 85        empty       unknown        empty
# 92        empty       unknown        empty
# 110       empty       unknown        empty
# 185       empty       unknown        empty
# ...         ...           ...          ...
# 5553      empty       unknown        empty
# 5792      empty       unknown        empty
# 5942      empty       unknown        empty
# 5955      empty       unknown        empty
# 5985      empty       unknown        empty
#
# [79 rows x 3 columns]
#
# Empty DataFrame
# Columns: [comments, language, cleaned_comments]
# Index: []
#
# Empty DataFrame
# Columns: [description, description_language, cleaned_description]
# Index: []
#
#     host_about host_language cleaned_host
# 3        empty       unknown        empty
# 32       empty       unknown        empty
# 102      empty       unknown        empty
# 106      empty       unknown        empty
# 351      empty       unknown        empty
# 364      empty       unknown        empty
# 527      empty       unknown        empty
# 559      empty       unknown        empty
# 605      empty       unknown        empty
# 627      empty       unknown        empty

# %% [markdown]
# # Cleaned Data Sets

# %%
train_reviews = train_reviews.join(airbnb_train_reviews[['index']], how='inner')

# %%
train_reviews.head()
# Out:
#                                             comments language  \
# 0  this is a very cozy and comfortable house to s...       en
# 1                                               good       en
# 2  my first hostel experience and all i have to s...       en
# 3  das hostel war neu und deshalb funktionierte a...       de
# 4  it was fine for a dorm but i think for the peo...       en
#
#                                     cleaned_comments  index
# 0  cozy comfortable house stay never worry safety...      1
# 1                                               good      1
# 2  first hostel experience say pretty hard beat p...      1
# 3  hostel neu deshalb funktionieren tadellos schn...      1
# 4  fine dorm think people staying far le bathroom...      1

# %%
test_reviews = test_reviews.join(airbnb_test_reviews[['index']], how='inner')

# %%
test_reviews.head()
# Out:
#                                             comments language  \
# 0  thank you very much antonio all has been perfe...       en
# 1  very nice appartment in the old town of lissab...       en
# 2  when travelling we re looking for kids friendl...       en
# 3  we ve been in lisbon in march adults and child...       en
# 4  our host antonio was very helpful with informa...       en
#
#                                     cleaned_comments  index
# 0  thank much antonio perfect stay appartment per...      1
# 1  nice appartment old town lissabon quite centra...      1
# 2  travelling looking kid friendly place stay ant...      1
# 3  lisbon march adult child house big comfortable...      1
# 4  host antonio helpful information lissabon pick...      1

# %%
train_reviews.drop(['comments','language'], axis=1, inplace=True)
test_reviews.drop(['comments','language'], axis=1, inplace=True)

# %%
train = train_description.join(train_host)
train['index'] = airbnb_train['index']

test = test_description.join(test_host)
test['index'] = airbnb_test['index']

# %%
train.drop(['description', 'description_language','host_about', 'host_language'], axis=1, inplace=True)
test.drop(['description', 'description_language','host_about', 'host_language'], axis=1, inplace=True)

# %%
train_reviews.head()
# Out:
#                                     cleaned_comments  index
# 0  cozy comfortable house stay never worry safety...      1
# 1                                               good      1
# 2  first hostel experience say pretty hard beat p...      1
# 3  hostel neu deshalb funktionieren tadellos schn...      1
# 4  fine dorm think people staying far le bathroom...      1

# %%
train.head()
# Out:
#                                  cleaned_description  \
# 0  shared mixed room hostel shared bathroom locat...
# 1  espaço ficar perto parque eduardo Vii saldanha...
# 2  trafaria house cozy familiar villa facility ne...
# 3  apartamento charmoso chiar largo Carmo travess...
# 4  joli appartemer bordure mer min avoir pied pla...
#
#                                         cleaned_host  index
# 0                          alojamento local registro      1
# 1  friendly host try always around need anything ...      2
# 2  social person liking communicate reading trave...      3
# 3  hello portuguese love meet people around word ...      4
# 4  famille deux enfant an habité pendant plusieur...      5

# %%
test_reviews.head()
# Out:
#                                     cleaned_comments  index
# 0  thank much antonio perfect stay appartment per...      1
# 1  nice appartment old town lissabon quite centra...      1
# 2  travelling looking kid friendly place stay ant...      1
# 3  lisbon march adult child house big comfortable...      1
# 4  host antonio helpful information lissabon pick...      1

# %%
test.head()
# Out:
#                                  cleaned_description  \
# 0  space apartment located historic center lisbon...
# 1  important response covid property extended cle...
# 2  bright beautiful spacious four bedroom apartme...
# 3  charming apartment close bay cascais bedroom d...
# 4  procurar um férias perto praia casino outro at...
#
#                                         cleaned_host  index
# 0  gostar viajar conhecer pessoa gostar receber a...      1
# 1  home team count u take care every single detai...      2
# 2  hi guestready professional property management...      3
# 3                                              empty      4
# 4  bem vinr Portugal adorar país adorar conhecer ...      5

# %% [markdown]
# ### test for final prediction

# %%
test_reviews_joined = test_reviews.groupby('index')['cleaned_comments'].apply(lambda x: ' '.join(x)).reset_index()
test_reviews_joined.head()
# Out:
#    index                                   cleaned_comments
# 0      1  thank much antonio perfect stay appartment per...
# 1      2  beautiful bright apartment residential area li...
# 2      4  claudia great host met u train station bring u...
# 3      5  maison exactement comme photo très propre drap...
# 4      6  excellent realy grerat house feel like domesti...

# %%
test_joined = pd.merge(test, test_reviews_joined, on='index', how='outer')
test_joined.head()
# Out:
#                                  cleaned_description  \
# 0  space apartment located historic center lisbon...
# 1  important response covid property extended cle...
# 2  bright beautiful spacious four bedroom apartme...
# 3  charming apartment close bay cascais bedroom d...
# 4  procurar um férias perto praia casino outro at...
#
#                                         cleaned_host  index  \
# 0  gostar viajar conhecer pessoa gostar receber a...      1
# 1  home team count u take care every single detai...      2
# 2  hi guestready professional property management...      3
# 3                                              empty      4
# 4  bem vinr Portugal adorar país adorar conhecer ...      5
#
#                                     cleaned_comments
# 0  thank much antonio perfect stay appartment per...
# 1  beautiful bright apartment residential area li...
# 2                                                NaN
# 3  claudia great host met u train station bring u...
# 4  maison exactement comme photo très propre drap...

# %%
test_joined.isna().sum()
# Out:
# cleaned_description      0
# cleaned_host             0
# index                    0
# cleaned_comments       220
# dtype: int64

# %%
test_joined['cleaned_comments'].fillna('empty', inplace = True)

# %%
test_joined.set_index('index', inplace=True)
test_joined.head()
# Out:
#                                      cleaned_description  \
# index
# 1      space apartment located historic center lisbon...
# 2      important response covid property extended cle...
# 3      bright beautiful spacious four bedroom apartme...
# 4      charming apartment close bay cascais bedroom d...
# 5      procurar um férias perto praia casino outro at...
#
#                                             cleaned_host  \
# index
# 1      gostar viajar conhecer pessoa gostar receber a...
# 2      home team count u take care every single detai...
# 3      hi guestready professional property management...
# 4                                                  empty
# 5      bem vinr Portugal adorar país adorar conhecer ...
#
#                                         cleaned_comments
# index
# 1      thank much antonio perfect stay appartment per...
# 2      beautiful bright apartment residential area li...
# 3                                                  empty
# 4      claudia great host met u train station bring u...
# 5      maison exactement comme photo très propre drap...

# %%
X1_test = test_joined['cleaned_comments']
X2_test = test_joined['cleaned_host']
X3_test = test_joined['cleaned_description']

# %%
print(X1_test.shape)
print(X2_test.shape)
print(X3_test.shape)
# Out:
# (695,)
# (695,)
# (695,)

# %% [markdown]
# #### saving cleaned data

# %%
train_reviews.to_csv('train_reviews.csv')
test_reviews.to_csv('train_reviews.csv')

# %%
def generate_wordcloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
train_reviews_ = " ".join(train_reviews['cleaned_comments'])
generate_wordcloud(train_reviews_)

# %%
train_reviews_words = " ".join(train_reviews['cleaned_comments']).split()
freq_train_rev = pd.Series(train_reviews_words).value_counts()
freq_train_rev.sort_values(ascending=False)[0:10]
# Out:
# apartment    157185
# great        140443
# place        109698
# stay         105076
# location     104508
# lisbon        78501
# très          74478
# u             73384
# host          72452
# nice          66595
# Name: count, dtype: int64

# %%
x_labels = freq_train_rev.index[0:10]
values = freq_train_rev[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
test_reviews_ = " ".join(test_reviews['cleaned_comments'])
generate_wordcloud(test_reviews_)

# %%
test_reviews_words = " ".join(test_reviews['cleaned_comments']).split()
freq_test_rev = pd.Series(test_reviews_words).value_counts()
freq_test_rev.sort_values(ascending=False)[0:10]
# Out:
# apartment    18626
# great        16701
# place        12952
# location     12336
# stay         12275
# lisbon        9587
# u             9057
# host          8326
# très          8063
# clean         7697
# Name: count, dtype: int64

# %%
x_labels = freq_test_rev.index[0:10]
values = freq_test_rev[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# #### host

# %%
train_host_ = " ".join(train['cleaned_host'])
generate_wordcloud(train_host_)

# %%
train_host_ = " ".join(train['cleaned_host']).split()
freq_host = pd.Series(train_host_).value_counts()
freq_host.sort_values(ascending=False)[0:10]
# Out:
# lisbon        4136
# love          2717
# home          2275
# apartment     1976
# stay          1949
# guest         1933
# experience    1917
# portugal      1802
# city          1785
# like          1662
# Name: count, dtype: int64

# %%
x_labels = freq_host.index[0:10]
values = freq_host[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
test_host_ = " ".join(test['cleaned_host'])
generate_wordcloud(test_host_)

# %%
test_host_ = " ".join(test['cleaned_host']).split()
freq_host = pd.Series(test_host_).value_counts()
freq_host.sort_values(ascending=False)[0:10]
# Out:
# lisbon        485
# love          315
# home          270
# stay          258
# guest         233
# apartment     231
# experience    217
# like          202
# city          200
# portugal      181
# Name: count, dtype: int64

# %%
x_labels = freq_host.index[0:10]
values = freq_host[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# #### property description

# %%
train_dcp_ = " ".join(train['cleaned_description'])
generate_wordcloud(train_dcp_)

# %%
train_dcp_ = " ".join(train['cleaned_description']).split()
freq_dcp = pd.Series(train_dcp_).value_counts()
freq_dcp.sort_values(ascending=False)[0:10]
# Out:
# apartment    9360
# lisbon       6297
# space        5996
# room         5771
# bedroom      4742
# bed          4196
# guest        3915
# located      3881
# kitchen      3685
# bathroom     3245
# Name: count, dtype: int64

# %%
x_labels = freq_dcp.index[0:10]
values = freq_dcp[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
test_dcp_ = " ".join(test['cleaned_description'])
generate_wordcloud(test_dcp_)

# %%
test_dcp_ = " ".join(test['cleaned_description']).split()
freq_dcp = pd.Series(test_dcp_).value_counts()
freq_dcp.sort_values(ascending=False)[0:10]
# Out:
# apartment    1075
# lisbon        703
# space         694
# room          679
# bedroom       580
# bed           514
# guest         488
# kitchen       456
# located       433
# one           431
# Name: count, dtype: int64

# %%
x_labels = freq_dcp.index[0:10]
values = freq_dcp[:10]
plt.bar(x_labels, values)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Frequency')
plt.title('Most Frequent Words')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ### Feature extraction
#
# Bag-of-Words (BoW): Represent each review as a vector of word frequencies.
#
# TF-IDF (Term Frequency-Inverse Document Frequency): Weigh the importance of words based on their frequency in the document and across all documents.
#
# Word embeddings: Represent words as dense vectors in a high-dimensional space.

# %% [markdown]
# #### joining the datasets

# %%
train_reviews_joined = train_reviews.groupby('index')['cleaned_comments'].apply(lambda x: ' '.join(x)).reset_index()
train_reviews_joined.head()
# Out:
#    index                                   cleaned_comments
# 0      1  cozy comfortable house stay never worry safety...
# 1      5  très bel appartemer magnifique voir plage mer ...
# 2      8  shani helpful throughout process thank answeri...
# 3      9  passer très bon séjour chez isabel helder appa...
# 4     10  outpost beautiful place stay azenhas mar prope...

# %%
train_joined = pd.merge(train, train_reviews_joined, on='index', how='outer')
train_joined = train_joined.join(airbnb_train[['unlisted']], how='outer')
train_joined.head()
# Out:
#                                  cleaned_description  \
# 0  shared mixed room hostel shared bathroom locat...
# 1  espaço ficar perto parque eduardo Vii saldanha...
# 2  trafaria house cozy familiar villa facility ne...
# 3  apartamento charmoso chiar largo Carmo travess...
# 4  joli appartemer bordure mer min avoir pied pla...
#
#                                         cleaned_host  index  \
# 0                          alojamento local registro      1
# 1  friendly host try always around need anything ...      2
# 2  social person liking communicate reading trave...      3
# 3  hello portuguese love meet people around word ...      4
# 4  famille deux enfant an habité pendant plusieur...      5
#
#                                     cleaned_comments  unlisted
# 0  cozy comfortable house stay never worry safety...         0
# 1                                                NaN         1
# 2                                                NaN         1
# 3                                                NaN         0
# 4  très bel appartemer magnifique voir plage mer ...         0

# %%
train_joined.isna().sum()
# Out:
# cleaned_description       0
# cleaned_host              0
# index                     0
# cleaned_comments       2012
# unlisted                  0
# dtype: int64

# %%
train_joined['cleaned_comments'].fillna('empty', inplace = True)

# %%
train_joined.set_index('index', inplace=True)
train_joined.head()
# Out:
#                                      cleaned_description  \
# index
# 1      shared mixed room hostel shared bathroom locat...
# 2      espaço ficar perto parque eduardo Vii saldanha...
# 3      trafaria house cozy familiar villa facility ne...
# 4      apartamento charmoso chiar largo Carmo travess...
# 5      joli appartemer bordure mer min avoir pied pla...
#
#                                             cleaned_host  \
# index
# 1                              alojamento local registro
# 2      friendly host try always around need anything ...
# 3      social person liking communicate reading trave...
# 4      hello portuguese love meet people around word ...
# 5      famille deux enfant an habité pendant plusieur...
#
#                                         cleaned_comments  unlisted
# index
# 1      cozy comfortable house stay never worry safety...         0
# 2                                                  empty         1
# 3                                                  empty         1
# 4                                                  empty         0
# 5      très bel appartemer magnifique voir plage mer ...         0

# %%
y_final = train_joined['unlisted']

# %%
y_final
# Out:
# index
# 1       0
# 2       1
# 3       1
# 4       0
# 5       0
#        ..
# 6244    0
# 6245    0
# 6246    1
# 6247    0
# 6248    0
# Name: unlisted, Length: 6248, dtype: int64

# %%
train_joined.drop('unlisted', axis=1, inplace=True)

# %% [markdown]
# #### Train-test split (to be able to evaluate the results)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    train_joined, y_final, stratify=y_final, random_state=42, test_size=0.25
)

# %%
print(f"Train shapes: X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"Validation shapes: X_val: {X_val.shape}, y_val: {y_val.shape}")
# Out:
# Train shapes: X_train: (4686, 3), y_train: (4686,)
# Validation shapes: X_val: (1562, 3), y_val: (1562,)

# %%
X1 = X_train['cleaned_comments']
X2 = X_train['cleaned_host']
X3 = X_train['cleaned_description']
y = y_train

# %%
print(X1.shape)
print(X2.shape)
print(X3.shape)
print(y.shape)
# Out:
# (4686,)
# (4686,)
# (4686,)
# (4686,)

# %%
y.value_counts()
# Out:
# unlisted
# 0    3405
# 1    1281
# Name: count, dtype: int64

# %%
from sklearn.model_selection import StratifiedKFold
kf = StratifiedKFold(n_splits=5, shuffle= True, random_state=42)

# %% [markdown]
# ## BoW

# %%
bow_vectorizer1 = CountVectorizer()
bow_vectorizer2 = CountVectorizer()
bow_vectorizer3 = CountVectorizer()

results_bow = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': []
}

# %%
# Perform BoW feature extraction for each feature
X1_bow = bow_vectorizer1.fit_transform(X1)
X2_bow = bow_vectorizer2.fit_transform(X2)
X3_bow = bow_vectorizer3.fit_transform(X3)

# Combine BoW features
X_combined_bow = hstack([X1_bow, X2_bow, X3_bow])

for train_index, test_index in kf.split(X_combined_bow,y):
    # Split data
    X_train_, X_test_ = X_combined_bow[train_index], X_combined_bow[test_index]
    y_train_, y_test_ = y.iloc[train_index], y.iloc[test_index]

    # Model Training and Evaluation
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train_, y_train_)
    y_pred = model.predict(X_test_)

    # Calculate evaluation metrics
    results_bow['accuracy'].append(accuracy_score(y_test_, y_pred))
    results_bow['precision'].append(precision_score(y_test_, y_pred))
    results_bow['recall'].append(recall_score(y_test_, y_pred))
    results_bow['f1'].append(f1_score(y_test_, y_pred))

# %%
print(f"Mean Accuracy for BoW: {np.mean(results_bow['accuracy'])}")
print(f"Mean Precision for BoW: {np.mean(results_bow['precision'])}")
print(f"Mean Recall for BoW: {np.mean(results_bow['recall'])}")
print(f"Mean F1 Score for BoW: {np.mean(results_bow['f1'])}")
# Out:
# Mean Accuracy for BoW: 0.8418704616875979
# Mean Precision for BoW: 0.7023760266551791
# Mean Recall for BoW: 0.7330222519455253
# Mean F1 Score for BoW: 0.7169515389423088

# %% [markdown]
# ## TF-IDF

# %%
tfidf_vectorizer1 = TfidfVectorizer()
tfidf_vectorizer2 = TfidfVectorizer()
tfidf_vectorizer3 = TfidfVectorizer()

results_tfidf = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': []
}

# %%
# Perform TF-IDF feature extraction for each feature
X1_tfidf = tfidf_vectorizer1.fit_transform(X1)
X2_tfidf = tfidf_vectorizer2.fit_transform(X2)
X3_tfidf = tfidf_vectorizer3.fit_transform(X3)

# Combine TF-IDF features
X_combined_tfidf = hstack([X1_tfidf, X2_tfidf, X3_tfidf])

# Loop through the kfold splits
for train_index, test_index in kf.split(X_combined_tfidf,y):
    # Split data
    X_train_, X_test_ = X_combined_tfidf[train_index], X_combined_tfidf[test_index]
    y_train_, y_test_ = y.iloc[train_index], y.iloc[test_index]

    # Model Training and Evaluation
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train_, y_train_)
    y_pred = model.predict(X_test_)

    # Calculate evaluation metrics
    results_tfidf['accuracy'].append(accuracy_score(y_test_, y_pred))
    results_tfidf['precision'].append(precision_score(y_test_, y_pred))
    results_tfidf['recall'].append(recall_score(y_test_, y_pred))
    results_tfidf['f1'].append(f1_score(y_test_, y_pred))

# Calculate average evaluation metrics
avg_accuracy = np.mean(results_tfidf['accuracy'])
avg_precision = np.mean(results_tfidf['precision'])
avg_recall = np.mean(results_tfidf['recall'])
avg_f1 = np.mean(results_tfidf['f1'])

# %%
print(f"Mean Accuracy for TF-IDF: {np.mean(results_tfidf['accuracy'])}")
print(f"Mean Precision for TF-IDF: {np.mean(results_tfidf['precision'])}")
print(f"Mean Recall for TF-IDF: {np.mean(results_tfidf['recall'])}")
print(f"Mean F1 Score for TF-IDF: {np.mean(results_tfidf['f1'])}")
# Out:
# Mean Accuracy for TF-IDF: 0.8819880624321599
# Mean Precision for TF-IDF: 0.7586289449342438
# Mean Recall for TF-IDF: 0.8345117947470817
# Mean F1 Score for TF-IDF: 0.7944333556378655

# %% [markdown]
# ## Word2Vec

# %%
results_word2vec = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': []
}

# %%
def train_word2vec_model(data):
    model = Word2Vec(data, vector_size=100, window=5, min_count=1, workers=4)
    return model

# Convert text to Word2Vec vectors
def text_to_word2vec(text, model):
    vector = np.zeros(model.vector_size)
    count = 0
    for word in text.split():
        if word in model.wv:
            vector += model.wv[word]
            count += 1
    if count != 0:
        vector /= count
    return vector

# Train Word2Vec models for each column
model1 = train_word2vec_model([doc.split() for doc in X1])
model2 = train_word2vec_model([doc.split() for doc in X2])
model3 = train_word2vec_model([doc.split() for doc in X3])

# Convert text to Word2Vec vectors
X1_word2vec = np.array([text_to_word2vec(doc, model1) for doc in X1])
X2_word2vec = np.array([text_to_word2vec(doc, model2) for doc in X2])
X3_word2vec = np.array([text_to_word2vec(doc, model3) for doc in X3])

# Concatenate the features
X_word2vec = np.concatenate((X1_word2vec, X2_word2vec, X3_word2vec), axis=1)

# %%
classifier = LogisticRegression(max_iter = 1000)

y_array = y.to_numpy()

# Perform cross-validation
accuracies = []
for train_index, test_index in kf.split(X_word2vec, y_array):
    X_train_, X_test_ = X_word2vec[train_index], X_word2vec[test_index]
    y_train_, y_test_ = y_array[train_index], y_array[test_index]
    
    # Train the classifier
    classifier.fit(X_train_, y_train_)
    
    # Predict on the test set
    y_pred = classifier.predict(X_test_)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test_, y_pred)
    precision = precision_score(y_test_, y_pred)
    recall = recall_score(y_test_, y_pred)
    f1 = f1_score(y_test_, y_pred)
    
    # Store the evaluation metrics in the results dictionary
    results_word2vec['accuracy'].append(accuracy)
    results_word2vec['precision'].append(precision)
    results_word2vec['recall'].append(recall)
    results_word2vec['f1'].append(f1)

# %%
# Calculate the average metrics across all folds
average_accuracy = np.mean(results_word2vec['accuracy'])
average_precision = np.mean(results_word2vec['precision'])
average_recall = np.mean(results_word2vec['recall'])
average_f1 = np.mean(results_word2vec['f1'])

print("Average Accuracy:", average_accuracy)
print("Average Precision:", average_precision)
print("Average Recall:", average_recall)
print("Average F1-score:", average_f1)
# Out:
# Average Accuracy: 0.8732394590547795
# Average Precision: 0.735869134594078
# Average Recall: 0.8376337548638133
# Average F1-score: 0.783202725483324

# %% [markdown]
# ## Embeddings - BERT

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertModel.from_pretrained('bert-base-multilingual-cased')
    
def embedding(texts, batch_size=8):
    embeddings = []
    # Initialize tqdm to create the progress bar
    with tqdm(total=len(texts), desc="Embedding Progress") as pbar:
        for i in range(0, len(texts), batch_size):
            batch = texts[i:i+batch_size]
            inputs = tokenizer(batch, return_tensors='pt', padding=True, truncation=True)
            with torch.no_grad():  # Disable gradient calculation
                outputs = model(**inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1)  # Mean pooling
            embeddings.extend(batch_embeddings.cpu().numpy())  # Move to CPU and convert to numpy array
            # Update the progress bar
            pbar.update(len(batch))
    return embeddings

# %% [markdown]
# #### X's

# %% [raw]
# X1_list = X1.tolist()
# X1_emb = embedding(X1_list)

# %% [raw]
# X2_list = X2.tolist()
# X2_emb = embedding(X2_list)

# %% [raw]
# X3_list = X3.tolist()
# X3_emb = embedding(X3_list)

# %% [markdown]
# #### saving ebm results

# %% [raw]
# # Convert the list to a NumPy array
# X1_emb_array = np.array(X1_emb)
#
# # Save the NumPy array to a .npy file
# np.save('X1_emb.npy', X1_emb_array)

# %% [raw]
# X2_emb_array = np.array(X2_emb)
# np.save('X2_emb.npy', X2_emb_array)

# %% [raw]
# X3_emb_array = np.array(X3_emb)
# np.save('X3_emb.npy', X3_emb_array)

# %% [markdown]
# #### load

# %%
X1_emb_array = np.load('X1_emb.npy')
X1_emb = X1_emb_array.tolist()

# %%
X2_emb_array = np.load('X2_emb.npy')
X2_emb = X2_emb_array.tolist()

# %%
X3_emb_array = np.load('X3_emb.npy')
X3_emb = X3_emb_array.tolist()

# %% [markdown]
# ### Evaluating the embeddings

# %%
results_emb = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': []
}

# %%
combined_embeddings = np.concatenate([X1_emb, X2_emb, X3_emb], axis=1)

# %%
combined_embeddings.shape
# Out:
# (4686, 2304)

# %%
y_array = y.to_numpy()

for train_index, test_index in kf.split(combined_embeddings, y_array):
    X_train_, X_test_ = combined_embeddings[train_index], combined_embeddings[test_index]
    y_train_, y_test_ = y_array[train_index], y_array[test_index]
    
    # Train a logistic regression model
    model = LogisticRegression(max_iter = 1000)
    model.fit(X_train_, y_train_)
    
    # Predict on the test set
    y_pred = model.predict(X_test_)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test_, y_pred)
    precision = precision_score(y_test_, y_pred)
    recall = recall_score(y_test_, y_pred)
    f1 = f1_score(y_test_, y_pred)
    
    # Store evaluation metrics
    results_emb['accuracy'].append(accuracy)
    results_emb['precision'].append(precision)
    results_emb['recall'].append(recall)
    results_emb['f1'].append(f1)

# %%
print("Mean Accuracy:", round(np.mean(results_emb['accuracy']), 3))
print("Standard Deviation of Accuracy:", round(np.std(results_emb['accuracy']), 3))
print()
print("Mean Precision:", round(np.mean(results_emb['precision']), 3))
print("Standard Deviation of Precision:", round(np.std(results_emb['precision']), 3))
print()
print("Mean Recall:", round(np.mean(results_emb['recall']), 3))
print("Standard Deviation of Recall:", round(np.std(results_emb['recall']), 3))
print()
print("Mean F1 Score:", round(np.mean(results_emb['f1']), 3))
print("Standard Deviation of F1 Score:", round(np.std(results_emb['f1']), 3))
# Out:
# Mean Accuracy: 0.861
# Standard Deviation of Accuracy: 0.007
#
# Mean Precision: 0.751
# Standard Deviation of Precision: 0.018
#
# Mean Recall: 0.738
# Standard Deviation of Recall: 0.011
#
# Mean F1 Score: 0.744
# Standard Deviation of F1 Score: 0.012

# %% [markdown]
# ## LaBSE - sentence embedding
# The LaBSE model from sentence-transformers is specifically optimized for creating high-quality sentence embeddings across multiple languages, and it includes all necessary preprocessing steps internally (padding and tokenization).

# %%
from sentence_transformers import SentenceTransformer

# Load LaBSE model
model = SentenceTransformer('sentence-transformers/LaBSE')

# Function to generate embeddings using LaBSE
def embedding(texts, batch_size=8):
    embeddings = []
    # Initialize tqdm to create the progress bar
    with tqdm(total=len(texts), desc="Embedding Progress") as pbar:
        for i in range(0, len(texts), batch_size):
            batch = texts[i:i+batch_size]
            batch_embeddings = model.encode(batch, show_progress_bar=False)
            embeddings.extend(batch_embeddings)
            # Update the progress bar
            pbar.update(len(batch))
    return embeddings

# %% [raw]
# X1_list_ = X1.tolist()
# X2_list_ = X2.tolist()
# X3_list_ = X3.tolist()

# %% [raw]
# X1_emb_ = embedding(X1_list_)

# %% [raw]
# X2_emb_ = embedding(X2_list_)

# %% [raw]
# X3_emb_ = embedding(X3_list_)

# %% [markdown]
# #### saving ebd results

# %% [raw]
# X1_emb_array_labse = np.array(X1_emb_)
# np.save('X1_emb_array_labse.npy', X1_emb_array_labse)

# %% [raw]
# X2_emb_array_labse = np.array(X2_emb_)
# np.save('X2_emb_array_labse.npy', X2_emb_array_labse)

# %% [raw]
# X3_emb_array_labse = np.array(X3_emb_)
# np.save('X3_emb_array_labse.npy', X3_emb_array_labse)

# %% [markdown]
# #### load

# %%
X1_emb_array_labse = np.load('X1_emb_array_labse.npy')
X1_emb_ = X1_emb_array_labse.tolist()

# %%
X2_emb_array_labse = np.load('X2_emb_array_labse.npy')
X2_emb_ = X2_emb_array_labse.tolist()

# %%
X3_emb_array_labse = np.load('X3_emb_array_labse.npy')
X3_emb_ = X3_emb_array_labse.tolist()

# %%
# Combine embeddings
combined_embeddings_labse = np.concatenate([X1_emb_, X2_emb_, X3_emb_], axis=1)

# Convert target to numpy array
y_array = y.to_numpy()

# Initialize results dictionary
results_emb = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1': []
}

# Cross-validation
for train_index, test_index in kf.split(combined_embeddings_labse, y_array):
    X_train_, X_test_ = combined_embeddings_labse[train_index], combined_embeddings_labse[test_index]
    y_train_, y_test_ = y_array[train_index], y_array[test_index]
    
    # Train a logistic regression model
    clf = LogisticRegression(max_iter=1000)
    clf.fit(X_train_, y_train_)
    
    # Predict on the test set
    y_pred = clf.predict(X_test_)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test_, y_pred)
    precision = precision_score(y_test_, y_pred)
    recall = recall_score(y_test_, y_pred)
    f1 = f1_score(y_test_, y_pred)
    
    # Store evaluation metrics
    results_emb['accuracy'].append(accuracy)
    results_emb['precision'].append(precision)
    results_emb['recall'].append(recall)
    results_emb['f1'].append(f1)

# Print results
print("Mean Accuracy:", round(np.mean(results_emb['accuracy']), 3))
print("Standard Deviation of Accuracy:", round(np.std(results_emb['accuracy']), 3))
print()
print("Mean Precision:", round(np.mean(results_emb['precision']), 3))
print("Standard Deviation of Precision:", round(np.std(results_emb['precision']), 3))
print()
print("Mean Recall:", round(np.mean(results_emb['recall']), 3))
print("Standard Deviation of Recall:", round(np.std(results_emb['recall']), 3))
print()
print("Mean F1 Score:", round(np.mean(results_emb['f1']), 3))
print("Standard Deviation of F1 Score:", round(np.std(results_emb['f1']), 3))
# Out:
# Mean Accuracy: 0.877
# Standard Deviation of Accuracy: 0.007
#
# Mean Precision: 0.753
# Standard Deviation of Precision: 0.015
#
# Mean Recall: 0.818
# Standard Deviation of Recall: 0.02
#
# Mean F1 Score: 0.784
# Standard Deviation of F1 Score: 0.012

# %% [markdown]
# ## Model testing with TF-IDF

# %% [markdown]
# ### Logistic Regression - sklearn  (using TF-IDF)

# %% [markdown]
# This approach involves performing hyperparameter tuning using a randomized search with cross-validation for three different logistic regression models. Each logistic regression model has different hyperparameters defined in the hyperparameters list. Here's an explanation of each part:
#
# **Models:** Three logistic regression models are defined with different settings for the solver parameter. This allows you to explore how different solvers perform with different hyperparameters.
#
# **Hyperparameters:** For each logistic regression model, a dictionary of hyperparameters is defined. These hyperparameters will be tuned during the randomized search. Each dictionary contains different combinations of hyperparameters to explore.
#
# **Cross-validation:** Stratified k-fold cross-validation is used to evaluate the performance of each model and hyperparameter combination. It ensures that each fold preserves the percentage of samples for each class. as we are using on all the project
#
# **Randomized Search:** For each model, a RandomizedSearchCV object is created. It performs a randomized search over the hyperparameter space defined in the corresponding hyperparameters dictionary. The scoring parameter is set to 'f1', indicating that the F1 score will be used as the evaluation metric.
#
# **Results:** After the randomized search is complete for each model, the best score and best parameters are recorded in a DataFrame named test_scores_lg. This DataFrame contains the performance of each model along with the corresponding best hyperparameters.

# %%
models = [
    LogisticRegression(class_weight='balanced', random_state=42, solver='saga'),
    LogisticRegression(class_weight='balanced', random_state=42, solver='liblinear'),
    LogisticRegression(class_weight='balanced', random_state=42, solver='saga')
]


hyperparameters = [
    {
        'model__penalty': ['l2'],
        'model__C': np.logspace(-2, 2, 50) 
    },
    {
        'model__penalty': ['l1', 'l2'],
        'model__C': np.logspace(-2, 2, 50)  
    },
    {
        'model__penalty': ['l1','elasticnet'],
        'model__C': np.logspace(-2, 2, 50),  
        'model__l1_ratio': [0.1, 0.5, 0.9]  
    }
]

# Initialize cross-validation
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=19)

results = []
cv_results_dfs = []

# Loop through each model and its hyperparameters
for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([('model', model)])

    # Perform random search
    rs = RandomizedSearchCV(pipeline, params, cv=stratified_kfold, n_iter=10, scoring='f1', verbose=10)
    rs.fit(X_combined_tfidf, y)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

# Create DataFrame with results
test_scores_lg_tfidf = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_lg_tfidf = test_scores_lg_tfidf.sort_values('best_score', ascending=False)

# %%
test_scores_lg_tfidf

# %%
print(test_scores_lg_tfidf['best_params'][1])
print(test_scores_lg_tfidf['best_score'][1])

# %% [raw]
# {'model__penalty': 'l2', 'model__C': 3.3932217718953264}
# 0.8029875886647521

# %%
print(test_scores_lg_tfidf['best_params'][2])
print(test_scores_lg_tfidf['best_score'][2])

# %% [raw]
# {'model__penalty': 'elasticnet', 'model__l1_ratio': 0.1, 'model__C': 47.1486636345739}
# 0.7938147638335016

# %%
print(test_scores_lg_tfidf['best_params'][0])
print(test_scores_lg_tfidf['best_score'][0])

# %% [raw]
# {'model__penalty': 'l2', 'model__C': 8.68511373751352}
# 0.803875274981545

# %% [markdown]
# ### KNN - sklearn  (using TF-IDF)

# %%
nn_model = KNeighborsClassifier()

# Define the hyperparameters for randomized search
hyperparameters = {
    'n_neighbors': range(1, 31),  # Test range of neighbors from 1 to 20
    'weights': ['uniform', 'distance'],  # Test uniform and distance-based weights
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algorithms for computing neighbors
    'p': [1, 2]  # Parameter for distance metric (1 for Manhattan, 2 for Euclidean)
}

# Set up randomized search with cross-validation
rs = RandomizedSearchCV(knn_model, hyperparameters, cv=stratified_kfold, n_iter=40, scoring='f1', verbose=10)

# Perform the randomized search for best hyperparameters
rs.fit(X_combined_tfidf, y)

# Extract the results
best_params_knn = rs.best_params_
best_score_knn = rs.best_score_
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5; 1/40] START algorithm=brute, n_neighbors=15, p=2, weights=distance.....
# [CV 1/5; 1/40] END algorithm=brute, n_neighbors=15, p=2, weights=distance;, score=0.790 total time=   0.6s
# [CV 2/5; 1/40] START algorithm=brute, n_neighbors=15, p=2, weights=distance.....
# [CV 2/5; 1/40] END algorithm=brute, n_neighbors=15, p=2, weights=distance;, score=0.789 total time=   0.6s
# [CV 3/5; 1/40] START algorithm=brute, n_neighbors=15, p=2, weights=distance.....
# [CV 3/5; 1/40] END algorithm=brute, n_neighbors=15, p=2, weights=distance;, score=0.790 total time=   0.6s
# [CV 4/5; 1/40] START algorithm=brute, n_neighbors=15, p=2, weights=distance.....
# [CV 4/5; 1/40] END algorithm=brute, n_neighbors=15, p=2, weights=distance;, score=0.780 total time=   0.6s
# [CV 5/5; 1/40] START algorithm=brute, n_neighbors=15, p=2, weights=distance.....
# [CV 5/5; 1/40] END algorithm=brute, n_neighbors=15, p=2, weights=distance;, score=0.773 total time=   0.6s
# [CV 1/5; 2/40] START algorithm=auto, n_neighbors=2, p=1, weights=uniform........
# [CV 1/5; 2/40] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.452 total time=   1.7s
# [CV 2/5; 2/40] START algorithm=auto, n_neighbors=2, p=1, weights=uniform........
# [CV 2/5; 2/40] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.446 total time=   1.8s
# [CV 3/5; 2/40] START algorithm=auto, n_neighbors=2, p=1, weights=uniform........
# [CV 3/5; 2/40] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.454 total time=   1.9s
# [CV 4/5; 2/40] START algorithm=auto, n_neighbors=2, p=1, weights=uniform........
# [CV 4/5; 2/40] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.460 total time=   1.8s
# [CV 5/5; 2/40] START algorithm=auto, n_neighbors=2, p=1, weights=uniform........
# [CV 5/5; 2/40] END algorithm=auto, n_neighbors=2, p=1, weights=uniform;, score=0.443 total time=   1.7s
# [CV 1/5; 3/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 1/5; 3/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.766 total time=   0.7s
# [CV 2/5; 3/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 2/5; 3/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.773 total time=   0.6s
# [CV 3/5; 3/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 3/5; 3/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.789 total time=   0.6s
# [CV 4/5; 3/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 4/5; 3/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.772 total time=   0.6s
# [CV 5/5; 3/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 5/5; 3/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.773 total time=   0.6s
# [CV 1/5; 4/40] START algorithm=brute, n_neighbors=30, p=1, weights=uniform......
# [CV 1/5; 4/40] END algorithm=brute, n_neighbors=30, p=1, weights=uniform;, score=0.438 total time=   1.7s
# [CV 2/5; 4/40] START algorithm=brute, n_neighbors=30, p=1, weights=uniform......
# [CV 2/5; 4/40] END algorithm=brute, n_neighbors=30, p=1, weights=uniform;, score=0.432 total time=   1.9s
# [CV 3/5; 4/40] START algorithm=brute, n_neighbors=30, p=1, weights=uniform......
# [CV 3/5; 4/40] END algorithm=brute, n_neighbors=30, p=1, weights=uniform;, score=0.434 total time=   1.7s
# [CV 4/5; 4/40] START algorithm=brute, n_neighbors=30, p=1, weights=uniform......
# [CV 4/5; 4/40] END algorithm=brute, n_neighbors=30, p=1, weights=uniform;, score=0.446 total time=   1.8s
# [CV 5/5; 4/40] START algorithm=brute, n_neighbors=30, p=1, weights=uniform......
# [CV 5/5; 4/40] END algorithm=brute, n_neighbors=30, p=1, weights=uniform;, score=0.431 total time=   2.3s
# [CV 1/5; 5/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform.......
# [CV 1/5; 5/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.770 total time=   0.8s
# [CV 2/5; 5/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform.......
# [CV 2/5; 5/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.782 total time=   0.7s
# [CV 3/5; 5/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform.......
# [CV 3/5; 5/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.782 total time=   0.6s
# [CV 4/5; 5/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform.......
# [CV 4/5; 5/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.776 total time=   0.6s
# [CV 5/5; 5/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform.......
# [CV 5/5; 5/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.770 total time=   0.6s
# [CV 1/5; 6/40] START algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform..
# [CV 1/5; 6/40] END algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform;, score=0.774 total time=   0.6s
# [CV 2/5; 6/40] START algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform..
# [CV 2/5; 6/40] END algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform;, score=0.785 total time=   0.6s
# [CV 3/5; 6/40] START algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform..
# [CV 3/5; 6/40] END algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform;, score=0.786 total time=   0.6s
# [CV 4/5; 6/40] START algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform..
# [CV 4/5; 6/40] END algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform;, score=0.770 total time=   0.6s
# [CV 5/5; 6/40] START algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform..
# [CV 5/5; 6/40] END algorithm=ball_tree, n_neighbors=19, p=2, weights=uniform;, score=0.776 total time=   0.6s
# [CV 1/5; 7/40] START algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform...
# [CV 1/5; 7/40] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform;, score=0.441 total time=   1.8s
# [CV 2/5; 7/40] START algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform...
# [CV 2/5; 7/40] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform;, score=0.439 total time=   1.8s
# [CV 3/5; 7/40] START algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform...
# [CV 3/5; 7/40] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform;, score=0.450 total time=   1.9s
# [CV 4/5; 7/40] START algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform...
# [CV 4/5; 7/40] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform;, score=0.488 total time=   1.8s
# [CV 5/5; 7/40] START algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform...
# [CV 5/5; 7/40] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform;, score=0.427 total time=   1.7s
# [CV 1/5; 8/40] START algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform..
# [CV 1/5; 8/40] END algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform;, score=0.781 total time=   0.6s
# [CV 2/5; 8/40] START algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform..
# [CV 2/5; 8/40] END algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform;, score=0.787 total time=   0.6s
# [CV 3/5; 8/40] START algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform..
# [CV 3/5; 8/40] END algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform;, score=0.799 total time=   0.6s
# [CV 4/5; 8/40] START algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform..
# [CV 4/5; 8/40] END algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform;, score=0.772 total time=   0.6s
# [CV 5/5; 8/40] START algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform..
# [CV 5/5; 8/40] END algorithm=ball_tree, n_neighbors=28, p=2, weights=uniform;, score=0.785 total time=   0.6s
# [CV 1/5; 9/40] START algorithm=auto, n_neighbors=5, p=2, weights=distance.......
# [CV 1/5; 9/40] END algorithm=auto, n_neighbors=5, p=2, weights=distance;, score=0.767 total time=   0.6s
# [CV 2/5; 9/40] START algorithm=auto, n_neighbors=5, p=2, weights=distance.......
# [CV 2/5; 9/40] END algorithm=auto, n_neighbors=5, p=2, weights=distance;, score=0.758 total time=   0.6s
# [CV 3/5; 9/40] START algorithm=auto, n_neighbors=5, p=2, weights=distance.......
# [CV 3/5; 9/40] END algorithm=auto, n_neighbors=5, p=2, weights=distance;, score=0.768 total time=   0.6s
# [CV 4/5; 9/40] START algorithm=auto, n_neighbors=5, p=2, weights=distance.......
# [CV 4/5; 9/40] END algorithm=auto, n_neighbors=5, p=2, weights=distance;, score=0.762 total time=   0.6s
# [CV 5/5; 9/40] START algorithm=auto, n_neighbors=5, p=2, weights=distance.......
# [CV 5/5; 9/40] END algorithm=auto, n_neighbors=5, p=2, weights=distance;, score=0.770 total time=   0.6s
# [CV 1/5; 10/40] START algorithm=auto, n_neighbors=17, p=1, weights=uniform......
# [CV 1/5; 10/40] END algorithm=auto, n_neighbors=17, p=1, weights=uniform;, score=0.443 total time=   1.7s
# [CV 2/5; 10/40] START algorithm=auto, n_neighbors=17, p=1, weights=uniform......
# [CV 2/5; 10/40] END algorithm=auto, n_neighbors=17, p=1, weights=uniform;, score=0.432 total time=   1.7s
# [CV 3/5; 10/40] START algorithm=auto, n_neighbors=17, p=1, weights=uniform......
# [CV 3/5; 10/40] END algorithm=auto, n_neighbors=17, p=1, weights=uniform;, score=0.434 total time=   1.8s
# [CV 4/5; 10/40] START algorithm=auto, n_neighbors=17, p=1, weights=uniform......
# [CV 4/5; 10/40] END algorithm=auto, n_neighbors=17, p=1, weights=uniform;, score=0.433 total time=   1.8s
# [CV 5/5; 10/40] START algorithm=auto, n_neighbors=17, p=1, weights=uniform......
# [CV 5/5; 10/40] END algorithm=auto, n_neighbors=17, p=1, weights=uniform;, score=0.432 total time=   1.7s
# [CV 1/5; 11/40] START algorithm=auto, n_neighbors=29, p=2, weights=uniform......
# [CV 1/5; 11/40] END algorithm=auto, n_neighbors=29, p=2, weights=uniform;, score=0.785 total time=   0.6s
# [CV 2/5; 11/40] START algorithm=auto, n_neighbors=29, p=2, weights=uniform......
# [CV 2/5; 11/40] END algorithm=auto, n_neighbors=29, p=2, weights=uniform;, score=0.786 total time=   0.6s
# [CV 3/5; 11/40] START algorithm=auto, n_neighbors=29, p=2, weights=uniform......
# [CV 3/5; 11/40] END algorithm=auto, n_neighbors=29, p=2, weights=uniform;, score=0.803 total time=   0.6s
# [CV 4/5; 11/40] START algorithm=auto, n_neighbors=29, p=2, weights=uniform......
# [CV 4/5; 11/40] END algorithm=auto, n_neighbors=29, p=2, weights=uniform;, score=0.772 total time=   0.6s
# [CV 5/5; 11/40] START algorithm=auto, n_neighbors=29, p=2, weights=uniform......
# [CV 5/5; 11/40] END algorithm=auto, n_neighbors=29, p=2, weights=uniform;, score=0.784 total time=   0.6s
# [CV 1/5; 12/40] START algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform.
# [CV 1/5; 12/40] END algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform;, score=0.778 total time=   0.6s
# [CV 2/5; 12/40] START algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform.
# [CV 2/5; 12/40] END algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform;, score=0.787 total time=   0.6s
# [CV 3/5; 12/40] START algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform.
# [CV 3/5; 12/40] END algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform;, score=0.803 total time=   0.6s
# [CV 4/5; 12/40] START algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform.
# [CV 4/5; 12/40] END algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform;, score=0.772 total time=   0.6s
# [CV 5/5; 12/40] START algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform.
# [CV 5/5; 12/40] END algorithm=ball_tree, n_neighbors=30, p=2, weights=uniform;, score=0.783 total time=   0.6s
# [CV 1/5; 13/40] START algorithm=kd_tree, n_neighbors=10, p=1, weights=distance..
# [CV 1/5; 13/40] END algorithm=kd_tree, n_neighbors=10, p=1, weights=distance;, score=0.443 total time=   1.1s
# [CV 2/5; 13/40] START algorithm=kd_tree, n_neighbors=10, p=1, weights=distance..
# [CV 2/5; 13/40] END algorithm=kd_tree, n_neighbors=10, p=1, weights=distance;, score=0.439 total time=   1.1s
# [CV 3/5; 13/40] START algorithm=kd_tree, n_neighbors=10, p=1, weights=distance..
# [CV 3/5; 13/40] END algorithm=kd_tree, n_neighbors=10, p=1, weights=distance;, score=0.446 total time=   1.1s
# [CV 4/5; 13/40] START algorithm=kd_tree, n_neighbors=10, p=1, weights=distance..
# [CV 4/5; 13/40] END algorithm=kd_tree, n_neighbors=10, p=1, weights=distance;, score=0.486 total time=   1.1s
# [CV 5/5; 13/40] START algorithm=kd_tree, n_neighbors=10, p=1, weights=distance..
# [CV 5/5; 13/40] END algorithm=kd_tree, n_neighbors=10, p=1, weights=distance;, score=0.436 total time=   1.1s
# [CV 1/5; 14/40] START algorithm=auto, n_neighbors=25, p=2, weights=distance.....
# [CV 1/5; 14/40] END algorithm=auto, n_neighbors=25, p=2, weights=distance;, score=0.795 total time=   0.6s
# [CV 2/5; 14/40] START algorithm=auto, n_neighbors=25, p=2, weights=distance.....
# [CV 2/5; 14/40] END algorithm=auto, n_neighbors=25, p=2, weights=distance;, score=0.793 total time=   0.6s
# [CV 3/5; 14/40] START algorithm=auto, n_neighbors=25, p=2, weights=distance.....
# [CV 3/5; 14/40] END algorithm=auto, n_neighbors=25, p=2, weights=distance;, score=0.803 total time=   0.6s
# [CV 4/5; 14/40] START algorithm=auto, n_neighbors=25, p=2, weights=distance.....
# [CV 4/5; 14/40] END algorithm=auto, n_neighbors=25, p=2, weights=distance;, score=0.780 total time=   0.6s
# [CV 5/5; 14/40] START algorithm=auto, n_neighbors=25, p=2, weights=distance.....
# [CV 5/5; 14/40] END algorithm=auto, n_neighbors=25, p=2, weights=distance;, score=0.787 total time=   0.6s
# [CV 1/5; 15/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform...
# [CV 1/5; 15/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform;, score=0.432 total time=   1.8s
# [CV 2/5; 15/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform...
# [CV 2/5; 15/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform;, score=0.435 total time=   1.8s
# [CV 3/5; 15/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform...
# [CV 3/5; 15/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform;, score=0.452 total time=   1.8s
# [CV 4/5; 15/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform...
# [CV 4/5; 15/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform;, score=0.497 total time=   1.9s
# [CV 5/5; 15/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform...
# [CV 5/5; 15/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=uniform;, score=0.433 total time=   1.7s
# [CV 1/5; 16/40] START algorithm=auto, n_neighbors=1, p=1, weights=uniform.......
# [CV 1/5; 16/40] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.457 total time=   1.8s
# [CV 2/5; 16/40] START algorithm=auto, n_neighbors=1, p=1, weights=uniform.......
# [CV 2/5; 16/40] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.447 total time=   1.8s
# [CV 3/5; 16/40] START algorithm=auto, n_neighbors=1, p=1, weights=uniform.......
# [CV 3/5; 16/40] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.452 total time=   1.8s
# [CV 4/5; 16/40] START algorithm=auto, n_neighbors=1, p=1, weights=uniform.......
# [CV 4/5; 16/40] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.518 total time=   1.8s
# [CV 5/5; 16/40] START algorithm=auto, n_neighbors=1, p=1, weights=uniform.......
# [CV 5/5; 16/40] END algorithm=auto, n_neighbors=1, p=1, weights=uniform;, score=0.448 total time=   1.7s
# [CV 1/5; 17/40] START algorithm=ball_tree, n_neighbors=16, p=1, weights=distance
# [CV 1/5; 17/40] END algorithm=ball_tree, n_neighbors=16, p=1, weights=distance;, score=0.449 total time=   1.1s
# [CV 2/5; 17/40] START algorithm=ball_tree, n_neighbors=16, p=1, weights=distance
# [CV 2/5; 17/40] END algorithm=ball_tree, n_neighbors=16, p=1, weights=distance;, score=0.435 total time=   1.1s
# [CV 3/5; 17/40] START algorithm=ball_tree, n_neighbors=16, p=1, weights=distance
# [CV 3/5; 17/40] END algorithm=ball_tree, n_neighbors=16, p=1, weights=distance;, score=0.439 total time=   1.4s
# [CV 4/5; 17/40] START algorithm=ball_tree, n_neighbors=16, p=1, weights=distance
# [CV 4/5; 17/40] END algorithm=ball_tree, n_neighbors=16, p=1, weights=distance;, score=0.440 total time=   1.3s
# [CV 5/5; 17/40] START algorithm=ball_tree, n_neighbors=16, p=1, weights=distance
# [CV 5/5; 17/40] END algorithm=ball_tree, n_neighbors=16, p=1, weights=distance;, score=0.434 total time=   1.2s
# [CV 1/5; 18/40] START algorithm=ball_tree, n_neighbors=11, p=2, weights=distance
# [CV 1/5; 18/40] END algorithm=ball_tree, n_neighbors=11, p=2, weights=distance;, score=0.784 total time=   0.7s
# [CV 2/5; 18/40] START algorithm=ball_tree, n_neighbors=11, p=2, weights=distance
# [CV 2/5; 18/40] END algorithm=ball_tree, n_neighbors=11, p=2, weights=distance;, score=0.792 total time=   0.6s
# [CV 3/5; 18/40] START algorithm=ball_tree, n_neighbors=11, p=2, weights=distance
# [CV 3/5; 18/40] END algorithm=ball_tree, n_neighbors=11, p=2, weights=distance;, score=0.789 total time=   0.6s
# [CV 4/5; 18/40] START algorithm=ball_tree, n_neighbors=11, p=2, weights=distance
# [CV 4/5; 18/40] END algorithm=ball_tree, n_neighbors=11, p=2, weights=distance;, score=0.761 total time=   0.6s
# [CV 5/5; 18/40] START algorithm=ball_tree, n_neighbors=11, p=2, weights=distance
# [CV 5/5; 18/40] END algorithm=ball_tree, n_neighbors=11, p=2, weights=distance;, score=0.776 total time=   0.6s
# [CV 1/5; 19/40] START algorithm=auto, n_neighbors=21, p=2, weights=distance.....
# [CV 1/5; 19/40] END algorithm=auto, n_neighbors=21, p=2, weights=distance;, score=0.782 total time=   0.6s
# [CV 2/5; 19/40] START algorithm=auto, n_neighbors=21, p=2, weights=distance.....
# [CV 2/5; 19/40] END algorithm=auto, n_neighbors=21, p=2, weights=distance;, score=0.789 total time=   0.6s
# [CV 3/5; 19/40] START algorithm=auto, n_neighbors=21, p=2, weights=distance.....
# [CV 3/5; 19/40] END algorithm=auto, n_neighbors=21, p=2, weights=distance;, score=0.792 total time=   0.6s
# [CV 4/5; 19/40] START algorithm=auto, n_neighbors=21, p=2, weights=distance.....
# [CV 4/5; 19/40] END algorithm=auto, n_neighbors=21, p=2, weights=distance;, score=0.778 total time=   0.6s
# [CV 5/5; 19/40] START algorithm=auto, n_neighbors=21, p=2, weights=distance.....
# [CV 5/5; 19/40] END algorithm=auto, n_neighbors=21, p=2, weights=distance;, score=0.787 total time=   0.6s
# [CV 1/5; 20/40] START algorithm=ball_tree, n_neighbors=5, p=2, weights=distance.
# [CV 1/5; 20/40] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance;, score=0.767 total time=   0.6s
# [CV 2/5; 20/40] START algorithm=ball_tree, n_neighbors=5, p=2, weights=distance.
# [CV 2/5; 20/40] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance;, score=0.758 total time=   0.6s
# [CV 3/5; 20/40] START algorithm=ball_tree, n_neighbors=5, p=2, weights=distance.
# [CV 3/5; 20/40] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance;, score=0.768 total time=   0.6s
# [CV 4/5; 20/40] START algorithm=ball_tree, n_neighbors=5, p=2, weights=distance.
# [CV 4/5; 20/40] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance;, score=0.762 total time=   0.6s
# [CV 5/5; 20/40] START algorithm=ball_tree, n_neighbors=5, p=2, weights=distance.
# [CV 5/5; 20/40] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance;, score=0.770 total time=   0.6s
# [CV 1/5; 21/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 1/5; 21/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.733 total time=   0.6s
# [CV 2/5; 21/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 2/5; 21/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.718 total time=   0.6s
# [CV 3/5; 21/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 3/5; 21/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.722 total time=   0.6s
# [CV 4/5; 21/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 4/5; 21/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.717 total time=   0.6s
# [CV 5/5; 21/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 5/5; 21/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.728 total time=   0.6s
# [CV 1/5; 22/40] START algorithm=kd_tree, n_neighbors=2, p=1, weights=distance...
# [CV 1/5; 22/40] END algorithm=kd_tree, n_neighbors=2, p=1, weights=distance;, score=0.457 total time=   1.1s
# [CV 2/5; 22/40] START algorithm=kd_tree, n_neighbors=2, p=1, weights=distance...
# [CV 2/5; 22/40] END algorithm=kd_tree, n_neighbors=2, p=1, weights=distance;, score=0.447 total time=   1.1s
# [CV 3/5; 22/40] START algorithm=kd_tree, n_neighbors=2, p=1, weights=distance...
# [CV 3/5; 22/40] END algorithm=kd_tree, n_neighbors=2, p=1, weights=distance;, score=0.452 total time=   1.1s
# [CV 4/5; 22/40] START algorithm=kd_tree, n_neighbors=2, p=1, weights=distance...
# [CV 4/5; 22/40] END algorithm=kd_tree, n_neighbors=2, p=1, weights=distance;, score=0.518 total time=   1.1s
# [CV 5/5; 22/40] START algorithm=kd_tree, n_neighbors=2, p=1, weights=distance...
# [CV 5/5; 22/40] END algorithm=kd_tree, n_neighbors=2, p=1, weights=distance;, score=0.448 total time=   1.1s
# [CV 1/5; 23/40] START algorithm=auto, n_neighbors=24, p=2, weights=uniform......
# [CV 1/5; 23/40] END algorithm=auto, n_neighbors=24, p=2, weights=uniform;, score=0.780 total time=   0.7s
# [CV 2/5; 23/40] START algorithm=auto, n_neighbors=24, p=2, weights=uniform......
# [CV 2/5; 23/40] END algorithm=auto, n_neighbors=24, p=2, weights=uniform;, score=0.792 total time=   0.6s
# [CV 3/5; 23/40] START algorithm=auto, n_neighbors=24, p=2, weights=uniform......
# [CV 3/5; 23/40] END algorithm=auto, n_neighbors=24, p=2, weights=uniform;, score=0.791 total time=   0.6s
# [CV 4/5; 23/40] START algorithm=auto, n_neighbors=24, p=2, weights=uniform......
# [CV 4/5; 23/40] END algorithm=auto, n_neighbors=24, p=2, weights=uniform;, score=0.771 total time=   0.6s
# [CV 5/5; 23/40] START algorithm=auto, n_neighbors=24, p=2, weights=uniform......
# [CV 5/5; 23/40] END algorithm=auto, n_neighbors=24, p=2, weights=uniform;, score=0.782 total time=   0.6s
# [CV 1/5; 24/40] START algorithm=brute, n_neighbors=29, p=1, weights=uniform.....
# [CV 1/5; 24/40] END algorithm=brute, n_neighbors=29, p=1, weights=uniform;, score=0.434 total time=   1.8s
# [CV 2/5; 24/40] START algorithm=brute, n_neighbors=29, p=1, weights=uniform.....
# [CV 2/5; 24/40] END algorithm=brute, n_neighbors=29, p=1, weights=uniform;, score=0.431 total time=   1.8s
# [CV 3/5; 24/40] START algorithm=brute, n_neighbors=29, p=1, weights=uniform.....
# [CV 3/5; 24/40] END algorithm=brute, n_neighbors=29, p=1, weights=uniform;, score=0.432 total time=   1.8s
# [CV 4/5; 24/40] START algorithm=brute, n_neighbors=29, p=1, weights=uniform.....
# [CV 4/5; 24/40] END algorithm=brute, n_neighbors=29, p=1, weights=uniform;, score=0.438 total time=   1.8s
# [CV 5/5; 24/40] START algorithm=brute, n_neighbors=29, p=1, weights=uniform.....
# [CV 5/5; 24/40] END algorithm=brute, n_neighbors=29, p=1, weights=uniform;, score=0.431 total time=   1.7s
# [CV 1/5; 25/40] START algorithm=kd_tree, n_neighbors=21, p=1, weights=distance..
# [CV 1/5; 25/40] END algorithm=kd_tree, n_neighbors=21, p=1, weights=distance;, score=0.437 total time=   1.1s
# [CV 2/5; 25/40] START algorithm=kd_tree, n_neighbors=21, p=1, weights=distance..
# [CV 2/5; 25/40] END algorithm=kd_tree, n_neighbors=21, p=1, weights=distance;, score=0.433 total time=   1.1s
# [CV 3/5; 25/40] START algorithm=kd_tree, n_neighbors=21, p=1, weights=distance..
# [CV 3/5; 25/40] END algorithm=kd_tree, n_neighbors=21, p=1, weights=distance;, score=0.436 total time=   1.1s
# [CV 4/5; 25/40] START algorithm=kd_tree, n_neighbors=21, p=1, weights=distance..
# [CV 4/5; 25/40] END algorithm=kd_tree, n_neighbors=21, p=1, weights=distance;, score=0.438 total time=   1.1s
# [CV 5/5; 25/40] START algorithm=kd_tree, n_neighbors=21, p=1, weights=distance..
# [CV 5/5; 25/40] END algorithm=kd_tree, n_neighbors=21, p=1, weights=distance;, score=0.433 total time=   1.1s
# [CV 1/5; 26/40] START algorithm=ball_tree, n_neighbors=12, p=1, weights=distance
# [CV 1/5; 26/40] END algorithm=ball_tree, n_neighbors=12, p=1, weights=distance;, score=0.437 total time=   1.1s
# [CV 2/5; 26/40] START algorithm=ball_tree, n_neighbors=12, p=1, weights=distance
# [CV 2/5; 26/40] END algorithm=ball_tree, n_neighbors=12, p=1, weights=distance;, score=0.435 total time=   1.1s
# [CV 3/5; 26/40] START algorithm=ball_tree, n_neighbors=12, p=1, weights=distance
# [CV 3/5; 26/40] END algorithm=ball_tree, n_neighbors=12, p=1, weights=distance;, score=0.446 total time=   1.2s
# [CV 4/5; 26/40] START algorithm=ball_tree, n_neighbors=12, p=1, weights=distance
# [CV 4/5; 26/40] END algorithm=ball_tree, n_neighbors=12, p=1, weights=distance;, score=0.455 total time=   1.1s
# [CV 5/5; 26/40] START algorithm=ball_tree, n_neighbors=12, p=1, weights=distance
# [CV 5/5; 26/40] END algorithm=ball_tree, n_neighbors=12, p=1, weights=distance;, score=0.435 total time=   1.2s
# [CV 1/5; 27/40] START algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform...
# [CV 1/5; 27/40] END algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform;, score=0.767 total time=   0.7s
# [CV 2/5; 27/40] START algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform...
# [CV 2/5; 27/40] END algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform;, score=0.791 total time=   0.6s
# [CV 3/5; 27/40] START algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform...
# [CV 3/5; 27/40] END algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform;, score=0.781 total time=   0.6s
# [CV 4/5; 27/40] START algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform...
# [CV 4/5; 27/40] END algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform;, score=0.776 total time=   0.6s
# [CV 5/5; 27/40] START algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform...
# [CV 5/5; 27/40] END algorithm=kd_tree, n_neighbors=20, p=2, weights=uniform;, score=0.779 total time=   0.6s
# [CV 1/5; 28/40] START algorithm=brute, n_neighbors=10, p=2, weights=uniform.....
# [CV 1/5; 28/40] END algorithm=brute, n_neighbors=10, p=2, weights=uniform;, score=0.770 total time=   0.6s
# [CV 2/5; 28/40] START algorithm=brute, n_neighbors=10, p=2, weights=uniform.....
# [CV 2/5; 28/40] END algorithm=brute, n_neighbors=10, p=2, weights=uniform;, score=0.773 total time=   0.6s
# [CV 3/5; 28/40] START algorithm=brute, n_neighbors=10, p=2, weights=uniform.....
# [CV 3/5; 28/40] END algorithm=brute, n_neighbors=10, p=2, weights=uniform;, score=0.766 total time=   0.6s
# [CV 4/5; 28/40] START algorithm=brute, n_neighbors=10, p=2, weights=uniform.....
# [CV 4/5; 28/40] END algorithm=brute, n_neighbors=10, p=2, weights=uniform;, score=0.752 total time=   0.6s
# [CV 5/5; 28/40] START algorithm=brute, n_neighbors=10, p=2, weights=uniform.....
# [CV 5/5; 28/40] END algorithm=brute, n_neighbors=10, p=2, weights=uniform;, score=0.756 total time=   0.6s
# [CV 1/5; 29/40] START algorithm=kd_tree, n_neighbors=19, p=1, weights=distance..
# [CV 1/5; 29/40] END algorithm=kd_tree, n_neighbors=19, p=1, weights=distance;, score=0.440 total time=   1.1s
# [CV 2/5; 29/40] START algorithm=kd_tree, n_neighbors=19, p=1, weights=distance..
# [CV 2/5; 29/40] END algorithm=kd_tree, n_neighbors=19, p=1, weights=distance;, score=0.435 total time=   1.1s
# [CV 3/5; 29/40] START algorithm=kd_tree, n_neighbors=19, p=1, weights=distance..
# [CV 3/5; 29/40] END algorithm=kd_tree, n_neighbors=19, p=1, weights=distance;, score=0.437 total time=   1.1s
# [CV 4/5; 29/40] START algorithm=kd_tree, n_neighbors=19, p=1, weights=distance..
# [CV 4/5; 29/40] END algorithm=kd_tree, n_neighbors=19, p=1, weights=distance;, score=0.437 total time=   1.1s
# [CV 5/5; 29/40] START algorithm=kd_tree, n_neighbors=19, p=1, weights=distance..
# [CV 5/5; 29/40] END algorithm=kd_tree, n_neighbors=19, p=1, weights=distance;, score=0.433 total time=   1.2s
# [CV 1/5; 30/40] START algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform.
# [CV 1/5; 30/40] END algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform;, score=0.438 total time=   1.9s
# [CV 2/5; 30/40] START algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform.
# [CV 2/5; 30/40] END algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform;, score=0.432 total time=   1.9s
# [CV 3/5; 30/40] START algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform.
# [CV 3/5; 30/40] END algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform;, score=0.434 total time=   1.9s
# [CV 4/5; 30/40] START algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform.
# [CV 4/5; 30/40] END algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform;, score=0.446 total time=   1.9s
# [CV 5/5; 30/40] START algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform.
# [CV 5/5; 30/40] END algorithm=ball_tree, n_neighbors=30, p=1, weights=uniform;, score=0.431 total time=   1.8s
# [CV 1/5; 31/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=distance..
# [CV 1/5; 31/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=distance;, score=0.437 total time=   1.1s
# [CV 2/5; 31/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=distance..
# [CV 2/5; 31/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=distance;, score=0.434 total time=   1.2s
# [CV 3/5; 31/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=distance..
# [CV 3/5; 31/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=distance;, score=0.437 total time=   1.2s
# [CV 4/5; 31/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=distance..
# [CV 4/5; 31/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=distance;, score=0.438 total time=   1.2s
# [CV 5/5; 31/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=distance..
# [CV 5/5; 31/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=distance;, score=0.433 total time=   1.2s
# [CV 1/5; 32/40] START algorithm=ball_tree, n_neighbors=6, p=2, weights=distance.
# [CV 1/5; 32/40] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance;, score=0.757 total time=   0.7s
# [CV 2/5; 32/40] START algorithm=ball_tree, n_neighbors=6, p=2, weights=distance.
# [CV 2/5; 32/40] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance;, score=0.770 total time=   0.6s
# [CV 3/5; 32/40] START algorithm=ball_tree, n_neighbors=6, p=2, weights=distance.
# [CV 3/5; 32/40] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance;, score=0.782 total time=   0.6s
# [CV 4/5; 32/40] START algorithm=ball_tree, n_neighbors=6, p=2, weights=distance.
# [CV 4/5; 32/40] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance;, score=0.766 total time=   0.6s
# [CV 5/5; 32/40] START algorithm=ball_tree, n_neighbors=6, p=2, weights=distance.
# [CV 5/5; 32/40] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance;, score=0.772 total time=   0.6s
# [CV 1/5; 33/40] START algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform...
# [CV 1/5; 33/40] END algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform;, score=0.783 total time=   0.6s
# [CV 2/5; 33/40] START algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform...
# [CV 2/5; 33/40] END algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform;, score=0.787 total time=   0.6s
# [CV 3/5; 33/40] START algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform...
# [CV 3/5; 33/40] END algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform;, score=0.800 total time=   0.6s
# [CV 4/5; 33/40] START algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform...
# [CV 4/5; 33/40] END algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform;, score=0.776 total time=   0.7s
# [CV 5/5; 33/40] START algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform...
# [CV 5/5; 33/40] END algorithm=kd_tree, n_neighbors=25, p=2, weights=uniform;, score=0.780 total time=   0.6s
# [CV 1/5; 34/40] START algorithm=brute, n_neighbors=17, p=2, weights=distance....
# [CV 1/5; 34/40] END algorithm=brute, n_neighbors=17, p=2, weights=distance;, score=0.788 total time=   0.7s
# [CV 2/5; 34/40] START algorithm=brute, n_neighbors=17, p=2, weights=distance....
# [CV 2/5; 34/40] END algorithm=brute, n_neighbors=17, p=2, weights=distance;, score=0.792 total time=   0.6s
# [CV 3/5; 34/40] START algorithm=brute, n_neighbors=17, p=2, weights=distance....
# [CV 3/5; 34/40] END algorithm=brute, n_neighbors=17, p=2, weights=distance;, score=0.790 total time=   0.6s
# [CV 4/5; 34/40] START algorithm=brute, n_neighbors=17, p=2, weights=distance....
# [CV 4/5; 34/40] END algorithm=brute, n_neighbors=17, p=2, weights=distance;, score=0.773 total time=   0.6s
# [CV 5/5; 34/40] START algorithm=brute, n_neighbors=17, p=2, weights=distance....
# [CV 5/5; 34/40] END algorithm=brute, n_neighbors=17, p=2, weights=distance;, score=0.784 total time=   0.6s
# [CV 1/5; 35/40] START algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform..
# [CV 1/5; 35/40] END algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform;, score=0.453 total time=   1.8s
# [CV 2/5; 35/40] START algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform..
# [CV 2/5; 35/40] END algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform;, score=0.439 total time=   1.8s
# [CV 3/5; 35/40] START algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform..
# [CV 3/5; 35/40] END algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform;, score=0.465 total time=   1.8s
# [CV 4/5; 35/40] START algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform..
# [CV 4/5; 35/40] END algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform;, score=0.457 total time=   1.9s
# [CV 5/5; 35/40] START algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform..
# [CV 5/5; 35/40] END algorithm=ball_tree, n_neighbors=8, p=1, weights=uniform;, score=0.425 total time=   1.8s
# [CV 1/5; 36/40] START algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform..
# [CV 1/5; 36/40] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform;, score=0.441 total time=   1.9s
# [CV 2/5; 36/40] START algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform..
# [CV 2/5; 36/40] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform;, score=0.436 total time=   1.8s
# [CV 3/5; 36/40] START algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform..
# [CV 3/5; 36/40] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform;, score=0.439 total time=   1.9s
# [CV 4/5; 36/40] START algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform..
# [CV 4/5; 36/40] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform;, score=0.462 total time=   1.9s
# [CV 5/5; 36/40] START algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform..
# [CV 5/5; 36/40] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform;, score=0.428 total time=   1.8s
# [CV 1/5; 37/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 1/5; 37/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.435 total time=   1.9s
# [CV 2/5; 37/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 2/5; 37/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.434 total time=   1.9s
# [CV 3/5; 37/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 3/5; 37/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.434 total time=   1.9s
# [CV 4/5; 37/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 4/5; 37/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.438 total time=   1.9s
# [CV 5/5; 37/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 5/5; 37/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.431 total time=   1.8s
# [CV 1/5; 38/40] START algorithm=auto, n_neighbors=11, p=1, weights=distance.....
# [CV 1/5; 38/40] END algorithm=auto, n_neighbors=11, p=1, weights=distance;, score=0.439 total time=   1.2s
# [CV 2/5; 38/40] START algorithm=auto, n_neighbors=11, p=1, weights=distance.....
# [CV 2/5; 38/40] END algorithm=auto, n_neighbors=11, p=1, weights=distance;, score=0.435 total time=   1.2s
# [CV 3/5; 38/40] START algorithm=auto, n_neighbors=11, p=1, weights=distance.....
# [CV 3/5; 38/40] END algorithm=auto, n_neighbors=11, p=1, weights=distance;, score=0.446 total time=   1.2s
# [CV 4/5; 38/40] START algorithm=auto, n_neighbors=11, p=1, weights=distance.....
# [CV 4/5; 38/40] END algorithm=auto, n_neighbors=11, p=1, weights=distance;, score=0.439 total time=   1.2s
# [CV 5/5; 38/40] START algorithm=auto, n_neighbors=11, p=1, weights=distance.....
# [CV 5/5; 38/40] END algorithm=auto, n_neighbors=11, p=1, weights=distance;, score=0.433 total time=   1.2s
# [CV 1/5; 39/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance..
# [CV 1/5; 39/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.438 total time=   1.2s
# [CV 2/5; 39/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance..
# [CV 2/5; 39/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.434 total time=   1.2s
# [CV 3/5; 39/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance..
# [CV 3/5; 39/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.438 total time=   1.2s
# [CV 4/5; 39/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance..
# [CV 4/5; 39/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.438 total time=   1.2s
# [CV 5/5; 39/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance..
# [CV 5/5; 39/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.433 total time=   1.2s
# [CV 1/5; 40/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform..
# [CV 1/5; 40/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform;, score=0.440 total time=   2.0s
# [CV 2/5; 40/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform..
# [CV 2/5; 40/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform;, score=0.442 total time=   1.9s
# [CV 3/5; 40/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform..
# [CV 3/5; 40/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform;, score=0.437 total time=   1.9s
# [CV 4/5; 40/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform..
# [CV 4/5; 40/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform;, score=0.458 total time=   1.9s
# [CV 5/5; 40/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform..
# [CV 5/5; 40/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=uniform;, score=0.428 total time=   1.8s

# %%
# Display the best parameters and F1 score
print("Best parameters:", best_params_knn)
print("Best F1 Score:", best_score_knn)
# Out:
# Best parameters: {'weights': 'distance', 'p': 2, 'n_neighbors': 25, 'algorithm': 'auto'}
# Best F1 Score: 0.7916954900472147

# %% [raw]
# Best parameters: {'weights': 'distance', 'p': 2, 'n_neighbors': 25, 'algorithm': 'auto'}
# Best F1 Score: 0.7916954900472147

# %% [markdown]
# ### MLP - sklearn  (using TF-IDF)

# %%
models = [
    ('MLP', MLPClassifier(random_state=42))
]
  
hyperparameters = [
    {
        'MLP__hidden_layer_sizes': [(10,), (20,), (30,), (40,)],
        'MLP__activation': ['tanh', 'relu'],
        'MLP__solver': ['sgd', 'adam'],
        'MLP__learning_rate': ['constant', 'invscaling', 'adaptive'],
        'MLP__alpha': np.logspace(-4, 4, 100),
        'MLP__learning_rate_init': [0.001,0.01],
        'MLP__max_iter': np.arange(100, 300),
        'MLP__batch_size': np.arange(50, 150)
    }
]

stratified_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

results = []
cv_results_dfs = []

for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([model])
    
    rs = RandomizedSearchCV(pipeline, params, cv=stratified_kfold, n_iter=20, scoring='f1', verbose=10)
    rs.fit(X_combined_tfidf, y)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

test_scores_mlp_tfidf = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_mlp_tfidf = test_scores_mlp_tfidf.sort_values('best_score', ascending=False)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV 1/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 1/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.741 total time= 3.7min
# [CV 2/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 2/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.747 total time= 1.6min
# [CV 3/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 3/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.745 total time= 1.4min
# [CV 4/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 4/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.771 total time= 3.8min
# [CV 5/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 5/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.794 total time= 1.6min
# [CV 6/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 6/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.734 total time= 1.9min
# [CV 7/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 7/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.803 total time= 1.5min
# [CV 8/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 8/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.735 total time= 2.5min
# [CV 9/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 9/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.738 total time= 2.4min
# [CV 10/10; 1/20] START MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam
# [CV 10/10; 1/20] END MLP__activation=tanh, MLP__alpha=0.0003678379771828634, MLP__batch_size=70, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=192, MLP__solver=adam;, score=0.762 total time= 3.2min
# [CV 1/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 1/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.767 total time= 4.5min
# [CV 2/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 2/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.776 total time= 4.6min
# [CV 3/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 3/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.765 total time= 4.6min
# [CV 4/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 4/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.803 total time= 4.5min
# [CV 5/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 5/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.811 total time= 4.6min
# [CV 6/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 6/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.735 total time= 4.6min
# [CV 7/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 7/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.808 total time= 4.6min
# [CV 8/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 8/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.739 total time= 4.6min
# [CV 9/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 9/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.769 total time= 4.6min
# [CV 10/10; 2/20] START MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd
# [CV 10/10; 2/20] END MLP__activation=relu, MLP__alpha=0.005994842503189409, MLP__batch_size=123, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=252, MLP__solver=sgd;, score=0.777 total time= 4.6min
# [CV 1/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 1/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.772 total time= 2.9min
# [CV 2/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 2/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.762 total time= 1.4min
# [CV 3/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 3/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.736 total time= 2.0min
# [CV 4/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 4/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.803 total time= 2.1min
# [CV 5/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 5/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.836 total time= 2.4min
# [CV 6/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 6/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.772 total time= 2.3min
# [CV 7/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 7/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.777 total time= 1.8min
# [CV 8/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 8/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.737 total time= 2.7min
# [CV 9/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 9/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.763 total time= 2.9min
# [CV 10/10; 3/20] START MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam
# [CV 10/10; 3/20] END MLP__activation=relu, MLP__alpha=0.09770099572992257, MLP__batch_size=149, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=199, MLP__solver=adam;, score=0.782 total time= 2.3min
# [CV 1/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 1/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.8s
# [CV 2/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 2/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.0s
# [CV 3/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 3/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  19.6s
# [CV 4/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 4/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  17.6s
# [CV 5/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 5/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.2s
# [CV 6/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 6/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.9s
# [CV 7/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 7/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  19.1s
# [CV 8/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 8/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  17.7s
# [CV 9/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 9/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.6s
# [CV 10/10; 4/20] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd
# [CV 10/10; 4/20] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=97, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=180, MLP__solver=sgd;, score=0.000 total time=  18.0s
# [CV 1/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 1/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  51.7s
# [CV 2/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 2/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  52.5s
# [CV 3/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 3/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  52.5s
# [CV 4/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 4/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  50.7s
# [CV 5/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 5/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  52.3s
# [CV 6/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 6/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  53.9s
# [CV 7/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 7/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  51.0s
# [CV 8/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 8/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  51.3s
# [CV 9/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 9/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  53.7s
# [CV 10/10; 5/20] START MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd
# [CV 10/10; 5/20] END MLP__activation=tanh, MLP__alpha=31.257158496882415, MLP__batch_size=109, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=120, MLP__solver=sgd;, score=0.000 total time=  52.8s
# [CV 1/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 1/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.757 total time= 2.2min
# [CV 2/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 2/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.776 total time= 2.2min
# [CV 3/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 3/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.772 total time= 2.1min
# [CV 4/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 4/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.806 total time= 2.1min
# [CV 5/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 5/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.812 total time= 2.2min
# [CV 6/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 6/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.750 total time= 2.2min
# [CV 7/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 7/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.812 total time= 2.1min
# [CV 8/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 8/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.730 total time= 2.1min
# [CV 9/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 9/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.772 total time= 2.1min
# [CV 10/10; 6/20] START MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd
# [CV 10/10; 6/20] END MLP__activation=tanh, MLP__alpha=0.03199267137797385, MLP__batch_size=118, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=227, MLP__solver=sgd;, score=0.783 total time= 2.1min
# [CV 1/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 1/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  38.8s
# [CV 2/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 2/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.9s
# [CV 3/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 3/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  38.9s
# [CV 4/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 4/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.9s
# [CV 5/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 5/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.0s
# [CV 6/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 6/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  42.1s
# [CV 7/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 7/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.3s
# [CV 8/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 8/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  42.2s
# [CV 9/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 9/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.2s
# [CV 10/10; 7/20] START MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd
# [CV 10/10; 7/20] END MLP__activation=relu, MLP__alpha=351.11917342151344, MLP__batch_size=67, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=286, MLP__solver=sgd;, score=0.000 total time=  39.4s
# [CV 1/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 1/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.790 total time= 3.1min
# [CV 2/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 2/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.788 total time= 3.1min
# [CV 3/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 3/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.760 total time= 3.1min
# [CV 4/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 4/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.803 total time= 3.2min
# [CV 5/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 5/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.816 total time= 3.1min
# [CV 6/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 6/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.785 total time= 3.2min
# [CV 7/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 7/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.809 total time= 3.2min
# [CV 8/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 8/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.727 total time= 3.1min
# [CV 9/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 9/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.787 total time= 3.2min
# [CV 10/10; 8/20] START MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd
# [CV 10/10; 8/20] END MLP__activation=tanh, MLP__alpha=1.0974987654930568, MLP__batch_size=67, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=200, MLP__solver=sgd;, score=0.790 total time= 3.2min
# [CV 1/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 1/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 5.3min
# [CV 2/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 2/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 5.2min
# [CV 3/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 3/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.9min
# [CV 4/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 4/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time=21.8min
# [CV 5/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 5/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time=21.0min
# [CV 6/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 6/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.2min
# [CV 7/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 7/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.3min
# [CV 8/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 8/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.2min
# [CV 9/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 9/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.3min
# [CV 10/10; 9/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd
# [CV 10/10; 9/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=124, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=190, MLP__solver=sgd;, score=0.000 total time= 4.3min
# [CV 1/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 1/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.5s
# [CV 2/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 2/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  19.3s
# [CV 3/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 3/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.4s
# [CV 4/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 4/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  19.3s
# [CV 5/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 5/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.3s
# [CV 6/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 6/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  19.1s
# [CV 7/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 7/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.2s
# [CV 8/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 8/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.9s
# [CV 9/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 9/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.1s
# [CV 10/10; 10/20] START MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd
# [CV 10/10; 10/20] END MLP__activation=tanh, MLP__alpha=17.886495290574352, MLP__batch_size=139, MLP__hidden_layer_sizes=(20,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=138, MLP__solver=sgd;, score=0.000 total time=  18.2s
# [CV 1/10; 11/20] START MLP__activation=relu, MLP__alpha=0.026560877829466867, MLP__batch_size=110, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=126, MLP__solver=sgd
# ...
# [CV 8/10; 17/20] START MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam
# [CV 8/10; 17/20] END MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam;, score=0.000 total time=  44.5s
# [CV 9/10; 17/20] START MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam
# [CV 9/10; 17/20] END MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam;, score=0.000 total time=  43.2s
# [CV 10/10; 17/20] START MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam
# [CV 10/10; 17/20] END MLP__activation=tanh, MLP__alpha=10.235310218990268, MLP__batch_size=90, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=103, MLP__solver=adam;, score=0.000 total time=  42.9s
# [CV 1/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 1/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 1.9min
# [CV 2/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 2/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 1.9min
# [CV 3/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 3/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 4/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 4/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 1.9min
# [CV 5/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 5/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 6/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 6/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 7/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 7/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 8/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 8/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 9/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 9/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 10/10; 18/20] START MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd
# [CV 10/10; 18/20] END MLP__activation=tanh, MLP__alpha=0.002364489412645407, MLP__batch_size=61, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=209, MLP__solver=sgd;, score=0.000 total time= 2.0min
# [CV 1/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 1/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.765 total time= 7.4min
# [CV 2/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 2/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.780 total time=14.4min
# [CV 3/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 3/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.762 total time= 7.5min
# [CV 4/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 4/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.800 total time= 7.5min
# [CV 5/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 5/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.816 total time= 7.7min
# [CV 6/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 6/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.755 total time= 7.5min
# [CV 7/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 7/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.811 total time= 7.4min
# [CV 8/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 8/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.739 total time= 7.4min
# [CV 9/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 9/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.773 total time= 7.6min
# [CV 10/10; 19/20] START MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd
# [CV 10/10; 19/20] END MLP__activation=tanh, MLP__alpha=0.004977023564332114, MLP__batch_size=126, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=sgd;, score=0.777 total time= 7.4min
# [CV 1/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 1/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.785 total time= 4.8min
# [CV 2/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 2/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.786 total time= 4.9min
# [CV 3/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 3/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.767 total time= 4.9min
# [CV 4/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 4/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.820 total time= 5.0min
# [CV 5/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 5/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.834 total time= 5.0min
# [CV 6/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 6/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.808 total time= 5.0min
# [CV 7/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 7/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.812 total time= 5.0min
# [CV 8/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 8/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.739 total time= 5.0min
# [CV 9/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 9/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.792 total time= 4.9min
# [CV 10/10; 20/20] START MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd
# [CV 10/10; 20/20] END MLP__activation=tanh, MLP__alpha=0.3593813663804629, MLP__batch_size=143, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=250, MLP__solver=sgd;, score=0.807 total time= 5.0min

# %%
test_scores_mlp_tfidf
# Out:
#    best_score                                        best_params
# 0    0.795028  {'MLP__solver': 'sgd', 'MLP__max_iter': 250, '...

# %%
print(test_scores_mlp_tfidf['best_params'][0])
print(test_scores_mlp_tfidf['best_score'][0])
# Out:
# {'MLP__solver': 'sgd', 'MLP__max_iter': 250, 'MLP__learning_rate_init': 0.01, 'MLP__learning_rate': 'adaptive', 'MLP__hidden_layer_sizes': (30,), 'MLP__batch_size': 143, 'MLP__alpha': 0.3593813663804629, 'MLP__activation': 'tanh'}
# 0.7950284542076699

# %% [raw]
# {'MLP__solver': 'sgd', 'MLP__max_iter': 250, 'MLP__learning_rate_init': 0.01, 'MLP__learning_rate': 'adaptive', 'MLP__hidden_layer_sizes': (30,), 'MLP__batch_size': 143, 'MLP__alpha': 0.3593813663804629, 'MLP__activation': 'tanh'}
# 0.7950284542076699

# %% [markdown]
# ### XGBoost  (using  TF-IDF)

# %%
models = [
    ('XGBoost', XGBClassifier(random_state=19, objective='binary:logistic', eval_metric='logloss'))
]

hyperparameters = [
    {
        'XGBoost__n_estimators': [300, 350, 400],
        'XGBoost__max_depth': [15, 20, 25],
        'XGBoost__subsample': [1.0],
        'XGBoost__min_child_weight': [1, 5, 10],
        'XGBoost__learning_rate': [0.01, 0.1, 1.0]
    }
]

stratified_kfold = StratifiedKFold(n_splits=4, shuffle=True, random_state=19)

results = []
cv_results_dfs = []

for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([model])
    
    rs = RandomizedSearchCV(pipeline, params, n_iter= 30, cv=stratified_kfold, scoring='f1', verbose=10)
    rs.fit(X_combined_tfidf, y)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

test_scores_xgb = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_xgb = test_scores_xgb.sort_values('best_score', ascending=False)
# Out:
# Fitting 4 folds for each of 30 candidates, totalling 120 fits
# [CV 1/4; 1/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 1/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.792 total time= 5.6min
# [CV 2/4; 1/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 1/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.777 total time= 5.7min
# [CV 3/4; 1/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 1/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.796 total time= 5.8min
# [CV 4/4; 1/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 1/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.790 total time= 6.1min
# [CV 1/4; 2/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 2/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.783 total time= 2.4min
# [CV 2/4; 2/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 2/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.777 total time= 2.9min
# [CV 3/4; 2/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 2/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.792 total time= 3.0min
# [CV 4/4; 2/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 2/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.782 total time= 2.5min
# [CV 1/4; 3/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 3/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.791 total time= 8.7min
# [CV 2/4; 3/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 3/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.778 total time= 9.2min
# [CV 3/4; 3/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 3/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.800 total time= 9.4min
# [CV 4/4; 3/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 3/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.777 total time=10.8min
# [CV 1/4; 4/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 4/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.787 total time= 3.3min
# [CV 2/4; 4/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 4/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.779 total time= 2.9min
# [CV 3/4; 4/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 4/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.783 total time= 3.1min
# [CV 4/4; 4/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 4/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.769 total time= 3.0min
# [CV 1/4; 5/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 5/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.739 total time=  32.2s
# [CV 2/4; 5/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 5/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.734 total time=  32.5s
# [CV 3/4; 5/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 5/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.740 total time=  33.2s
# [CV 4/4; 5/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 5/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.721 total time=  34.2s
# [CV 1/4; 6/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 6/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.760 total time= 1.7min
# [CV 2/4; 6/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 6/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.757 total time= 1.8min
# [CV 3/4; 6/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 6/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.765 total time= 1.6min
# [CV 4/4; 6/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 6/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.764 total time= 1.6min
# [CV 1/4; 7/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 7/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.771 total time= 1.6min
# [CV 2/4; 7/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 7/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.747 total time= 1.5min
# [CV 3/4; 7/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 7/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.769 total time= 1.6min
# [CV 4/4; 7/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 7/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.760 total time= 1.5min
# [CV 1/4; 8/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 8/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.737 total time=  38.4s
# [CV 2/4; 8/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 8/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.740 total time=  39.8s
# [CV 3/4; 8/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 8/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.729 total time=  40.3s
# [CV 4/4; 8/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 8/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.727 total time=  39.4s
# [CV 1/4; 9/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 9/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.766 total time=  55.2s
# [CV 2/4; 9/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 9/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.776 total time=  53.5s
# [CV 3/4; 9/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 9/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.757 total time=  54.0s
# [CV 4/4; 9/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 9/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.748 total time=  54.7s
# [CV 1/4; 10/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 10/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.760 total time= 1.1min
# [CV 2/4; 10/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 10/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.755 total time= 1.1min
# [CV 3/4; 10/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 10/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.766 total time= 1.1min
# [CV 4/4; 10/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 10/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.746 total time= 1.3min
# [CV 1/4; 11/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 11/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.781 total time= 3.4min
# [CV 2/4; 11/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 11/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.774 total time= 3.4min
# [CV 3/4; 11/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 11/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.775 total time= 3.3min
# [CV 4/4; 11/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 11/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.763 total time= 3.1min
# [CV 1/4; 12/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 12/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.793 total time= 5.2min
# [CV 2/4; 12/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 12/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.781 total time= 5.5min
# [CV 3/4; 12/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 12/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.795 total time= 5.4min
# [CV 4/4; 12/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 12/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.786 total time= 5.5min
# [CV 1/4; 13/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 13/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.753 total time=  43.2s
# [CV 2/4; 13/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 13/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.749 total time=  46.5s
# [CV 3/4; 13/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 13/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.725 total time=  44.9s
# [CV 4/4; 13/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 13/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.715 total time=  44.5s
# [CV 1/4; 14/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 14/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.763 total time=  52.5s
# [CV 2/4; 14/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 14/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.775 total time=  47.9s
# [CV 3/4; 14/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 14/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.757 total time=  51.7s
# [CV 4/4; 14/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 14/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.746 total time=  50.0s
# [CV 1/4; 15/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 15/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.735 total time=  33.0s
# [CV 2/4; 15/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 15/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.740 total time=  34.2s
# [CV 3/4; 15/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 15/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.730 total time=  34.7s
# [CV 4/4; 15/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 15/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.723 total time=  33.4s
# [CV 1/4; 16/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 16/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.803 total time= 9.8min
# [CV 2/4; 16/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 16/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.785 total time=10.6min
# [CV 3/4; 16/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 16/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.801 total time= 9.5min
# [CV 4/4; 16/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 16/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.770 total time= 9.5min
# [CV 1/4; 17/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 17/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.720 total time=  36.7s
# [CV 2/4; 17/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 17/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.729 total time=  37.7s
# [CV 3/4; 17/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 17/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.737 total time=  38.0s
# [CV 4/4; 17/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 17/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.714 total time=  36.5s
# [CV 1/4; 18/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 18/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.771 total time= 1.8min
# [CV 2/4; 18/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 18/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.749 total time= 1.7min
# [CV 3/4; 18/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 18/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.765 total time= 1.6min
# [CV 4/4; 18/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 18/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.759 total time= 1.7min
# [CV 1/4; 19/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 19/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.792 total time= 3.9min
# [CV 2/4; 19/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 19/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.788 total time= 4.6min
# [CV 3/4; 19/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 19/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.799 total time= 4.5min
# [CV 4/4; 19/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 19/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.789 total time= 4.6min
# [CV 1/4; 20/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 20/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.738 total time=  44.0s
# [CV 2/4; 20/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 20/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.739 total time=  50.6s
# [CV 3/4; 20/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 20/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.755 total time=  47.8s
# [CV 4/4; 20/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 20/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.718 total time=  47.2s
# [CV 1/4; 21/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 21/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.721 total time=  38.1s
# [CV 2/4; 21/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 21/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.734 total time=  35.7s
# [CV 3/4; 21/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 21/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.740 total time=  38.5s
# [CV 4/4; 21/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 21/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.717 total time=  35.9s
# [CV 1/4; 22/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 22/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.758 total time= 1.9min
# [CV 2/4; 22/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 22/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.757 total time= 1.7min
# [CV 3/4; 22/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 22/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.766 total time= 1.7min
# [CV 4/4; 22/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 22/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.762 total time= 1.7min
# [CV 1/4; 23/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 23/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.787 total time= 3.2min
# [CV 2/4; 23/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 23/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.774 total time= 3.0min
# [CV 3/4; 23/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 23/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.777 total time= 2.8min
# [CV 4/4; 23/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 23/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.760 total time= 2.8min
# [CV 1/4; 24/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 1/4; 24/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.742 total time=  28.2s
# [CV 2/4; 24/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 2/4; 24/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.732 total time=  28.7s
# [CV 3/4; 24/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 3/4; 24/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.740 total time=  29.2s
# [CV 4/4; 24/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0
# [CV 4/4; 24/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=300, XGBoost__subsample=1.0;, score=0.722 total time=  29.5s
# [CV 1/4; 25/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 25/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.759 total time= 1.2min
# [CV 2/4; 25/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 25/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.758 total time= 1.3min
# [CV 3/4; 25/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 25/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.763 total time= 1.3min
# [CV 4/4; 25/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 25/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.747 total time= 1.3min
# [CV 1/4; 26/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 26/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.783 total time= 3.2min
# [CV 2/4; 26/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 26/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.772 total time= 3.4min
# [CV 3/4; 26/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 26/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.777 total time= 3.2min
# [CV 4/4; 26/30] START XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 26/30] END XGBoost__learning_rate=0.1, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.763 total time= 3.4min
# [CV 1/4; 27/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 1/4; 27/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.794 total time=12.2min
# [CV 2/4; 27/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 2/4; 27/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.771 total time=13.9min
# [CV 3/4; 27/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 3/4; 27/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.808 total time=12.7min
# [CV 4/4; 27/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0
# [CV 4/4; 27/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=1, XGBoost__n_estimators=400, XGBoost__subsample=1.0;, score=0.766 total time=12.5min
# [CV 1/4; 28/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 28/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.749 total time=  35.7s
# [CV 2/4; 28/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 28/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.753 total time=  36.0s
# [CV 3/4; 28/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 28/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.732 total time=  37.0s
# [CV 4/4; 28/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 28/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.718 total time=  36.8s
# [CV 1/4; 29/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 29/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.739 total time=  39.3s
# [CV 2/4; 29/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 29/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.747 total time=  40.7s
# [CV 3/4; 29/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 29/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.750 total time=  40.3s
# [CV 4/4; 29/30] START XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 29/30] END XGBoost__learning_rate=1.0, XGBoost__max_depth=25, XGBoost__min_child_weight=5, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.714 total time=  39.4s
# [CV 1/4; 30/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 1/4; 30/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.780 total time= 2.3min
# [CV 2/4; 30/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 2/4; 30/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.779 total time= 2.5min
# [CV 3/4; 30/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 3/4; 30/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.793 total time= 2.2min
# [CV 4/4; 30/30] START XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0
# [CV 4/4; 30/30] END XGBoost__learning_rate=0.01, XGBoost__max_depth=25, XGBoost__min_child_weight=10, XGBoost__n_estimators=350, XGBoost__subsample=1.0;, score=0.784 total time= 2.1min

# %%
test_scores_xgb
# Out:
#    best_score                                        best_params
# 0    0.791821  {'XGBoost__subsample': 1.0, 'XGBoost__n_estima...

# %%
print(test_scores_xgb['best_params'][0])
print(test_scores_xgb['best_score'][0])
# Out:
# {'XGBoost__subsample': 1.0, 'XGBoost__n_estimators': 350, 'XGBoost__min_child_weight': 5, 'XGBoost__max_depth': 15, 'XGBoost__learning_rate': 0.01}
# 0.7918206175863243

# %% [raw]
# {'XGBoost__subsample': 1.0, 'XGBoost__n_estimators': 350, 'XGBoost__min_child_weight': 5, 'XGBoost__max_depth': 15, 'XGBoost__learning_rate': 0.01}
# 0.7918206175863243

# %% [markdown]
# ## Model testing with LaBSE embedings

# %% [markdown]
# ### Logistic Regression - sklearn  (using labse embeddings)

# %% [markdown]
# This approach involves performing hyperparameter tuning using a randomized search with cross-validation for three different logistic regression models. Each logistic regression model has different hyperparameters defined in the hyperparameters list. Here's an explanation of each part:
#
# **Models:** Three logistic regression models are defined with different settings for the solver parameter. This allows you to explore how different solvers perform with different hyperparameters.
#
# **Hyperparameters:** For each logistic regression model, a dictionary of hyperparameters is defined. These hyperparameters will be tuned during the randomized search. Each dictionary contains different combinations of hyperparameters to explore.
#
# **Cross-validation:** Stratified k-fold cross-validation is used to evaluate the performance of each model and hyperparameter combination. It ensures that each fold preserves the percentage of samples for each class. as we are using on all the project
#
# **Randomized Search:** For each model, a RandomizedSearchCV object is created. It performs a randomized search over the hyperparameter space defined in the corresponding hyperparameters dictionary. The scoring parameter is set to 'f1', indicating that the F1 score will be used as the evaluation metric.
#
# **Results:** After the randomized search is complete for each model, the best score and best parameters are recorded in a DataFrame named test_scores_lg. This DataFrame contains the performance of each model along with the corresponding best hyperparameters.

# %%
models = [
    LogisticRegression(class_weight='balanced', random_state=42, solver='saga'),
    LogisticRegression(class_weight='balanced', random_state=42, solver='liblinear'),
    LogisticRegression(class_weight='balanced', random_state=42, solver='saga')
]


hyperparameters = [
    {
        'model__penalty': ['l2'],
        'model__C': np.logspace(-2, 2, 50) 
    },
    {
        'model__penalty': ['l1', 'l2'],
        'model__C': np.logspace(-2, 2, 50)  
    },
    {
        'model__penalty': ['l1','elasticnet'],
        'model__C': np.logspace(-2, 2, 50),  
        'model__l1_ratio': [0.1, 0.5, 0.9]  
    }
]

# Initialize cross-validation
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=19)

results = []
cv_results_dfs = []

# Loop through each model and its hyperparameters
for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([('model', model)])

    # Perform random search
    rs = RandomizedSearchCV(pipeline, params, cv=stratified_kfold, n_iter=10, scoring='f1', verbose=10)
    rs.fit(combined_embeddings_labse, y_array)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

# Create DataFrame with results
test_scores_lg1 = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_lg1 = test_scores_lg1.sort_values('best_score', ascending=False)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 1/5; 1/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.781 total time=   1.0s
# [CV 2/5; 1/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 2/5; 1/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.780 total time=   0.9s
# [CV 3/5; 1/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 3/5; 1/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.785 total time=   0.9s
# [CV 4/5; 1/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 4/5; 1/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.787 total time=   0.9s
# [CV 5/5; 1/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 5/5; 1/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.773 total time=   1.0s
# [CV 1/5; 2/10] START model__C=32.374575428176435, model__penalty=l2.............
# [CV 1/5; 2/10] END model__C=32.374575428176435, model__penalty=l2;, score=0.749 total time=   4.1s
# [CV 2/5; 2/10] START model__C=32.374575428176435, model__penalty=l2.............
# [CV 2/5; 2/10] END model__C=32.374575428176435, model__penalty=l2;, score=0.747 total time=   4.1s
# [CV 3/5; 2/10] START model__C=32.374575428176435, model__penalty=l2.............
# [CV 3/5; 2/10] END model__C=32.374575428176435, model__penalty=l2;, score=0.752 total time=   4.2s
# [CV 4/5; 2/10] START model__C=32.374575428176435, model__penalty=l2.............
# [CV 4/5; 2/10] END model__C=32.374575428176435, model__penalty=l2;, score=0.796 total time=   4.1s
# [CV 5/5; 2/10] START model__C=32.374575428176435, model__penalty=l2.............
# [CV 5/5; 2/10] END model__C=32.374575428176435, model__penalty=l2;, score=0.769 total time=   4.1s
# [CV 1/5; 3/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 1/5; 3/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.785 total time=   1.0s
# [CV 2/5; 3/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 2/5; 3/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.780 total time=   1.0s
# [CV 3/5; 3/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 3/5; 3/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.788 total time=   0.9s
# [CV 4/5; 3/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 4/5; 3/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.792 total time=   0.9s
# [CV 5/5; 3/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 5/5; 3/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.775 total time=   1.0s
# [CV 1/5; 4/10] START model__C=0.04498432668969444, model__penalty=l2............
# [CV 1/5; 4/10] END model__C=0.04498432668969444, model__penalty=l2;, score=0.778 total time=   1.0s
# [CV 2/5; 4/10] START model__C=0.04498432668969444, model__penalty=l2............
# [CV 2/5; 4/10] END model__C=0.04498432668969444, model__penalty=l2;, score=0.779 total time=   0.8s
# [CV 3/5; 4/10] START model__C=0.04498432668969444, model__penalty=l2............
# [CV 3/5; 4/10] END model__C=0.04498432668969444, model__penalty=l2;, score=0.784 total time=   0.9s
# [CV 4/5; 4/10] START model__C=0.04498432668969444, model__penalty=l2............
# [CV 4/5; 4/10] END model__C=0.04498432668969444, model__penalty=l2;, score=0.784 total time=   1.0s
# [CV 5/5; 4/10] START model__C=0.04498432668969444, model__penalty=l2............
# [CV 5/5; 4/10] END model__C=0.04498432668969444, model__penalty=l2;, score=0.766 total time=   0.9s
# [CV 1/5; 5/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 1/5; 5/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.739 total time=   4.2s
# [CV 2/5; 5/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 2/5; 5/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.731 total time=   4.1s
# [CV 3/5; 5/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 3/5; 5/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.740 total time=   4.1s
# [CV 4/5; 5/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 4/5; 5/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.789 total time=   4.1s
# [CV 5/5; 5/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 5/5; 5/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.759 total time=   4.2s
# [CV 1/5; 6/10] START model__C=0.014563484775012436, model__penalty=l2...........
# [CV 1/5; 6/10] END model__C=0.014563484775012436, model__penalty=l2;, score=0.778 total time=   0.9s
# [CV 2/5; 6/10] START model__C=0.014563484775012436, model__penalty=l2...........
# [CV 2/5; 6/10] END model__C=0.014563484775012436, model__penalty=l2;, score=0.779 total time=   0.8s
# [CV 3/5; 6/10] START model__C=0.014563484775012436, model__penalty=l2...........
# [CV 3/5; 6/10] END model__C=0.014563484775012436, model__penalty=l2;, score=0.784 total time=   0.8s
# [CV 4/5; 6/10] START model__C=0.014563484775012436, model__penalty=l2...........
# [CV 4/5; 6/10] END model__C=0.014563484775012436, model__penalty=l2;, score=0.784 total time=   0.8s
# [CV 5/5; 6/10] START model__C=0.014563484775012436, model__penalty=l2...........
# [CV 5/5; 6/10] END model__C=0.014563484775012436, model__penalty=l2;, score=0.766 total time=   0.9s
# [CV 1/5; 7/10] START model__C=26.826957952797247, model__penalty=l2.............
# [CV 1/5; 7/10] END model__C=26.826957952797247, model__penalty=l2;, score=0.749 total time=   4.1s
# [CV 2/5; 7/10] START model__C=26.826957952797247, model__penalty=l2.............
# [CV 2/5; 7/10] END model__C=26.826957952797247, model__penalty=l2;, score=0.753 total time=   4.1s
# [CV 3/5; 7/10] START model__C=26.826957952797247, model__penalty=l2.............
# [CV 3/5; 7/10] END model__C=26.826957952797247, model__penalty=l2;, score=0.757 total time=   4.1s
# [CV 4/5; 7/10] START model__C=26.826957952797247, model__penalty=l2.............
# [CV 4/5; 7/10] END model__C=26.826957952797247, model__penalty=l2;, score=0.796 total time=   4.1s
# [CV 5/5; 7/10] START model__C=26.826957952797247, model__penalty=l2.............
# [CV 5/5; 7/10] END model__C=26.826957952797247, model__penalty=l2;, score=0.767 total time=   4.1s
# [CV 1/5; 8/10] START model__C=0.012067926406393288, model__penalty=l2...........
# [CV 1/5; 8/10] END model__C=0.012067926406393288, model__penalty=l2;, score=0.778 total time=   0.9s
# [CV 2/5; 8/10] START model__C=0.012067926406393288, model__penalty=l2...........
# [CV 2/5; 8/10] END model__C=0.012067926406393288, model__penalty=l2;, score=0.779 total time=   0.9s
# [CV 3/5; 8/10] START model__C=0.012067926406393288, model__penalty=l2...........
# [CV 3/5; 8/10] END model__C=0.012067926406393288, model__penalty=l2;, score=0.784 total time=   0.9s
# [CV 4/5; 8/10] START model__C=0.012067926406393288, model__penalty=l2...........
# [CV 4/5; 8/10] END model__C=0.012067926406393288, model__penalty=l2;, score=0.784 total time=   0.8s
# [CV 5/5; 8/10] START model__C=0.012067926406393288, model__penalty=l2...........
# [CV 5/5; 8/10] END model__C=0.012067926406393288, model__penalty=l2;, score=0.766 total time=   0.9s
# [CV 1/5; 9/10] START model__C=0.2442053094548651, model__penalty=l2.............
# [CV 1/5; 9/10] END model__C=0.2442053094548651, model__penalty=l2;, score=0.778 total time=   1.0s
# [CV 2/5; 9/10] START model__C=0.2442053094548651, model__penalty=l2.............
# [CV 2/5; 9/10] END model__C=0.2442053094548651, model__penalty=l2;, score=0.779 total time=   0.9s
# [CV 3/5; 9/10] START model__C=0.2442053094548651, model__penalty=l2.............
# [CV 3/5; 9/10] END model__C=0.2442053094548651, model__penalty=l2;, score=0.783 total time=   0.9s
# [CV 4/5; 9/10] START model__C=0.2442053094548651, model__penalty=l2.............
# [CV 4/5; 9/10] END model__C=0.2442053094548651, model__penalty=l2;, score=0.785 total time=   0.9s
# [CV 5/5; 9/10] START model__C=0.2442053094548651, model__penalty=l2.............
# [CV 5/5; 9/10] END model__C=0.2442053094548651, model__penalty=l2;, score=0.767 total time=   1.0s
# [CV 1/5; 10/10] START model__C=0.025595479226995357, model__penalty=l2..........
# [CV 1/5; 10/10] END model__C=0.025595479226995357, model__penalty=l2;, score=0.778 total time=   0.9s
# [CV 2/5; 10/10] START model__C=0.025595479226995357, model__penalty=l2..........
# [CV 2/5; 10/10] END model__C=0.025595479226995357, model__penalty=l2;, score=0.779 total time=   0.8s
# [CV 3/5; 10/10] START model__C=0.025595479226995357, model__penalty=l2..........
# [CV 3/5; 10/10] END model__C=0.025595479226995357, model__penalty=l2;, score=0.784 total time=   1.0s
# [CV 4/5; 10/10] START model__C=0.025595479226995357, model__penalty=l2..........
# [CV 4/5; 10/10] END model__C=0.025595479226995357, model__penalty=l2;, score=0.784 total time=   0.8s
# [CV 5/5; 10/10] START model__C=0.025595479226995357, model__penalty=l2..........
# [CV 5/5; 10/10] END model__C=0.025595479226995357, model__penalty=l2;, score=0.766 total time=   0.9s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START model__C=0.29470517025518095, model__penalty=l2............
# [CV 1/5; 1/10] END model__C=0.29470517025518095, model__penalty=l2;, score=0.778 total time=   0.5s
# [CV 2/5; 1/10] START model__C=0.29470517025518095, model__penalty=l2............
# [CV 2/5; 1/10] END model__C=0.29470517025518095, model__penalty=l2;, score=0.779 total time=   0.7s
# [CV 3/5; 1/10] START model__C=0.29470517025518095, model__penalty=l2............
# [CV 3/5; 1/10] END model__C=0.29470517025518095, model__penalty=l2;, score=0.783 total time=   0.6s
# [CV 4/5; 1/10] START model__C=0.29470517025518095, model__penalty=l2............
# [CV 4/5; 1/10] END model__C=0.29470517025518095, model__penalty=l2;, score=0.785 total time=   0.5s
# [CV 5/5; 1/10] START model__C=0.29470517025518095, model__penalty=l2............
# [CV 5/5; 1/10] END model__C=0.29470517025518095, model__penalty=l2;, score=0.767 total time=   0.6s
# [CV 1/5; 2/10] START model__C=4.094915062380423, model__penalty=l1..............
# [CV 1/5; 2/10] END model__C=4.094915062380423, model__penalty=l1;, score=0.785 total time=   1.2s
# [CV 2/5; 2/10] START model__C=4.094915062380423, model__penalty=l1..............
# [CV 2/5; 2/10] END model__C=4.094915062380423, model__penalty=l1;, score=0.773 total time=   0.9s
# [CV 3/5; 2/10] START model__C=4.094915062380423, model__penalty=l1..............
# [CV 3/5; 2/10] END model__C=4.094915062380423, model__penalty=l1;, score=0.770 total time=   3.0s
# [CV 4/5; 2/10] START model__C=4.094915062380423, model__penalty=l1..............
# [CV 4/5; 2/10] END model__C=4.094915062380423, model__penalty=l1;, score=0.797 total time=   0.8s
# [CV 5/5; 2/10] START model__C=4.094915062380423, model__penalty=l1..............
# [CV 5/5; 2/10] END model__C=4.094915062380423, model__penalty=l1;, score=0.773 total time=   2.2s
# [CV 1/5; 3/10] START model__C=0.07906043210907697, model__penalty=l1............
# [CV 1/5; 3/10] END model__C=0.07906043210907697, model__penalty=l1;, score=0.775 total time=   0.3s
# [CV 2/5; 3/10] START model__C=0.07906043210907697, model__penalty=l1............
# [CV 2/5; 3/10] END model__C=0.07906043210907697, model__penalty=l1;, score=0.773 total time=   0.5s
# [CV 3/5; 3/10] START model__C=0.07906043210907697, model__penalty=l1............
# [CV 3/5; 3/10] END model__C=0.07906043210907697, model__penalty=l1;, score=0.777 total time=   0.4s
# [CV 4/5; 3/10] START model__C=0.07906043210907697, model__penalty=l1............
# [CV 4/5; 3/10] END model__C=0.07906043210907697, model__penalty=l1;, score=0.780 total time=   0.5s
# [CV 5/5; 3/10] START model__C=0.07906043210907697, model__penalty=l1............
# [CV 5/5; 3/10] END model__C=0.07906043210907697, model__penalty=l1;, score=0.760 total time=   0.4s
# [CV 1/5; 4/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 1/5; 4/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.781 total time=   0.7s
# [CV 2/5; 4/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 2/5; 4/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.780 total time=   0.6s
# [CV 3/5; 4/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 3/5; 4/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.787 total time=   0.7s
# [CV 4/5; 4/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 4/5; 4/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.787 total time=   0.7s
# [CV 5/5; 4/10] START model__C=0.517947467923121, model__penalty=l2..............
# [CV 5/5; 4/10] END model__C=0.517947467923121, model__penalty=l2;, score=0.773 total time=   0.7s
# [CV 1/5; 5/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 1/5; 5/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.784 total time=   0.7s
# [CV 2/5; 5/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 2/5; 5/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.782 total time=   0.7s
# [CV 3/5; 5/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 3/5; 5/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.788 total time=   0.7s
# [CV 4/5; 5/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 4/5; 5/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.792 total time=   0.7s
# [CV 5/5; 5/10] START model__C=0.6250551925273969, model__penalty=l2.............
# [CV 5/5; 5/10] END model__C=0.6250551925273969, model__penalty=l2;, score=0.775 total time=   0.7s
# [CV 1/5; 6/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 1/5; 6/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.742 total time=   3.0s
# [CV 2/5; 6/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 2/5; 6/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.715 total time=   3.1s
# [CV 3/5; 6/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 3/5; 6/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.736 total time=   3.3s
# [CV 4/5; 6/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 4/5; 6/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.788 total time=   3.0s
# [CV 5/5; 6/10] START model__C=68.66488450042998, model__penalty=l2..............
# [CV 5/5; 6/10] END model__C=68.66488450042998, model__penalty=l2;, score=0.758 total time=   2.7s
# [CV 1/5; 7/10] START model__C=15.264179671752318, model__penalty=l1.............
# [CV 1/5; 7/10] END model__C=15.264179671752318, model__penalty=l1;, score=0.738 total time=   4.8s
# [CV 2/5; 7/10] START model__C=15.264179671752318, model__penalty=l1.............
# [CV 2/5; 7/10] END model__C=15.264179671752318, model__penalty=l1;, score=0.713 total time=   5.0s
# [CV 3/5; 7/10] START model__C=15.264179671752318, model__penalty=l1.............
# [CV 3/5; 7/10] END model__C=15.264179671752318, model__penalty=l1;, score=0.729 total time=   6.0s
# [CV 4/5; 7/10] START model__C=15.264179671752318, model__penalty=l1.............
# [CV 4/5; 7/10] END model__C=15.264179671752318, model__penalty=l1;, score=0.789 total time=   4.8s
# [CV 5/5; 7/10] START model__C=15.264179671752318, model__penalty=l1.............
# [CV 5/5; 7/10] END model__C=15.264179671752318, model__penalty=l1;, score=0.736 total time=   4.5s
# [CV 1/5; 8/10] START model__C=0.0655128556859551, model__penalty=l1.............
# [CV 1/5; 8/10] END model__C=0.0655128556859551, model__penalty=l1;, score=0.775 total time=   0.4s
# [CV 2/5; 8/10] START model__C=0.0655128556859551, model__penalty=l1.............
# [CV 2/5; 8/10] END model__C=0.0655128556859551, model__penalty=l1;, score=0.773 total time=   0.5s
# [CV 3/5; 8/10] START model__C=0.0655128556859551, model__penalty=l1.............
# [CV 3/5; 8/10] END model__C=0.0655128556859551, model__penalty=l1;, score=0.775 total time=   0.4s
# [CV 4/5; 8/10] START model__C=0.0655128556859551, model__penalty=l1.............
# [CV 4/5; 8/10] END model__C=0.0655128556859551, model__penalty=l1;, score=0.780 total time=   0.3s
# [CV 5/5; 8/10] START model__C=0.0655128556859551, model__penalty=l1.............
# [CV 5/5; 8/10] END model__C=0.0655128556859551, model__penalty=l1;, score=0.760 total time=   0.4s
# [CV 1/5; 9/10] START model__C=3.3932217718953264, model__penalty=l2.............
# [CV 1/5; 9/10] END model__C=3.3932217718953264, model__penalty=l2;, score=0.786 total time=   1.1s
# [CV 2/5; 9/10] START model__C=3.3932217718953264, model__penalty=l2.............
# [CV 2/5; 9/10] END model__C=3.3932217718953264, model__penalty=l2;, score=0.769 total time=   1.4s
# [CV 3/5; 9/10] START model__C=3.3932217718953264, model__penalty=l2.............
# [CV 3/5; 9/10] END model__C=3.3932217718953264, model__penalty=l2;, score=0.782 total time=   1.1s
# [CV 4/5; 9/10] START model__C=3.3932217718953264, model__penalty=l2.............
# [CV 4/5; 9/10] END model__C=3.3932217718953264, model__penalty=l2;, score=0.796 total time=   1.1s
# [CV 5/5; 9/10] START model__C=3.3932217718953264, model__penalty=l2.............
# [CV 5/5; 9/10] END model__C=3.3932217718953264, model__penalty=l2;, score=0.778 total time=   1.1s
# [CV 1/5; 10/10] START model__C=0.054286754393238594, model__penalty=l1..........
# [CV 1/5; 10/10] END model__C=0.054286754393238594, model__penalty=l1;, score=0.772 total time=   0.6s
# [CV 2/5; 10/10] START model__C=0.054286754393238594, model__penalty=l1..........
# [CV 2/5; 10/10] END model__C=0.054286754393238594, model__penalty=l1;, score=0.775 total time=   0.4s
# [CV 3/5; 10/10] START model__C=0.054286754393238594, model__penalty=l1..........
# [CV 3/5; 10/10] END model__C=0.054286754393238594, model__penalty=l1;, score=0.775 total time=   0.3s
# [CV 4/5; 10/10] START model__C=0.054286754393238594, model__penalty=l1..........
# [CV 4/5; 10/10] END model__C=0.054286754393238594, model__penalty=l1;, score=0.780 total time=   0.3s
# [CV 5/5; 10/10] START model__C=0.054286754393238594, model__penalty=l1..........
# [CV 5/5; 10/10] END model__C=0.054286754393238594, model__penalty=l1;, score=0.761 total time=   0.5s
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1
# [CV 1/5; 1/10] END model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1;, score=0.733 total time=   7.5s
# [CV 2/5; 1/10] START model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1
# [CV 2/5; 1/10] END model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1;, score=0.721 total time=   7.6s
# [CV 3/5; 1/10] START model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1
# [CV 3/5; 1/10] END model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1;, score=0.740 total time=   7.6s
# [CV 4/5; 1/10] START model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1
# [CV 4/5; 1/10] END model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1;, score=0.793 total time=   7.5s
# [CV 5/5; 1/10] START model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1
# [CV 5/5; 1/10] END model__C=32.374575428176435, model__l1_ratio=0.1, model__penalty=l1;, score=0.751 total time=   7.5s
# [CV 1/5; 2/10] START model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1
# [CV 1/5; 2/10] END model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1;, score=0.774 total time=   4.7s
# [CV 2/5; 2/10] START model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1
# [CV 2/5; 2/10] END model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1;, score=0.776 total time=   4.7s
# [CV 3/5; 2/10] START model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1
# [CV 3/5; 2/10] END model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1;, score=0.779 total time=   4.7s
# [CV 4/5; 2/10] START model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1
# [CV 4/5; 2/10] END model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1;, score=0.781 total time=   4.7s
# [CV 5/5; 2/10] START model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1
# [CV 5/5; 2/10] END model__C=0.1151395399326447, model__l1_ratio=0.9, model__penalty=l1;, score=0.760 total time=   4.7s
# [CV 1/5; 3/10] START model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet
# [CV 1/5; 3/10] END model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet;, score=0.778 total time=   0.8s
# [CV 2/5; 3/10] START model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet
# [CV 2/5; 3/10] END model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet;, score=0.779 total time=   0.8s
# [CV 3/5; 3/10] START model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet
# [CV 3/5; 3/10] END model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet;, score=0.783 total time=   0.8s
# [CV 4/5; 3/10] START model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet
# [CV 4/5; 3/10] END model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet;, score=0.784 total time=   0.8s
# [CV 5/5; 3/10] START model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet
# [CV 5/5; 3/10] END model__C=0.054286754393238594, model__l1_ratio=0.9, model__penalty=elasticnet;, score=0.766 total time=   0.8s
# [CV 1/5; 4/10] START model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1
# [CV 1/5; 4/10] END model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1;, score=0.788 total time=   5.5s
# [CV 2/5; 4/10] START model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1
# [CV 2/5; 4/10] END model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1;, score=0.786 total time=   5.5s
# [CV 3/5; 4/10] START model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1
# [CV 3/5; 4/10] END model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1;, score=0.787 total time=   5.5s
# [CV 4/5; 4/10] START model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1
# [CV 4/5; 4/10] END model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1;, score=0.788 total time=   5.5s
# [CV 5/5; 4/10] START model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1
# [CV 5/5; 4/10] END model__C=1.9306977288832496, model__l1_ratio=0.9, model__penalty=l1;, score=0.779 total time=   5.5s
# [CV 1/5; 5/10] START model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1
# [CV 1/5; 5/10] END model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1;, score=0.730 total time=   7.1s
# [CV 2/5; 5/10] START model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1
# [CV 2/5; 5/10] END model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1;, score=0.714 total time=   7.2s
# [CV 3/5; 5/10] START model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1
# [CV 3/5; 5/10] END model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1;, score=0.736 total time=   7.2s
# [CV 4/5; 5/10] START model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1
# [CV 4/5; 5/10] END model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1;, score=0.788 total time=   7.2s
# [CV 5/5; 5/10] START model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1
# [CV 5/5; 5/10] END model__C=56.89866029018293, model__l1_ratio=0.1, model__penalty=l1;, score=0.752 total time=   7.2s
# [CV 1/5; 6/10] START model__C=100.0, model__l1_ratio=0.1, model__penalty=l1.....
# [CV 1/5; 6/10] END model__C=100.0, model__l1_ratio=0.1, model__penalty=l1;, score=0.726 total time=   6.6s
# [CV 2/5; 6/10] START model__C=100.0, model__l1_ratio=0.1, model__penalty=l1.....
# [CV 2/5; 6/10] END model__C=100.0, model__l1_ratio=0.1, model__penalty=l1;, score=0.710 total time=   6.7s
# [CV 3/5; 6/10] START model__C=100.0, model__l1_ratio=0.1, model__penalty=l1.....
# [CV 3/5; 6/10] END model__C=100.0, model__l1_ratio=0.1, model__penalty=l1;, score=0.728 total time=   6.6s
# [CV 4/5; 6/10] START model__C=100.0, model__l1_ratio=0.1, model__penalty=l1.....
# [CV 4/5; 6/10] END model__C=100.0, model__l1_ratio=0.1, model__penalty=l1;, score=0.788 total time=   6.6s
# [CV 5/5; 6/10] START model__C=100.0, model__l1_ratio=0.1, model__penalty=l1.....
# [CV 5/5; 6/10] END model__C=100.0, model__l1_ratio=0.1, model__penalty=l1;, score=0.750 total time=   6.7s
# [CV 1/5; 7/10] START model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1
# [CV 1/5; 7/10] END model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1;, score=0.788 total time=   5.9s
# [CV 2/5; 7/10] START model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1
# [CV 2/5; 7/10] END model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1;, score=0.786 total time=   5.9s
# [CV 3/5; 7/10] START model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1
# [CV 3/5; 7/10] END model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1;, score=0.780 total time=   5.9s
# [CV 4/5; 7/10] START model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1
# [CV 4/5; 7/10] END model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1;, score=0.796 total time=   6.0s
# [CV 5/5; 7/10] START model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1
# [CV 5/5; 7/10] END model__C=2.811768697974228, model__l1_ratio=0.9, model__penalty=l1;, score=0.778 total time=   5.8s
# [CV 1/5; 8/10] START model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1
# [CV 1/5; 8/10] END model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1;, score=0.777 total time=   4.7s
# [CV 2/5; 8/10] START model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1
# [CV 2/5; 8/10] END model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1;, score=0.776 total time=   4.7s
# [CV 3/5; 8/10] START model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1
# [CV 3/5; 8/10] END model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1;, score=0.781 total time=   5.0s
# [CV 4/5; 8/10] START model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1
# [CV 4/5; 8/10] END model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1;, score=0.782 total time=   4.9s
# [CV 5/5; 8/10] START model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1
# [CV 5/5; 8/10] END model__C=0.29470517025518095, model__l1_ratio=0.1, model__penalty=l1;, score=0.760 total time=   5.2s
# [CV 1/5; 9/10] START model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1
# [CV 1/5; 9/10] END model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1;, score=0.766 total time=   7.3s
# [CV 2/5; 9/10] START model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1
# [CV 2/5; 9/10] END model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1;, score=0.762 total time=   6.9s
# [CV 3/5; 9/10] START model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1
# [CV 3/5; 9/10] END model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1;, score=0.767 total time=   6.9s
# [CV 4/5; 9/10] START model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1
# [CV 4/5; 9/10] END model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1;, score=0.796 total time=   6.9s
# [CV 5/5; 9/10] START model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1
# [CV 5/5; 9/10] END model__C=7.196856730011514, model__l1_ratio=0.5, model__penalty=l1;, score=0.771 total time=   6.8s
# [CV 1/5; 10/10] START model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1
# [CV 1/5; 10/10] END model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1;, score=0.777 total time=   4.8s
# [CV 2/5; 10/10] START model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1
# [CV 2/5; 10/10] END model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1;, score=0.778 total time=   4.9s
# [CV 3/5; 10/10] START model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1
# [CV 3/5; 10/10] END model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1;, score=0.784 total time=   5.0s
# [CV 4/5; 10/10] START model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1
# [CV 4/5; 10/10] END model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1;, score=0.784 total time=   5.0s
# [CV 5/5; 10/10] START model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1
# [CV 5/5; 10/10] END model__C=0.6250551925273969, model__l1_ratio=0.1, model__penalty=l1;, score=0.764 total time=   5.0s

# %%
test_scores_lg1
# Out:
#    best_score                                        best_params
# 2    0.785745  {'model__penalty': 'l1', 'model__l1_ratio': 0....
# 1    0.784202  {'model__penalty': 'l2', 'model__C': 0.6250551...
# 0    0.784199  {'model__penalty': 'l2', 'model__C': 0.6250551...

# %%
print(test_scores_lg1['best_params'][1])
print(test_scores_lg1['best_score'][1])
# Out:
# {'model__penalty': 'l2', 'model__C': 0.6250551925273969}
# 0.7842022707846501

# %% [raw]
# {'model__penalty': 'l2', 'model__C': 1.5998587196060574}
# 0.7877825076554492

# %%
print(test_scores_lg1['best_params'][2])
print(test_scores_lg1['best_score'][2])
# Out:
# {'model__penalty': 'l1', 'model__l1_ratio': 0.9, 'model__C': 2.811768697974228}
# 0.7857454010166858

# %% [raw]
# {'model__penalty': 'elasticnet', 'model__l1_ratio': 0.1, 'model__C': 1.0985411419875584}
# 0.7876718089824106

# %%
print(test_scores_lg1['best_params'][0])
print(test_scores_lg1['best_score'][0])
# Out:
# {'model__penalty': 'l2', 'model__C': 0.6250551925273969}
# 0.7841993286710806

# %% [raw]
# {'model__penalty': 'l2', 'model__C': 2.811768697974228}
# 0.7857040733871727

# %% [markdown]
# ### KNN - sklearn  (using labse embeddings)

# %%
nn_model = KNeighborsClassifier()

# Define the hyperparameters for randomized search
hyperparameters = {
    'n_neighbors': range(1, 31),  # Test range of neighbors from 1 to 20
    'weights': ['uniform', 'distance'],  # Test uniform and distance-based weights
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],  # Algorithms for computing neighbors
    'p': [1, 2]  # Parameter for distance metric (1 for Manhattan, 2 for Euclidean)
}

# Set up randomized search with cross-validation
rs = RandomizedSearchCV(knn_model, hyperparameters, cv=stratified_kfold, n_iter=40, scoring='f1', verbose=10)

# Perform the randomized search for best hyperparameters
rs.fit(combined_embeddings_labse, y_array)

# Extract the results
best_params_knn = rs.best_params_
best_score_knn = rs.best_score_
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5; 1/40] START algorithm=ball_tree, n_neighbors=29, p=2, weights=distance.
# [CV 1/5; 1/40] END algorithm=ball_tree, n_neighbors=29, p=2, weights=distance;, score=0.799 total time=   8.2s
# [CV 2/5; 1/40] START algorithm=ball_tree, n_neighbors=29, p=2, weights=distance.
# [CV 2/5; 1/40] END algorithm=ball_tree, n_neighbors=29, p=2, weights=distance;, score=0.787 total time=   8.3s
# [CV 3/5; 1/40] START algorithm=ball_tree, n_neighbors=29, p=2, weights=distance.
# [CV 3/5; 1/40] END algorithm=ball_tree, n_neighbors=29, p=2, weights=distance;, score=0.798 total time=   8.2s
# [CV 4/5; 1/40] START algorithm=ball_tree, n_neighbors=29, p=2, weights=distance.
# [CV 4/5; 1/40] END algorithm=ball_tree, n_neighbors=29, p=2, weights=distance;, score=0.806 total time=   8.3s
# [CV 5/5; 1/40] START algorithm=ball_tree, n_neighbors=29, p=2, weights=distance.
# [CV 5/5; 1/40] END algorithm=ball_tree, n_neighbors=29, p=2, weights=distance;, score=0.781 total time=   8.2s
# [CV 1/5; 2/40] START algorithm=ball_tree, n_neighbors=24, p=1, weights=distance.
# [CV 1/5; 2/40] END algorithm=ball_tree, n_neighbors=24, p=1, weights=distance;, score=0.801 total time=   8.3s
# [CV 2/5; 2/40] START algorithm=ball_tree, n_neighbors=24, p=1, weights=distance.
# [CV 2/5; 2/40] END algorithm=ball_tree, n_neighbors=24, p=1, weights=distance;, score=0.790 total time=   8.4s
# [CV 3/5; 2/40] START algorithm=ball_tree, n_neighbors=24, p=1, weights=distance.
# [CV 3/5; 2/40] END algorithm=ball_tree, n_neighbors=24, p=1, weights=distance;, score=0.800 total time=   8.5s
# [CV 4/5; 2/40] START algorithm=ball_tree, n_neighbors=24, p=1, weights=distance.
# [CV 4/5; 2/40] END algorithm=ball_tree, n_neighbors=24, p=1, weights=distance;, score=0.808 total time=   8.5s
# [CV 5/5; 2/40] START algorithm=ball_tree, n_neighbors=24, p=1, weights=distance.
# [CV 5/5; 2/40] END algorithm=ball_tree, n_neighbors=24, p=1, weights=distance;, score=0.784 total time=   8.5s
# [CV 1/5; 3/40] START algorithm=brute, n_neighbors=30, p=1, weights=distance.....
# [CV 1/5; 3/40] END algorithm=brute, n_neighbors=30, p=1, weights=distance;, score=0.802 total time=   1.5s
# [CV 2/5; 3/40] START algorithm=brute, n_neighbors=30, p=1, weights=distance.....
# [CV 2/5; 3/40] END algorithm=brute, n_neighbors=30, p=1, weights=distance;, score=0.787 total time=   1.6s
# [CV 3/5; 3/40] START algorithm=brute, n_neighbors=30, p=1, weights=distance.....
# [CV 3/5; 3/40] END algorithm=brute, n_neighbors=30, p=1, weights=distance;, score=0.798 total time=   1.8s
# [CV 4/5; 3/40] START algorithm=brute, n_neighbors=30, p=1, weights=distance.....
# [CV 4/5; 3/40] END algorithm=brute, n_neighbors=30, p=1, weights=distance;, score=0.807 total time=   1.8s
# [CV 5/5; 3/40] START algorithm=brute, n_neighbors=30, p=1, weights=distance.....
# [CV 5/5; 3/40] END algorithm=brute, n_neighbors=30, p=1, weights=distance;, score=0.781 total time=   1.5s
# [CV 1/5; 4/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 1/5; 4/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.789 total time=   8.9s
# [CV 2/5; 4/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 2/5; 4/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.769 total time=   9.0s
# [CV 3/5; 4/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 3/5; 4/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.799 total time=   8.9s
# [CV 4/5; 4/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 4/5; 4/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.805 total time=   9.2s
# [CV 5/5; 4/40] START algorithm=kd_tree, n_neighbors=8, p=2, weights=distance....
# [CV 5/5; 4/40] END algorithm=kd_tree, n_neighbors=8, p=2, weights=distance;, score=0.762 total time=   9.0s
# [CV 1/5; 5/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance...
# [CV 1/5; 5/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.804 total time=   8.6s
# [CV 2/5; 5/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance...
# [CV 2/5; 5/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.794 total time=   8.7s
# [CV 3/5; 5/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance...
# [CV 3/5; 5/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.803 total time=   8.6s
# [CV 4/5; 5/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance...
# [CV 4/5; 5/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.797 total time=   8.6s
# [CV 5/5; 5/40] START algorithm=kd_tree, n_neighbors=13, p=1, weights=distance...
# [CV 5/5; 5/40] END algorithm=kd_tree, n_neighbors=13, p=1, weights=distance;, score=0.777 total time=   8.7s
# [CV 1/5; 6/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=distance...
# [CV 1/5; 6/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=distance;, score=0.810 total time=   8.6s
# [CV 2/5; 6/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=distance...
# [CV 2/5; 6/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=distance;, score=0.788 total time=   8.8s
# [CV 3/5; 6/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=distance...
# [CV 3/5; 6/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=distance;, score=0.798 total time=   9.0s
# [CV 4/5; 6/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=distance...
# [CV 4/5; 6/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=distance;, score=0.799 total time=   8.7s
# [CV 5/5; 6/40] START algorithm=kd_tree, n_neighbors=12, p=1, weights=distance...
# [CV 5/5; 6/40] END algorithm=kd_tree, n_neighbors=12, p=1, weights=distance;, score=0.767 total time=   8.7s
# [CV 1/5; 7/40] START algorithm=brute, n_neighbors=26, p=1, weights=uniform......
# [CV 1/5; 7/40] END algorithm=brute, n_neighbors=26, p=1, weights=uniform;, score=0.788 total time=   2.2s
# [CV 2/5; 7/40] START algorithm=brute, n_neighbors=26, p=1, weights=uniform......
# [CV 2/5; 7/40] END algorithm=brute, n_neighbors=26, p=1, weights=uniform;, score=0.779 total time=   2.1s
# [CV 3/5; 7/40] START algorithm=brute, n_neighbors=26, p=1, weights=uniform......
# [CV 3/5; 7/40] END algorithm=brute, n_neighbors=26, p=1, weights=uniform;, score=0.791 total time=   2.2s
# [CV 4/5; 7/40] START algorithm=brute, n_neighbors=26, p=1, weights=uniform......
# [CV 4/5; 7/40] END algorithm=brute, n_neighbors=26, p=1, weights=uniform;, score=0.793 total time=   2.2s
# [CV 5/5; 7/40] START algorithm=brute, n_neighbors=26, p=1, weights=uniform......
# [CV 5/5; 7/40] END algorithm=brute, n_neighbors=26, p=1, weights=uniform;, score=0.778 total time=   2.2s
# [CV 1/5; 8/40] START algorithm=auto, n_neighbors=22, p=1, weights=distance......
# [CV 1/5; 8/40] END algorithm=auto, n_neighbors=22, p=1, weights=distance;, score=0.801 total time=   1.4s
# [CV 2/5; 8/40] START algorithm=auto, n_neighbors=22, p=1, weights=distance......
# [CV 2/5; 8/40] END algorithm=auto, n_neighbors=22, p=1, weights=distance;, score=0.790 total time=   1.4s
# [CV 3/5; 8/40] START algorithm=auto, n_neighbors=22, p=1, weights=distance......
# [CV 3/5; 8/40] END algorithm=auto, n_neighbors=22, p=1, weights=distance;, score=0.799 total time=   1.4s
# [CV 4/5; 8/40] START algorithm=auto, n_neighbors=22, p=1, weights=distance......
# [CV 4/5; 8/40] END algorithm=auto, n_neighbors=22, p=1, weights=distance;, score=0.808 total time=   1.5s
# [CV 5/5; 8/40] START algorithm=auto, n_neighbors=22, p=1, weights=distance......
# [CV 5/5; 8/40] END algorithm=auto, n_neighbors=22, p=1, weights=distance;, score=0.778 total time=   1.4s
# [CV 1/5; 9/40] START algorithm=brute, n_neighbors=30, p=2, weights=distance.....
# [CV 1/5; 9/40] END algorithm=brute, n_neighbors=30, p=2, weights=distance;, score=0.801 total time=   0.1s
# [CV 2/5; 9/40] START algorithm=brute, n_neighbors=30, p=2, weights=distance.....
# [CV 2/5; 9/40] END algorithm=brute, n_neighbors=30, p=2, weights=distance;, score=0.788 total time=   0.1s
# [CV 3/5; 9/40] START algorithm=brute, n_neighbors=30, p=2, weights=distance.....
# [CV 3/5; 9/40] END algorithm=brute, n_neighbors=30, p=2, weights=distance;, score=0.798 total time=   0.1s
# [CV 4/5; 9/40] START algorithm=brute, n_neighbors=30, p=2, weights=distance.....
# [CV 4/5; 9/40] END algorithm=brute, n_neighbors=30, p=2, weights=distance;, score=0.808 total time=   0.1s
# [CV 5/5; 9/40] START algorithm=brute, n_neighbors=30, p=2, weights=distance.....
# [CV 5/5; 9/40] END algorithm=brute, n_neighbors=30, p=2, weights=distance;, score=0.781 total time=   0.1s
# [CV 1/5; 10/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 1/5; 10/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.790 total time=   2.2s
# [CV 2/5; 10/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 2/5; 10/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.777 total time=   2.2s
# [CV 3/5; 10/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 3/5; 10/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.790 total time=   2.2s
# [CV 4/5; 10/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 4/5; 10/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.791 total time=   2.1s
# [CV 5/5; 10/40] START algorithm=auto, n_neighbors=21, p=1, weights=uniform......
# [CV 5/5; 10/40] END algorithm=auto, n_neighbors=21, p=1, weights=uniform;, score=0.773 total time=   2.1s
# [CV 1/5; 11/40] START algorithm=brute, n_neighbors=23, p=1, weights=uniform.....
# [CV 1/5; 11/40] END algorithm=brute, n_neighbors=23, p=1, weights=uniform;, score=0.790 total time=   2.2s
# [CV 2/5; 11/40] START algorithm=brute, n_neighbors=23, p=1, weights=uniform.....
# [CV 2/5; 11/40] END algorithm=brute, n_neighbors=23, p=1, weights=uniform;, score=0.779 total time=   2.1s
# [CV 3/5; 11/40] START algorithm=brute, n_neighbors=23, p=1, weights=uniform.....
# [CV 3/5; 11/40] END algorithm=brute, n_neighbors=23, p=1, weights=uniform;, score=0.789 total time=   2.1s
# [CV 4/5; 11/40] START algorithm=brute, n_neighbors=23, p=1, weights=uniform.....
# [CV 4/5; 11/40] END algorithm=brute, n_neighbors=23, p=1, weights=uniform;, score=0.793 total time=   2.2s
# [CV 5/5; 11/40] START algorithm=brute, n_neighbors=23, p=1, weights=uniform.....
# [CV 5/5; 11/40] END algorithm=brute, n_neighbors=23, p=1, weights=uniform;, score=0.774 total time=   2.2s
# [CV 1/5; 12/40] START algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform..
# [CV 1/5; 12/40] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform;, score=0.735 total time=   8.3s
# [CV 2/5; 12/40] START algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform..
# [CV 2/5; 12/40] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform;, score=0.695 total time=   8.3s
# [CV 3/5; 12/40] START algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform..
# [CV 3/5; 12/40] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform;, score=0.745 total time=   8.3s
# [CV 4/5; 12/40] START algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform..
# [CV 4/5; 12/40] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform;, score=0.737 total time=   8.4s
# [CV 5/5; 12/40] START algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform..
# [CV 5/5; 12/40] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform;, score=0.710 total time=   8.6s
# [CV 1/5; 13/40] START algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform....
# [CV 1/5; 13/40] END algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform;, score=0.795 total time=   8.9s
# [CV 2/5; 13/40] START algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform....
# [CV 2/5; 13/40] END algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform;, score=0.762 total time=   9.0s
# [CV 3/5; 13/40] START algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform....
# [CV 3/5; 13/40] END algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform;, score=0.778 total time=   9.0s
# [CV 4/5; 13/40] START algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform....
# [CV 4/5; 13/40] END algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform;, score=0.790 total time=   9.0s
# [CV 5/5; 13/40] START algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform....
# [CV 5/5; 13/40] END algorithm=kd_tree, n_neighbors=7, p=2, weights=uniform;, score=0.748 total time=   8.9s
# [CV 1/5; 14/40] START algorithm=auto, n_neighbors=1, p=2, weights=uniform.......
# [CV 1/5; 14/40] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.737 total time=   0.1s
# [CV 2/5; 14/40] START algorithm=auto, n_neighbors=1, p=2, weights=uniform.......
# [CV 2/5; 14/40] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.718 total time=   0.1s
# [CV 3/5; 14/40] START algorithm=auto, n_neighbors=1, p=2, weights=uniform.......
# [CV 3/5; 14/40] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.720 total time=   0.1s
# [CV 4/5; 14/40] START algorithm=auto, n_neighbors=1, p=2, weights=uniform.......
# [CV 4/5; 14/40] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.742 total time=   0.1s
# [CV 5/5; 14/40] START algorithm=auto, n_neighbors=1, p=2, weights=uniform.......
# [CV 5/5; 14/40] END algorithm=auto, n_neighbors=1, p=2, weights=uniform;, score=0.723 total time=   0.1s
# [CV 1/5; 15/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform...
# [CV 1/5; 15/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform;, score=0.790 total time=   8.8s
# [CV 2/5; 15/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform...
# [CV 2/5; 15/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform;, score=0.779 total time=   8.8s
# [CV 3/5; 15/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform...
# [CV 3/5; 15/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform;, score=0.792 total time=   8.7s
# [CV 4/5; 15/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform...
# [CV 4/5; 15/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform;, score=0.789 total time=   8.8s
# [CV 5/5; 15/40] START algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform...
# [CV 5/5; 15/40] END algorithm=kd_tree, n_neighbors=22, p=1, weights=uniform;, score=0.771 total time=   8.7s
# [CV 1/5; 16/40] START algorithm=brute, n_neighbors=28, p=1, weights=uniform.....
# [CV 1/5; 16/40] END algorithm=brute, n_neighbors=28, p=1, weights=uniform;, score=0.792 total time=   2.1s
# [CV 2/5; 16/40] START algorithm=brute, n_neighbors=28, p=1, weights=uniform.....
# [CV 2/5; 16/40] END algorithm=brute, n_neighbors=28, p=1, weights=uniform;, score=0.776 total time=   2.2s
# [CV 3/5; 16/40] START algorithm=brute, n_neighbors=28, p=1, weights=uniform.....
# [CV 3/5; 16/40] END algorithm=brute, n_neighbors=28, p=1, weights=uniform;, score=0.791 total time=   2.1s
# [CV 4/5; 16/40] START algorithm=brute, n_neighbors=28, p=1, weights=uniform.....
# [CV 4/5; 16/40] END algorithm=brute, n_neighbors=28, p=1, weights=uniform;, score=0.791 total time=   2.1s
# [CV 5/5; 16/40] START algorithm=brute, n_neighbors=28, p=1, weights=uniform.....
# [CV 5/5; 16/40] END algorithm=brute, n_neighbors=28, p=1, weights=uniform;, score=0.773 total time=   2.1s
# [CV 1/5; 17/40] START algorithm=brute, n_neighbors=4, p=1, weights=distance.....
# [CV 1/5; 17/40] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.784 total time=   1.4s
# [CV 2/5; 17/40] START algorithm=brute, n_neighbors=4, p=1, weights=distance.....
# [CV 2/5; 17/40] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.756 total time=   1.4s
# [CV 3/5; 17/40] START algorithm=brute, n_neighbors=4, p=1, weights=distance.....
# [CV 3/5; 17/40] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.789 total time=   1.4s
# [CV 4/5; 17/40] START algorithm=brute, n_neighbors=4, p=1, weights=distance.....
# [CV 4/5; 17/40] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.769 total time=   1.5s
# [CV 5/5; 17/40] START algorithm=brute, n_neighbors=4, p=1, weights=distance.....
# [CV 5/5; 17/40] END algorithm=brute, n_neighbors=4, p=1, weights=distance;, score=0.745 total time=   1.4s
# [CV 1/5; 18/40] START algorithm=auto, n_neighbors=24, p=1, weights=uniform......
# [CV 1/5; 18/40] END algorithm=auto, n_neighbors=24, p=1, weights=uniform;, score=0.790 total time=   2.2s
# [CV 2/5; 18/40] START algorithm=auto, n_neighbors=24, p=1, weights=uniform......
# [CV 2/5; 18/40] END algorithm=auto, n_neighbors=24, p=1, weights=uniform;, score=0.779 total time=   2.2s
# [CV 3/5; 18/40] START algorithm=auto, n_neighbors=24, p=1, weights=uniform......
# [CV 3/5; 18/40] END algorithm=auto, n_neighbors=24, p=1, weights=uniform;, score=0.789 total time=   2.2s
# [CV 4/5; 18/40] START algorithm=auto, n_neighbors=24, p=1, weights=uniform......
# [CV 4/5; 18/40] END algorithm=auto, n_neighbors=24, p=1, weights=uniform;, score=0.793 total time=   2.2s
# [CV 5/5; 18/40] START algorithm=auto, n_neighbors=24, p=1, weights=uniform......
# [CV 5/5; 18/40] END algorithm=auto, n_neighbors=24, p=1, weights=uniform;, score=0.773 total time=   2.2s
# [CV 1/5; 19/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 1/5; 19/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.742 total time=   8.4s
# [CV 2/5; 19/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 2/5; 19/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.720 total time=   8.3s
# [CV 3/5; 19/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 3/5; 19/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.720 total time=   8.6s
# [CV 4/5; 19/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 4/5; 19/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.746 total time=   8.4s
# [CV 5/5; 19/40] START algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform..
# [CV 5/5; 19/40] END algorithm=ball_tree, n_neighbors=1, p=2, weights=uniform;, score=0.723 total time=   8.3s
# [CV 1/5; 20/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform....
# [CV 1/5; 20/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform;, score=0.778 total time=   9.0s
# [CV 2/5; 20/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform....
# [CV 2/5; 20/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform;, score=0.761 total time=   9.0s
# [CV 3/5; 20/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform....
# [CV 3/5; 20/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform;, score=0.781 total time=   8.9s
# [CV 4/5; 20/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform....
# [CV 4/5; 20/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform;, score=0.792 total time=   9.0s
# [CV 5/5; 20/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform....
# [CV 5/5; 20/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform;, score=0.743 total time=   8.9s
# [CV 1/5; 21/40] START algorithm=brute, n_neighbors=2, p=1, weights=distance.....
# [CV 1/5; 21/40] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.755 total time=   1.4s
# [CV 2/5; 21/40] START algorithm=brute, n_neighbors=2, p=1, weights=distance.....
# [CV 2/5; 21/40] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.739 total time=   1.4s
# [CV 3/5; 21/40] START algorithm=brute, n_neighbors=2, p=1, weights=distance.....
# [CV 3/5; 21/40] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.713 total time=   1.4s
# [CV 4/5; 21/40] START algorithm=brute, n_neighbors=2, p=1, weights=distance.....
# [CV 4/5; 21/40] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.726 total time=   1.4s
# [CV 5/5; 21/40] START algorithm=brute, n_neighbors=2, p=1, weights=distance.....
# [CV 5/5; 21/40] END algorithm=brute, n_neighbors=2, p=1, weights=distance;, score=0.710 total time=   1.4s
# [CV 1/5; 22/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=distance.
# [CV 1/5; 22/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=distance;, score=0.780 total time=   8.3s
# [CV 2/5; 22/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=distance.
# [CV 2/5; 22/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=distance;, score=0.740 total time=   8.2s
# [CV 3/5; 22/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=distance.
# [CV 3/5; 22/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=distance;, score=0.785 total time=   8.2s
# [CV 4/5; 22/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=distance.
# [CV 4/5; 22/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=distance;, score=0.759 total time=   8.3s
# [CV 5/5; 22/40] START algorithm=ball_tree, n_neighbors=3, p=1, weights=distance.
# [CV 5/5; 22/40] END algorithm=ball_tree, n_neighbors=3, p=1, weights=distance;, score=0.752 total time=   8.2s
# [CV 1/5; 23/40] START algorithm=ball_tree, n_neighbors=25, p=1, weights=distance
# [CV 1/5; 23/40] END algorithm=ball_tree, n_neighbors=25, p=1, weights=distance;, score=0.801 total time=   8.3s
# [CV 2/5; 23/40] START algorithm=ball_tree, n_neighbors=25, p=1, weights=distance
# [CV 2/5; 23/40] END algorithm=ball_tree, n_neighbors=25, p=1, weights=distance;, score=0.790 total time=   8.3s
# [CV 3/5; 23/40] START algorithm=ball_tree, n_neighbors=25, p=1, weights=distance
# [CV 3/5; 23/40] END algorithm=ball_tree, n_neighbors=25, p=1, weights=distance;, score=0.796 total time=   8.3s
# [CV 4/5; 23/40] START algorithm=ball_tree, n_neighbors=25, p=1, weights=distance
# [CV 4/5; 23/40] END algorithm=ball_tree, n_neighbors=25, p=1, weights=distance;, score=0.808 total time=   8.4s
# [CV 5/5; 23/40] START algorithm=ball_tree, n_neighbors=25, p=1, weights=distance
# [CV 5/5; 23/40] END algorithm=ball_tree, n_neighbors=25, p=1, weights=distance;, score=0.781 total time=   8.3s
# [CV 1/5; 24/40] START algorithm=kd_tree, n_neighbors=5, p=1, weights=distance...
# [CV 1/5; 24/40] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance;, score=0.811 total time=   8.7s
# [CV 2/5; 24/40] START algorithm=kd_tree, n_neighbors=5, p=1, weights=distance...
# [CV 2/5; 24/40] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance;, score=0.761 total time=   8.7s
# [CV 3/5; 24/40] START algorithm=kd_tree, n_neighbors=5, p=1, weights=distance...
# [CV 3/5; 24/40] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance;, score=0.797 total time=   8.7s
# [CV 4/5; 24/40] START algorithm=kd_tree, n_neighbors=5, p=1, weights=distance...
# [CV 4/5; 24/40] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance;, score=0.799 total time=   8.7s
# [CV 5/5; 24/40] START algorithm=kd_tree, n_neighbors=5, p=1, weights=distance...
# [CV 5/5; 24/40] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance;, score=0.767 total time=   8.7s
# [CV 1/5; 25/40] START algorithm=brute, n_neighbors=27, p=2, weights=uniform.....
# [CV 1/5; 25/40] END algorithm=brute, n_neighbors=27, p=2, weights=uniform;, score=0.791 total time=   0.1s
# [CV 2/5; 25/40] START algorithm=brute, n_neighbors=27, p=2, weights=uniform.....
# [CV 2/5; 25/40] END algorithm=brute, n_neighbors=27, p=2, weights=uniform;, score=0.778 total time=   0.1s
# [CV 3/5; 25/40] START algorithm=brute, n_neighbors=27, p=2, weights=uniform.....
# [CV 3/5; 25/40] END algorithm=brute, n_neighbors=27, p=2, weights=uniform;, score=0.789 total time=   0.1s
# [CV 4/5; 25/40] START algorithm=brute, n_neighbors=27, p=2, weights=uniform.....
# [CV 4/5; 25/40] END algorithm=brute, n_neighbors=27, p=2, weights=uniform;, score=0.795 total time=   0.1s
# [CV 5/5; 25/40] START algorithm=brute, n_neighbors=27, p=2, weights=uniform.....
# [CV 5/5; 25/40] END algorithm=brute, n_neighbors=27, p=2, weights=uniform;, score=0.776 total time=   0.1s
# [CV 1/5; 26/40] START algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform...
# [CV 1/5; 26/40] END algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform;, score=0.790 total time=   9.0s
# [CV 2/5; 26/40] START algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform...
# [CV 2/5; 26/40] END algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform;, score=0.776 total time=   9.0s
# [CV 3/5; 26/40] START algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform...
# [CV 3/5; 26/40] END algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform;, score=0.791 total time=   9.0s
# [CV 4/5; 26/40] START algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform...
# [CV 4/5; 26/40] END algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform;, score=0.793 total time=   9.0s
# [CV 5/5; 26/40] START algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform...
# [CV 5/5; 26/40] END algorithm=kd_tree, n_neighbors=26, p=2, weights=uniform;, score=0.776 total time=   9.0s
# [CV 1/5; 27/40] START algorithm=kd_tree, n_neighbors=22, p=2, weights=distance..
# [CV 1/5; 27/40] END algorithm=kd_tree, n_neighbors=22, p=2, weights=distance;, score=0.803 total time=   9.0s
# [CV 2/5; 27/40] START algorithm=kd_tree, n_neighbors=22, p=2, weights=distance..
# [CV 2/5; 27/40] END algorithm=kd_tree, n_neighbors=22, p=2, weights=distance;, score=0.785 total time=   9.0s
# [CV 3/5; 27/40] START algorithm=kd_tree, n_neighbors=22, p=2, weights=distance..
# [CV 3/5; 27/40] END algorithm=kd_tree, n_neighbors=22, p=2, weights=distance;, score=0.802 total time=   9.0s
# [CV 4/5; 27/40] START algorithm=kd_tree, n_neighbors=22, p=2, weights=distance..
# [CV 4/5; 27/40] END algorithm=kd_tree, n_neighbors=22, p=2, weights=distance;, score=0.807 total time=   9.2s
# [CV 5/5; 27/40] START algorithm=kd_tree, n_neighbors=22, p=2, weights=distance..
# [CV 5/5; 27/40] END algorithm=kd_tree, n_neighbors=22, p=2, weights=distance;, score=0.783 total time=   8.9s
# [CV 1/5; 28/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform......
# [CV 1/5; 28/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.789 total time=   0.1s
# [CV 2/5; 28/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform......
# [CV 2/5; 28/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.780 total time=   0.1s
# [CV 3/5; 28/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform......
# [CV 3/5; 28/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.784 total time=   0.1s
# [CV 4/5; 28/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform......
# [CV 4/5; 28/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.783 total time=   0.1s
# [CV 5/5; 28/40] START algorithm=auto, n_neighbors=15, p=2, weights=uniform......
# [CV 5/5; 28/40] END algorithm=auto, n_neighbors=15, p=2, weights=uniform;, score=0.758 total time=   0.1s
# [CV 1/5; 29/40] START algorithm=kd_tree, n_neighbors=13, p=2, weights=distance..
# [CV 1/5; 29/40] END algorithm=kd_tree, n_neighbors=13, p=2, weights=distance;, score=0.797 total time=   8.9s
# [CV 2/5; 29/40] START algorithm=kd_tree, n_neighbors=13, p=2, weights=distance..
# [CV 2/5; 29/40] END algorithm=kd_tree, n_neighbors=13, p=2, weights=distance;, score=0.789 total time=   9.1s
# [CV 3/5; 29/40] START algorithm=kd_tree, n_neighbors=13, p=2, weights=distance..
# [CV 3/5; 29/40] END algorithm=kd_tree, n_neighbors=13, p=2, weights=distance;, score=0.799 total time=   8.9s
# [CV 4/5; 29/40] START algorithm=kd_tree, n_neighbors=13, p=2, weights=distance..
# [CV 4/5; 29/40] END algorithm=kd_tree, n_neighbors=13, p=2, weights=distance;, score=0.798 total time=   9.0s
# [CV 5/5; 29/40] START algorithm=kd_tree, n_neighbors=13, p=2, weights=distance..
# [CV 5/5; 29/40] END algorithm=kd_tree, n_neighbors=13, p=2, weights=distance;, score=0.772 total time=   9.0s
# [CV 1/5; 30/40] START algorithm=auto, n_neighbors=3, p=2, weights=uniform.......
# [CV 1/5; 30/40] END algorithm=auto, n_neighbors=3, p=2, weights=uniform;, score=0.765 total time=   0.1s
# [CV 2/5; 30/40] START algorithm=auto, n_neighbors=3, p=2, weights=uniform.......
# [CV 2/5; 30/40] END algorithm=auto, n_neighbors=3, p=2, weights=uniform;, score=0.748 total time=   0.1s
# [CV 3/5; 30/40] START algorithm=auto, n_neighbors=3, p=2, weights=uniform.......
# [CV 3/5; 30/40] END algorithm=auto, n_neighbors=3, p=2, weights=uniform;, score=0.771 total time=   0.1s
# [CV 4/5; 30/40] START algorithm=auto, n_neighbors=3, p=2, weights=uniform.......
# [CV 4/5; 30/40] END algorithm=auto, n_neighbors=3, p=2, weights=uniform;, score=0.758 total time=   0.1s
# [CV 5/5; 30/40] START algorithm=auto, n_neighbors=3, p=2, weights=uniform.......
# [CV 5/5; 30/40] END algorithm=auto, n_neighbors=3, p=2, weights=uniform;, score=0.750 total time=   0.1s
# [CV 1/5; 31/40] START algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform.
# [CV 1/5; 31/40] END algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform;, score=0.791 total time=   8.4s
# [CV 2/5; 31/40] START algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform.
# [CV 2/5; 31/40] END algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform;, score=0.761 total time=   8.4s
# [CV 3/5; 31/40] START algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform.
# [CV 3/5; 31/40] END algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform;, score=0.787 total time=   8.4s
# [CV 4/5; 31/40] START algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform.
# [CV 4/5; 31/40] END algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform;, score=0.782 total time=   8.4s
# [CV 5/5; 31/40] START algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform.
# [CV 5/5; 31/40] END algorithm=ball_tree, n_neighbors=12, p=2, weights=uniform;, score=0.753 total time=   8.4s
# [CV 1/5; 32/40] START algorithm=kd_tree, n_neighbors=27, p=1, weights=distance..
# [CV 1/5; 32/40] END algorithm=kd_tree, n_neighbors=27, p=1, weights=distance;, score=0.801 total time=   8.7s
# [CV 2/5; 32/40] START algorithm=kd_tree, n_neighbors=27, p=1, weights=distance..
# [CV 2/5; 32/40] END algorithm=kd_tree, n_neighbors=27, p=1, weights=distance;, score=0.787 total time=   8.8s
# [CV 3/5; 32/40] START algorithm=kd_tree, n_neighbors=27, p=1, weights=distance..
# [CV 3/5; 32/40] END algorithm=kd_tree, n_neighbors=27, p=1, weights=distance;, score=0.800 total time=   8.7s
# [CV 4/5; 32/40] START algorithm=kd_tree, n_neighbors=27, p=1, weights=distance..
# [CV 4/5; 32/40] END algorithm=kd_tree, n_neighbors=27, p=1, weights=distance;, score=0.807 total time=   8.7s
# [CV 5/5; 32/40] START algorithm=kd_tree, n_neighbors=27, p=1, weights=distance..
# [CV 5/5; 32/40] END algorithm=kd_tree, n_neighbors=27, p=1, weights=distance;, score=0.781 total time=   8.7s
# [CV 1/5; 33/40] START algorithm=auto, n_neighbors=21, p=2, weights=uniform......
# [CV 1/5; 33/40] END algorithm=auto, n_neighbors=21, p=2, weights=uniform;, score=0.791 total time=   0.1s
# [CV 2/5; 33/40] START algorithm=auto, n_neighbors=21, p=2, weights=uniform......
# [CV 2/5; 33/40] END algorithm=auto, n_neighbors=21, p=2, weights=uniform;, score=0.776 total time=   0.1s
# [CV 3/5; 33/40] START algorithm=auto, n_neighbors=21, p=2, weights=uniform......
# [CV 3/5; 33/40] END algorithm=auto, n_neighbors=21, p=2, weights=uniform;, score=0.792 total time=   0.1s
# [CV 4/5; 33/40] START algorithm=auto, n_neighbors=21, p=2, weights=uniform......
# [CV 4/5; 33/40] END algorithm=auto, n_neighbors=21, p=2, weights=uniform;, score=0.793 total time=   0.1s
# [CV 5/5; 33/40] START algorithm=auto, n_neighbors=21, p=2, weights=uniform......
# [CV 5/5; 33/40] END algorithm=auto, n_neighbors=21, p=2, weights=uniform;, score=0.779 total time=   0.1s
# [CV 1/5; 34/40] START algorithm=ball_tree, n_neighbors=9, p=2, weights=distance.
# [CV 1/5; 34/40] END algorithm=ball_tree, n_neighbors=9, p=2, weights=distance;, score=0.804 total time=   8.4s
# [CV 2/5; 34/40] START algorithm=ball_tree, n_neighbors=9, p=2, weights=distance.
# [CV 2/5; 34/40] END algorithm=ball_tree, n_neighbors=9, p=2, weights=distance;, score=0.781 total time=   8.3s
# [CV 3/5; 34/40] START algorithm=ball_tree, n_neighbors=9, p=2, weights=distance.
# [CV 3/5; 34/40] END algorithm=ball_tree, n_neighbors=9, p=2, weights=distance;, score=0.799 total time=   8.4s
# [CV 4/5; 34/40] START algorithm=ball_tree, n_neighbors=9, p=2, weights=distance.
# [CV 4/5; 34/40] END algorithm=ball_tree, n_neighbors=9, p=2, weights=distance;, score=0.804 total time=   8.3s
# [CV 5/5; 34/40] START algorithm=ball_tree, n_neighbors=9, p=2, weights=distance.
# [CV 5/5; 34/40] END algorithm=ball_tree, n_neighbors=9, p=2, weights=distance;, score=0.762 total time=   8.4s
# [CV 1/5; 35/40] START algorithm=brute, n_neighbors=12, p=1, weights=distance....
# [CV 1/5; 35/40] END algorithm=brute, n_neighbors=12, p=1, weights=distance;, score=0.810 total time=   1.5s
# [CV 2/5; 35/40] START algorithm=brute, n_neighbors=12, p=1, weights=distance....
# [CV 2/5; 35/40] END algorithm=brute, n_neighbors=12, p=1, weights=distance;, score=0.788 total time=   1.4s
# [CV 3/5; 35/40] START algorithm=brute, n_neighbors=12, p=1, weights=distance....
# [CV 3/5; 35/40] END algorithm=brute, n_neighbors=12, p=1, weights=distance;, score=0.798 total time=   1.4s
# [CV 4/5; 35/40] START algorithm=brute, n_neighbors=12, p=1, weights=distance....
# [CV 4/5; 35/40] END algorithm=brute, n_neighbors=12, p=1, weights=distance;, score=0.799 total time=   1.4s
# [CV 5/5; 35/40] START algorithm=brute, n_neighbors=12, p=1, weights=distance....
# [CV 5/5; 35/40] END algorithm=brute, n_neighbors=12, p=1, weights=distance;, score=0.767 total time=   1.4s
# [CV 1/5; 36/40] START algorithm=kd_tree, n_neighbors=4, p=1, weights=distance...
# [CV 1/5; 36/40] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance;, score=0.784 total time=   8.7s
# [CV 2/5; 36/40] START algorithm=kd_tree, n_neighbors=4, p=1, weights=distance...
# [CV 2/5; 36/40] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance;, score=0.756 total time=   8.7s
# [CV 3/5; 36/40] START algorithm=kd_tree, n_neighbors=4, p=1, weights=distance...
# [CV 3/5; 36/40] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance;, score=0.789 total time=   8.7s
# [CV 4/5; 36/40] START algorithm=kd_tree, n_neighbors=4, p=1, weights=distance...
# [CV 4/5; 36/40] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance;, score=0.769 total time=   8.7s
# [CV 5/5; 36/40] START algorithm=kd_tree, n_neighbors=4, p=1, weights=distance...
# [CV 5/5; 36/40] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance;, score=0.745 total time=   8.7s
# [CV 1/5; 37/40] START algorithm=brute, n_neighbors=1, p=1, weights=distance.....
# [CV 1/5; 37/40] END algorithm=brute, n_neighbors=1, p=1, weights=distance;, score=0.755 total time=   1.4s
# [CV 2/5; 37/40] START algorithm=brute, n_neighbors=1, p=1, weights=distance.....
# [CV 2/5; 37/40] END algorithm=brute, n_neighbors=1, p=1, weights=distance;, score=0.737 total time=   1.4s
# [CV 3/5; 37/40] START algorithm=brute, n_neighbors=1, p=1, weights=distance.....
# [CV 3/5; 37/40] END algorithm=brute, n_neighbors=1, p=1, weights=distance;, score=0.713 total time=   1.4s
# [CV 4/5; 37/40] START algorithm=brute, n_neighbors=1, p=1, weights=distance.....
# [CV 4/5; 37/40] END algorithm=brute, n_neighbors=1, p=1, weights=distance;, score=0.726 total time=   1.4s
# [CV 5/5; 37/40] START algorithm=brute, n_neighbors=1, p=1, weights=distance.....
# [CV 5/5; 37/40] END algorithm=brute, n_neighbors=1, p=1, weights=distance;, score=0.710 total time=   1.4s
# [CV 1/5; 38/40] START algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform...
# [CV 1/5; 38/40] END algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform;, score=0.788 total time=   8.7s
# [CV 2/5; 38/40] START algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform...
# [CV 2/5; 38/40] END algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform;, score=0.779 total time=   8.7s
# [CV 3/5; 38/40] START algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform...
# [CV 3/5; 38/40] END algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform;, score=0.789 total time=   8.7s
# [CV 4/5; 38/40] START algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform...
# [CV 4/5; 38/40] END algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform;, score=0.795 total time=   8.7s
# [CV 5/5; 38/40] START algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform...
# [CV 5/5; 38/40] END algorithm=kd_tree, n_neighbors=25, p=1, weights=uniform;, score=0.778 total time=   8.7s
# [CV 1/5; 39/40] START algorithm=auto, n_neighbors=12, p=1, weights=distance.....
# [CV 1/5; 39/40] END algorithm=auto, n_neighbors=12, p=1, weights=distance;, score=0.810 total time=   1.4s
# [CV 2/5; 39/40] START algorithm=auto, n_neighbors=12, p=1, weights=distance.....
# [CV 2/5; 39/40] END algorithm=auto, n_neighbors=12, p=1, weights=distance;, score=0.788 total time=   1.4s
# [CV 3/5; 39/40] START algorithm=auto, n_neighbors=12, p=1, weights=distance.....
# [CV 3/5; 39/40] END algorithm=auto, n_neighbors=12, p=1, weights=distance;, score=0.798 total time=   1.4s
# [CV 4/5; 39/40] START algorithm=auto, n_neighbors=12, p=1, weights=distance.....
# [CV 4/5; 39/40] END algorithm=auto, n_neighbors=12, p=1, weights=distance;, score=0.799 total time=   1.4s
# [CV 5/5; 39/40] START algorithm=auto, n_neighbors=12, p=1, weights=distance.....
# [CV 5/5; 39/40] END algorithm=auto, n_neighbors=12, p=1, weights=distance;, score=0.767 total time=   1.5s
# [CV 1/5; 40/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=distance...
# [CV 1/5; 40/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance;, score=0.790 total time=   9.0s
# [CV 2/5; 40/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=distance...
# [CV 2/5; 40/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance;, score=0.768 total time=   9.0s
# [CV 3/5; 40/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=distance...
# [CV 3/5; 40/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance;, score=0.792 total time=   8.9s
# [CV 4/5; 40/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=distance...
# [CV 4/5; 40/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance;, score=0.804 total time=   9.0s
# [CV 5/5; 40/40] START algorithm=kd_tree, n_neighbors=5, p=2, weights=distance...
# [CV 5/5; 40/40] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance;, score=0.757 total time=   8.9s

# %%
# Display the best parameters and F1 score
print("Best parameters:", best_params_knn)
print("Best F1 Score:", best_score_knn)
# Out:
# Best parameters: {'weights': 'distance', 'p': 1, 'n_neighbors': 24, 'algorithm': 'ball_tree'}
# Best F1 Score: 0.796549424715073

# %% [markdown]
# ### MLP - sklearn  (using labse embeddings)

# %% [markdown]
# **Approach 2:**
#
# **Model:** Utilizes a scikit-learn MLPClassifier.\
# **Hyperparameter Tuning:** Performs hyperparameter tuning using Randomized Search Cross Validation (RandomizedSearchCV).\
# **Hyperparameters:** Searches through a predefined set of hyperparameters for the MLPClassifier using a randomized search strategy.\
# **Evaluation:** Collects and analyzes the results of hyperparameter tuning, including the best score and best parameters found during the search.

# %%
models = [
    ('MLP', MLPClassifier(random_state=42))
]
  
hyperparameters = [
    {
        'MLP__hidden_layer_sizes': [(10,), (20,), (30,), (40,)],
        'MLP__activation': ['tanh', 'relu'],
        'MLP__solver': ['sgd', 'adam'],
        'MLP__learning_rate': ['constant', 'invscaling', 'adaptive'],
        'MLP__alpha': np.logspace(-4, 4, 100),
        'MLP__learning_rate_init': [0.001,0.01],
        'MLP__max_iter': np.arange(100, 300),
        'MLP__batch_size': np.arange(50, 150)
    }
]

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = []
cv_results_dfs = []

for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([model])
    
    rs = RandomizedSearchCV(pipeline, params, cv=stratified_kfold, n_iter=10, scoring='f1', verbose=10)
    rs.fit(combined_embeddings_labse, y_array)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

test_scores_mlp = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_mlp = test_scores_mlp.sort_values('best_score', ascending=False)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd
# [CV 1/5; 1/10] END MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd;, score=0.755 total time=  39.3s
# [CV 2/5; 1/10] START MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd
# [CV 2/5; 1/10] END MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd;, score=0.778 total time=  37.9s
# [CV 3/5; 1/10] START MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd
# [CV 3/5; 1/10] END MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd;, score=0.735 total time=  34.3s
# [CV 4/5; 1/10] START MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd
# [CV 4/5; 1/10] END MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd;, score=0.752 total time=  40.3s
# [CV 5/5; 1/10] START MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd
# [CV 5/5; 1/10] END MLP__activation=tanh, MLP__alpha=0.007220809018385471, MLP__batch_size=130, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=285, MLP__solver=sgd;, score=0.706 total time=  36.7s
# [CV 1/5; 2/10] START MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam
# [CV 1/5; 2/10] END MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam;, score=0.747 total time=  15.7s
# [CV 2/5; 2/10] START MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam
# [CV 2/5; 2/10] END MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam;, score=0.745 total time=  10.9s
# [CV 3/5; 2/10] START MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam
# [CV 3/5; 2/10] END MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam;, score=0.739 total time=  10.5s
# [CV 4/5; 2/10] START MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam
# [CV 4/5; 2/10] END MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam;, score=0.746 total time=  10.4s
# [CV 5/5; 2/10] START MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam
# [CV 5/5; 2/10] END MLP__activation=tanh, MLP__alpha=0.0006428073117284319, MLP__batch_size=97, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=107, MLP__solver=adam;, score=0.730 total time=  11.0s
# [CV 1/5; 3/10] START MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam
# [CV 1/5; 3/10] END MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam;, score=0.758 total time=  10.7s
# [CV 2/5; 3/10] START MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam
# [CV 2/5; 3/10] END MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam;, score=0.792 total time=  12.4s
# [CV 3/5; 3/10] START MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam
# [CV 3/5; 3/10] END MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam;, score=0.767 total time=  12.7s
# [CV 4/5; 3/10] START MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam
# [CV 4/5; 3/10] END MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam;, score=0.750 total time=  17.9s
# [CV 5/5; 3/10] START MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam
# [CV 5/5; 3/10] END MLP__activation=tanh, MLP__alpha=0.0013530477745798076, MLP__batch_size=137, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=constant, MLP__learning_rate_init=0.01, MLP__max_iter=238, MLP__solver=adam;, score=0.756 total time=  17.8s
# [CV 1/5; 4/10] START MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam
# [CV 1/5; 4/10] END MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam;, score=0.000 total time=   4.9s
# [CV 2/5; 4/10] START MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam
# [CV 2/5; 4/10] END MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam;, score=0.000 total time=   5.4s
# [CV 3/5; 4/10] START MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam
# [CV 3/5; 4/10] END MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam;, score=0.000 total time=   5.8s
# [CV 4/5; 4/10] START MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam
# [CV 4/5; 4/10] END MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam;, score=0.000 total time=   4.8s
# [CV 5/5; 4/10] START MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam
# [CV 5/5; 4/10] END MLP__activation=relu, MLP__alpha=8302.175681319752, MLP__batch_size=147, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=constant, MLP__learning_rate_init=0.001, MLP__max_iter=170, MLP__solver=adam;, score=0.000 total time=   5.5s
# [CV 1/5; 5/10] START MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam
# [CV 1/5; 5/10] END MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam;, score=0.791 total time=   5.3s
# [CV 2/5; 5/10] START MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam
# [CV 2/5; 5/10] END MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam;, score=0.781 total time=   5.6s
# [CV 3/5; 5/10] START MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam
# [CV 3/5; 5/10] END MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam;, score=0.803 total time=   4.6s
# [CV 4/5; 5/10] START MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam
# [CV 4/5; 5/10] END MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam;, score=0.769 total time=   5.5s
# [CV 5/5; 5/10] START MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam
# [CV 5/5; 5/10] END MLP__activation=tanh, MLP__alpha=0.9111627561154896, MLP__batch_size=146, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=171, MLP__solver=adam;, score=0.791 total time=   3.9s
# [CV 1/5; 6/10] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd
# [CV 1/5; 6/10] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd;, score=0.000 total time=   3.8s
# [CV 2/5; 6/10] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd
# [CV 2/5; 6/10] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd;, score=0.000 total time=   3.9s
# [CV 3/5; 6/10] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd
# [CV 3/5; 6/10] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd;, score=0.000 total time=   4.2s
# [CV 4/5; 6/10] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd
# [CV 4/5; 6/10] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd;, score=0.000 total time=   4.1s
# [CV 5/5; 6/10] START MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd
# [CV 5/5; 6/10] END MLP__activation=relu, MLP__alpha=1873.8174228603868, MLP__batch_size=80, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.001, MLP__max_iter=106, MLP__solver=sgd;, score=0.000 total time=   4.8s
# [CV 1/5; 7/10] START MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam
# [CV 1/5; 7/10] END MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam;, score=0.000 total time=   6.3s
# [CV 2/5; 7/10] START MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam
# [CV 2/5; 7/10] END MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam;, score=0.000 total time=   5.7s
# [CV 3/5; 7/10] START MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam
# [CV 3/5; 7/10] END MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam;, score=0.000 total time=   6.1s
# [CV 4/5; 7/10] START MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam
# [CV 4/5; 7/10] END MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam;, score=0.000 total time=   6.2s
# [CV 5/5; 7/10] START MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam
# [CV 5/5; 7/10] END MLP__activation=relu, MLP__alpha=10.235310218990268, MLP__batch_size=59, MLP__hidden_layer_sizes=(40,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=264, MLP__solver=adam;, score=0.000 total time=   7.5s
# [CV 1/5; 8/10] START MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam
# [CV 1/5; 8/10] END MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam;, score=0.000 total time=   2.1s
# [CV 2/5; 8/10] START MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam
# [CV 2/5; 8/10] END MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam;, score=0.000 total time=   4.0s
# [CV 3/5; 8/10] START MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam
# [CV 3/5; 8/10] END MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam;, score=0.000 total time=   1.8s
# [CV 4/5; 8/10] START MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam
# [CV 4/5; 8/10] END MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam;, score=0.000 total time=   2.1s
# [CV 5/5; 8/10] START MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam
# [CV 5/5; 8/10] END MLP__activation=relu, MLP__alpha=17.886495290574352, MLP__batch_size=127, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=invscaling, MLP__learning_rate_init=0.01, MLP__max_iter=243, MLP__solver=adam;, score=0.000 total time=   1.9s
# [CV 1/5; 9/10] START MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd
# [CV 1/5; 9/10] END MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd;, score=0.771 total time=  27.0s
# [CV 2/5; 9/10] START MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd
# [CV 2/5; 9/10] END MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd;, score=0.791 total time=  26.1s
# [CV 3/5; 9/10] START MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd
# [CV 3/5; 9/10] END MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd;, score=0.770 total time=  28.9s
# [CV 4/5; 9/10] START MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd
# [CV 4/5; 9/10] END MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd;, score=0.756 total time=  23.7s
# [CV 5/5; 9/10] START MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd
# [CV 5/5; 9/10] END MLP__activation=relu, MLP__alpha=0.018307382802953697, MLP__batch_size=89, MLP__hidden_layer_sizes=(30,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.01, MLP__max_iter=196, MLP__solver=sgd;, score=0.765 total time=  27.7s
# [CV 1/5; 10/10] START MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam
# [CV 1/5; 10/10] END MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam;, score=0.741 total time=  22.9s
# [CV 2/5; 10/10] START MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam
# [CV 2/5; 10/10] END MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam;, score=0.720 total time=  25.0s
# [CV 3/5; 10/10] START MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam
# [CV 3/5; 10/10] END MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam;, score=0.677 total time=  21.4s
# [CV 4/5; 10/10] START MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam
# [CV 4/5; 10/10] END MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam;, score=0.703 total time=  23.8s
# [CV 5/5; 10/10] START MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam
# [CV 5/5; 10/10] END MLP__activation=tanh, MLP__alpha=0.00021049041445120198, MLP__batch_size=79, MLP__hidden_layer_sizes=(10,), MLP__learning_rate=adaptive, MLP__learning_rate_init=0.001, MLP__max_iter=296, MLP__solver=adam;, score=0.709 total time=  23.2s

# %%
test_scores_mlp
# Out:
#    best_score                                        best_params
# 0    0.787012  {'MLP__solver': 'adam', 'MLP__max_iter': 171, ...

# %%
print(test_scores_mlp['best_params'][0])
print(test_scores_mlp['best_score'][0])
# Out:
# {'MLP__solver': 'adam', 'MLP__max_iter': 171, 'MLP__learning_rate_init': 0.001, 'MLP__learning_rate': 'invscaling', 'MLP__hidden_layer_sizes': (30,), 'MLP__batch_size': 146, 'MLP__alpha': 0.9111627561154896, 'MLP__activation': 'tanh'}
# 0.7870120864434715

# %% [raw]
# {'MLP__solver': 'adam', 'MLP__max_iter': 171, 'MLP__learning_rate_init': 0.001, 'MLP__learning_rate': 'invscaling', 'MLP__hidden_layer_sizes': (30,), 'MLP__batch_size': 146, 'MLP__alpha': 0.9111627561154896, 'MLP__activation': 'tanh'}
# 0.7870120864434715

# %% [markdown]
# ### XGBoost  (using LaBSE embeddings)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
import pandas as pd

models = [
    ('XGBoost', XGBClassifier(random_state=19, objective='binary:logistic', eval_metric='logloss'))
]

hyperparameters = [
    {
        'XGBoost__n_estimators': [360, 370, 380],
        'XGBoost__max_depth': [15, 17, 20],
        'XGBoost__subsample': [1.0],
        'XGBoost__min_child_weight': [1, 5, 10],
        'XGBoost__learning_rate': [0.01, 0.1, 1.0]
    }
]

stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=19)

results = []
cv_results_dfs = []

for model, params in zip(models, hyperparameters):
    pipeline = ImbPipeline([model])
    
    rs = GridSearchCV(pipeline, params, cv=stratified_kfold, scoring='f1', verbose=10)
    rs.fit(combined_embeddings_labse, y_array)
    
    results.append([rs.best_score_, rs.best_params_])
    cv_results_df = pd.DataFrame(rs.cv_results_)
    cv_results_dfs.append(cv_results_df)

test_scores_xgb = pd.DataFrame(results, columns=['best_score', 'best_params'])
test_scores_xgb = test_scores_xgb.sort_values('best_score', ascending=False)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5; 1/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 1/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.803 total time= 1.4min
# [CV 2/5; 1/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 1/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.779 total time= 1.4min
# [CV 3/5; 1/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 1/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.798 total time= 1.4min
# [CV 4/5; 1/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 1/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.807 total time= 1.4min
# [CV 5/5; 1/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 1/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.786 total time= 1.3min
# [CV 1/5; 2/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 2/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.803 total time= 1.4min
# [CV 2/5; 2/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 2/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.779 total time= 1.4min
# [CV 3/5; 2/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 2/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.802 total time= 1.4min
# [CV 4/5; 2/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 2/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.807 total time= 1.4min
# [CV 5/5; 2/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 2/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.786 total time= 1.4min
# [CV 1/5; 3/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 3/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.803 total time= 1.4min
# [CV 2/5; 3/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 3/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.779 total time= 1.4min
# [CV 3/5; 3/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 3/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.802 total time= 1.4min
# [CV 4/5; 3/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 3/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.807 total time= 1.4min
# [CV 5/5; 3/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 3/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.786 total time= 1.4min
# [CV 1/5; 4/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 4/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.814 total time=  46.3s
# [CV 2/5; 4/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 4/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.783 total time=  45.6s
# [CV 3/5; 4/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 4/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.798 total time=  46.7s
# [CV 4/5; 4/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 4/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.812 total time=  46.9s
# [CV 5/5; 4/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 4/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.787 total time=  48.5s
# [CV 1/5; 5/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 5/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.816 total time=  48.0s
# [CV 2/5; 5/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 5/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.786 total time=  46.9s
# [CV 3/5; 5/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 5/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.796 total time=  46.4s
# [CV 4/5; 5/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 5/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.814 total time=  46.1s
# [CV 5/5; 5/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 5/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.787 total time=  47.7s
# [CV 1/5; 6/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 6/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.816 total time=  49.7s
# [CV 2/5; 6/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 6/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.784 total time=  48.4s
# [CV 3/5; 6/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 6/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.796 total time=  48.6s
# [CV 4/5; 6/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 6/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.814 total time=  48.4s
# [CV 5/5; 6/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 6/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.789 total time=  49.7s
# [CV 1/5; 7/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 7/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.803 total time=  34.0s
# [CV 2/5; 7/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 7/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.785 total time=  32.9s
# [CV 3/5; 7/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 7/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.790 total time=  32.6s
# [CV 4/5; 7/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 7/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.801 total time=  33.7s
# [CV 5/5; 7/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 7/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.787 total time=  33.1s
# [CV 1/5; 8/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 8/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.803 total time=  34.1s
# [CV 2/5; 8/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 8/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.785 total time=  33.4s
# [CV 3/5; 8/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 8/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.790 total time=  33.4s
# [CV 4/5; 8/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 8/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.801 total time=  34.0s
# [CV 5/5; 8/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 8/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.787 total time=  34.1s
# [CV 1/5; 9/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 9/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.803 total time=  34.5s
# [CV 2/5; 9/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 9/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.785 total time=  34.0s
# [CV 3/5; 9/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 9/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.792 total time=  34.8s
# [CV 4/5; 9/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 9/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.801 total time=  35.4s
# [CV 5/5; 9/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 9/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=15, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.789 total time=  35.5s
# [CV 1/5; 10/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 10/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.805 total time= 1.5min
# [CV 2/5; 10/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 10/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.773 total time= 1.5min
# [CV 3/5; 10/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 10/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.791 total time= 1.4min
# [CV 4/5; 10/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 10/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.810 total time= 1.4min
# [CV 5/5; 10/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 10/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.787 total time= 1.4min
# [CV 1/5; 11/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 11/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.805 total time= 1.5min
# [CV 2/5; 11/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 11/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.774 total time= 1.4min
# [CV 3/5; 11/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 11/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.791 total time= 1.4min
# [CV 4/5; 11/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 11/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.812 total time= 1.4min
# [CV 5/5; 11/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 11/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.783 total time= 1.4min
# [CV 1/5; 12/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 12/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.804 total time= 1.5min
# [CV 2/5; 12/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 12/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.776 total time= 1.5min
# [CV 3/5; 12/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 12/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.794 total time= 1.5min
# [CV 4/5; 12/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 12/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.812 total time= 1.5min
# [CV 5/5; 12/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 12/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.783 total time= 1.5min
# [CV 1/5; 13/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 13/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.807 total time=  49.1s
# [CV 2/5; 13/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 13/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.783 total time=  47.9s
# [CV 3/5; 13/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 13/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.795 total time=  46.7s
# [CV 4/5; 13/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 13/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.806 total time=  47.6s
# [CV 5/5; 13/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 13/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.782 total time=  48.2s
# [CV 1/5; 14/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 14/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.807 total time=  49.2s
# [CV 2/5; 14/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 14/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.783 total time=  48.4s
# [CV 3/5; 14/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 14/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.797 total time=  48.0s
# [CV 4/5; 14/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 14/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.808 total time=  48.5s
# [CV 5/5; 14/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 14/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.782 total time=  48.3s
# [CV 1/5; 15/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 15/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.807 total time=  49.4s
# [CV 2/5; 15/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 15/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.783 total time=  48.7s
# [CV 3/5; 15/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 15/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.797 total time=  49.0s
# [CV 4/5; 15/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 15/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.808 total time=  48.8s
# [CV 5/5; 15/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 15/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.782 total time=  48.8s
# [CV 1/5; 16/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 16/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.804 total time=  33.2s
# [CV 2/5; 16/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 16/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.785 total time=  32.8s
# [CV 3/5; 16/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 16/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.792 total time=  32.8s
# [CV 4/5; 16/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 16/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.805 total time=  33.5s
# [CV 5/5; 16/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 16/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.788 total time=  33.4s
# [CV 1/5; 17/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 17/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.804 total time=  34.9s
# [CV 2/5; 17/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 17/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.785 total time=  34.2s
# [CV 3/5; 17/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 17/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.792 total time=  34.2s
# [CV 4/5; 17/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 17/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.805 total time=  34.8s
# [CV 5/5; 17/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 17/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.787 total time=  35.1s
# [CV 1/5; 18/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 18/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.804 total time=  35.5s
# [CV 2/5; 18/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 18/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.785 total time=  34.9s
# [CV 3/5; 18/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 18/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.791 total time=  35.2s
# [CV 4/5; 18/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 18/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.807 total time=  35.8s
# [CV 5/5; 18/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 18/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.787 total time=  35.5s
# [CV 1/5; 19/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 19/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.802 total time= 1.5min
# [CV 2/5; 19/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 19/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.789 total time= 1.5min
# [CV 3/5; 19/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 19/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.797 total time= 1.5min
# [CV 4/5; 19/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 19/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.812 total time= 1.4min
# [CV 5/5; 19/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 19/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.783 total time= 1.4min
# [CV 1/5; 20/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 20/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.802 total time= 1.5min
# [CV 2/5; 20/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 20/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.789 total time= 1.4min
# [CV 3/5; 20/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 20/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.799 total time= 1.5min
# [CV 4/5; 20/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 20/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.812 total time= 1.5min
# [CV 5/5; 20/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 20/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.786 total time= 1.5min
# [CV 1/5; 21/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 21/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.802 total time= 1.5min
# [CV 2/5; 21/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 21/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.789 total time= 1.5min
# [CV 3/5; 21/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 21/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.799 total time= 1.5min
# [CV 4/5; 21/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 21/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.812 total time= 1.5min
# [CV 5/5; 21/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 21/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.786 total time= 1.5min
# [CV 1/5; 22/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 22/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.804 total time=  47.5s
# [CV 2/5; 22/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 22/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.786 total time=  46.6s
# [CV 3/5; 22/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 22/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.797 total time=  46.7s
# [CV 4/5; 22/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 22/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.806 total time=  46.7s
# [CV 5/5; 22/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 22/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.788 total time=  46.9s
# [CV 1/5; 23/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 23/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.804 total time=  48.0s
# [CV 2/5; 23/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 23/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.788 total time=  47.7s
# [CV 3/5; 23/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 23/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.797 total time=  47.7s
# [CV 4/5; 23/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 23/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.806 total time=  47.5s
# [CV 5/5; 23/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 23/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.788 total time=  48.0s
# [CV 1/5; 24/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 24/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.804 total time=  49.1s
# [CV 2/5; 24/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 24/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.788 total time=  48.4s
# [CV 3/5; 24/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 24/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.797 total time=  48.7s
# [CV 4/5; 24/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 24/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.806 total time=  50.6s
# [CV 5/5; 24/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 24/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.786 total time=  50.4s
# [CV 1/5; 25/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 25/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.804 total time=  33.7s
# [CV 2/5; 25/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 25/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.785 total time=  33.5s
# [CV 3/5; 25/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 25/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.792 total time=  33.1s
# [CV 4/5; 25/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 25/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.805 total time=  33.8s
# [CV 5/5; 25/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 25/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.788 total time=  33.9s
# [CV 1/5; 26/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 26/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.804 total time=  34.6s
# [CV 2/5; 26/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 26/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.785 total time=  33.9s
# [CV 3/5; 26/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 26/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.792 total time=  34.0s
# [CV 4/5; 26/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 26/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.805 total time=  34.8s
# [CV 5/5; 26/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 26/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.787 total time=  34.6s
# [CV 1/5; 27/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 27/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.804 total time=  35.2s
# [CV 2/5; 27/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 27/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.785 total time=  35.4s
# [CV 3/5; 27/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 27/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.791 total time=  35.1s
# [CV 4/5; 27/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 27/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.807 total time=  35.6s
# [CV 5/5; 27/81] START XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 27/81] END XGBoost__learning_rate=0.01, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.787 total time=  35.3s
# [CV 1/5; 28/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 28/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.798 total time=  29.3s
# [CV 2/5; 28/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 28/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.778 total time=  28.4s
# [CV 3/5; 28/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 28/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.795 total time=  28.2s
# [CV 4/5; 28/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 28/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.810 total time=  29.1s
# [CV 5/5; 28/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 28/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.798 total time=  28.7s
# [CV 1/5; 29/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 29/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.798 total time=  29.2s
# [CV 2/5; 29/81] START XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 29/81] END XGBoost__learning_rate=0.1, XGBoost__max_depth=15, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.778 total time=  28.9s
# ...
# [CV 3/5; 72/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.753 total time=   7.7s
# [CV 4/5; 72/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 72/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.763 total time=   8.1s
# [CV 5/5; 72/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 72/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=17, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.769 total time=   7.8s
# [CV 1/5; 73/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 73/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.777 total time=  10.9s
# [CV 2/5; 73/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 73/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.753 total time=  10.4s
# [CV 3/5; 73/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 73/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.760 total time=   9.8s
# [CV 4/5; 73/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 73/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.785 total time=  10.9s
# [CV 5/5; 73/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 73/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.780 total time=  10.4s
# [CV 1/5; 74/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 74/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.775 total time=  11.1s
# [CV 2/5; 74/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 74/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.755 total time=  10.7s
# [CV 3/5; 74/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 74/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.760 total time=   9.9s
# [CV 4/5; 74/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 74/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.781 total time=  10.7s
# [CV 5/5; 74/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 74/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.783 total time=  10.1s
# [CV 1/5; 75/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 75/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.777 total time=  10.7s
# [CV 2/5; 75/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 75/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.755 total time=  10.4s
# [CV 3/5; 75/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 75/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.761 total time=   9.7s
# [CV 4/5; 75/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 75/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.781 total time=  10.9s
# [CV 5/5; 75/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 75/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=1, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.781 total time=  10.2s
# [CV 1/5; 76/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 76/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.784 total time=   7.9s
# [CV 2/5; 76/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 76/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.739 total time=   8.0s
# [CV 3/5; 76/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 76/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.759 total time=   8.0s
# [CV 4/5; 76/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 76/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.804 total time=   8.9s
# [CV 5/5; 76/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 76/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.765 total time=   8.3s
# [CV 1/5; 77/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 77/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.784 total time=   8.5s
# [CV 2/5; 77/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 77/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.739 total time=   8.4s
# [CV 3/5; 77/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 77/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.759 total time=   7.8s
# [CV 4/5; 77/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 77/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.802 total time=   8.1s
# [CV 5/5; 77/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 77/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.768 total time=   8.2s
# [CV 1/5; 78/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 78/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.782 total time=   8.3s
# [CV 2/5; 78/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 78/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.743 total time=   8.2s
# [CV 3/5; 78/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 78/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.759 total time=   7.9s
# [CV 4/5; 78/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 78/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.805 total time=   8.9s
# [CV 5/5; 78/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 78/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=5, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.768 total time=   9.0s
# [CV 1/5; 79/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 1/5; 79/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.758 total time=   7.9s
# [CV 2/5; 79/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 2/5; 79/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.750 total time=   7.2s
# [CV 3/5; 79/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 3/5; 79/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.753 total time=   7.2s
# [CV 4/5; 79/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 4/5; 79/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.763 total time=   7.5s
# [CV 5/5; 79/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0
# [CV 5/5; 79/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=360, XGBoost__subsample=1.0;, score=0.769 total time=   7.2s
# [CV 1/5; 80/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 1/5; 80/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.758 total time=   7.6s
# [CV 2/5; 80/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 2/5; 80/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.750 total time=   7.2s
# [CV 3/5; 80/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 3/5; 80/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.753 total time=   7.3s
# [CV 4/5; 80/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 4/5; 80/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.763 total time=   7.6s
# [CV 5/5; 80/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0
# [CV 5/5; 80/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=370, XGBoost__subsample=1.0;, score=0.769 total time=   7.3s
# [CV 1/5; 81/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 1/5; 81/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.758 total time=   7.6s
# [CV 2/5; 81/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 2/5; 81/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.750 total time=   7.4s
# [CV 3/5; 81/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 3/5; 81/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.753 total time=   7.4s
# [CV 4/5; 81/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 4/5; 81/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.763 total time=   7.6s
# [CV 5/5; 81/81] START XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0
# [CV 5/5; 81/81] END XGBoost__learning_rate=1.0, XGBoost__max_depth=20, XGBoost__min_child_weight=10, XGBoost__n_estimators=380, XGBoost__subsample=1.0;, score=0.769 total time=   7.5s

# %%
test_scores_xgb
# Out:
#    best_score                                        best_params
# 0    0.801343  {'XGBoost__learning_rate': 0.1, 'XGBoost__max_...

# %%
print(test_scores_xgb['best_params'][0])
print(test_scores_xgb['best_score'][0])
# Out:
# {'XGBoost__learning_rate': 0.1, 'XGBoost__max_depth': 20, 'XGBoost__min_child_weight': 1, 'XGBoost__n_estimators': 370, 'XGBoost__subsample': 1.0}
# 0.8013426232762819

# %% [raw]
# {'XGBoost__learning_rate': 0.1, 'XGBoost__max_depth': 20, 'XGBoost__min_child_weight': 1, 'XGBoost__n_estimators': 370, 'XGBoost__subsample': 1.0}
# 0.8013426232762819

# %% [markdown]
# ## DistilBERT - Transformer (for model testing)

# %%
y_train = y_train.reset_index(drop=True)
X_train = X_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)

# %%
def prepare_data(X, y):
    data = pd.DataFrame({
        'text': X['cleaned_comments'] + ' [SEP] ' + X['cleaned_host'] + ' [SEP] ' + X['cleaned_description'],
        'label': y
    })
    return data

# %%
train_data = prepare_data(X_train, y_train)
val_data = prepare_data(X_val, y_val)

# %%
class BinaryClassificationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = str(self.data['text'][index])
        label = self.data['label'][index]
        
        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        input_ids = inputs['input_ids'].squeeze()
        attention_mask = inputs['attention_mask'].squeeze()

        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2)

max_length = 512  # Increase max_length to 512

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=8,  # Increase epochs to 8
    per_device_train_batch_size=16,  # Adjust batch size
    per_device_eval_batch_size=16,  # Adjust batch size
    warmup_steps=1000,  # Increase warm-up steps
    weight_decay=0.001,  # Adjust weight decay
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=1,
    load_best_model_at_end=True,
    metric_for_best_model='f1',
    greater_is_better=True,
)

# Define compute_metrics function (same as before)

# Initialize Trainer
trainer = Trainer(
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# Train the model
trainer.train()

# Evaluate on validation set
results = trainer.evaluate()

print("Validation Results:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2344' max='2344' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2344/2344 48:22, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.361600</td>
#       <td>0.343401</td>
#       <td>0.870038</td>
#       <td>0.774695</td>
#       <td>0.736287</td>
#       <td>0.817330</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.432900</td>
#       <td>0.342822</td>
#       <td>0.865557</td>
#       <td>0.754673</td>
#       <td>0.752914</td>
#       <td>0.756440</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.313100</td>
#       <td>0.330636</td>
#       <td>0.879641</td>
#       <td>0.784897</td>
#       <td>0.767338</td>
#       <td>0.803279</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.285900</td>
#       <td>0.350107</td>
#       <td>0.873239</td>
#       <td>0.760291</td>
#       <td>0.786967</td>
#       <td>0.735363</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.257700</td>
#       <td>0.374123</td>
#       <td>0.874520</td>
#       <td>0.766110</td>
#       <td>0.781022</td>
#       <td>0.751756</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.213100</td>
#       <td>0.398725</td>
#       <td>0.877081</td>
#       <td>0.778291</td>
#       <td>0.767654</td>
#       <td>0.789227</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.161500</td>
#       <td>0.497274</td>
#       <td>0.875800</td>
#       <td>0.773364</td>
#       <td>0.771562</td>
#       <td>0.775176</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.065500</td>
#       <td>0.533307</td>
#       <td>0.877081</td>
#       <td>0.771429</td>
#       <td>0.784504</td>
#       <td>0.758782</td>
#     </tr>
#   </tbody>
# </table><p>
# Validation Results:
# eval_loss: 0.3306363523006439
# eval_accuracy: 0.8796414852752881
# eval_f1: 0.7848970251716247
# eval_precision: 0.767337807606264
# eval_recall: 0.8032786885245902
# eval_runtime: 48.4688
# eval_samples_per_second: 32.227
# eval_steps_per_second: 2.022
# epoch: 8.0

# %% [raw]
# Validation Results:
# eval_loss: 0.3306363523006439
# eval_accuracy: 0.8796414852752881
# eval_f1: 0.7848970251716247
# eval_precision: 0.767337807606264
# eval_recall: 0.8032786885245902
# eval_runtime: 48.4688
# eval_samples_per_second: 32.227
# eval_steps_per_second: 2.022
# epoch: 8.0

# %%
# Predictions on validation set
val_predictions = trainer.predict(val_dataset)
val_y_true = val_predictions.label_ids
val_y_pred = val_predictions.predictions.argmax(axis=-1)

# %%
# Classification report for validation set
print(classification_report(val_y_true, val_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      1135
#            1       0.77      0.80      0.78       427
#
#     accuracy                           0.88      1562
#    macro avg       0.85      0.86      0.85      1562
# weighted avg       0.88      0.88      0.88      1562

# %%
# Compute ROC curve for the transformer
fpr_transformer, tpr_transformer, _ = roc_curve(val_y_true, val_predictions.predictions[:, 1])
roc_auc_transformer = auc(fpr_transformer, tpr_transformer)

# %%
f1_distilbert = f1_score(val_y_true, val_y_pred)
accuracy_distilbert = accuracy_score(val_y_true, val_y_pred)
roc_distilbert = roc_auc_score(val_y_true, val_y_pred)
precision_distilbert = precision_score(val_y_true, val_y_pred)
recall_distilbert = recall_score(val_y_true, val_y_pred)

# %%
# Fit vectorizers on the training data
tfidf_vectorizer1 = TfidfVectorizer().fit(X_train['cleaned_comments'])
tfidf_vectorizer2 = TfidfVectorizer().fit(X_train['cleaned_host'])
tfidf_vectorizer3 = TfidfVectorizer().fit(X_train['cleaned_description'])

# Transform the training data
X1_tfidf_train = tfidf_vectorizer1.transform(X_train['cleaned_comments'])
X2_tfidf_train = tfidf_vectorizer2.transform(X_train['cleaned_host'])
X3_tfidf_train = tfidf_vectorizer3.transform(X_train['cleaned_description'])

# Combine TF-IDF features for the training data
X_combined_tfidf_train = hstack([X1_tfidf_train, X2_tfidf_train, X3_tfidf_train])

# Transform the validation data using the same vectorizers
X1_tfidf_val = tfidf_vectorizer1.transform(X_val['cleaned_comments'])
X2_tfidf_val = tfidf_vectorizer2.transform(X_val['cleaned_host'])
X3_tfidf_val = tfidf_vectorizer3.transform(X_val['cleaned_description'])

# Combine TF-IDF features for the validation data
X_combined_tfidf_val = hstack([X1_tfidf_val, X2_tfidf_val, X3_tfidf_val])

# Ensure that the number of features match
print(X_combined_tfidf_train.shape)  # Should output: (4686, 162797)
print(X_combined_tfidf_val.shape)
# Out:
# (4686, 162797)
# (1562, 162797)

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import confusion_matrix
def final_metrics(y_data, y_pred):
    print('___________________________________________________________________________________________________________')
    print('                              Classification Report & Confusion Matrix                                     ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_data, y_pred))
    print(confusion_matrix(y_data, y_pred))

# %% [markdown]
# ### Logistic Regression

# %%
lg_model = LogisticRegression(C=8.68511373751352, penalty='l2', solver='saga', random_state=42)

lg_model.fit(X_combined_tfidf_train, y_train)

y_train_pred = lg_model.predict(X_combined_tfidf_train)
y_val_pred = lg_model.predict(X_combined_tfidf_val)


train_f1_score = f1_score(y_train, y_train_pred)
test_f1_score = f1_score(y_val, y_val_pred)

print("Training F1 Score:", train_f1_score)
print("Testing F1 Score:", test_f1_score)
# Out:
# Training F1 Score: 0.9891304347826086
# Testing F1 Score: 0.8078703703703703

# %%
# Classification report for training data
print("Classification Report for Training Data:")
print(final_metrics(y_train, y_train_pred))
# Out:
# Classification Report for Training Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      3405
#            1       0.98      0.99      0.99      1281
#
#     accuracy                           0.99      4686
#    macro avg       0.99      0.99      0.99      4686
# weighted avg       0.99      0.99      0.99      4686
#
# [[3384   21]
#  [   7 1274]]
# None

# %%
# Classification report for validation data
print("Classification Report for Validation Data:")
print(final_metrics(y_val, y_val_pred))
# Out:
# Classification Report for Validation Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      1135
#            1       0.80      0.82      0.81       427
#
#     accuracy                           0.89      1562
#    macro avg       0.86      0.87      0.87      1562
# weighted avg       0.89      0.89      0.89      1562
#
# [[1047   88]
#  [  78  349]]
# None

# %%
f1_logit = f1_score(y_val, y_val_pred)
accuracy_logit = accuracy_score(y_val, y_val_pred)
roc_logit = roc_auc_score(y_val, y_val_pred)
precision_logit = precision_score(y_val, y_val_pred)
recall_logit = recall_score(y_val, y_val_pred)

# %% [markdown]
# ### KNN Classifier

# %%
knn_model = KNeighborsClassifier(weights= 'distance', p=2, n_neighbors= 25, algorithm= 'auto')

knn_model.fit(X_combined_tfidf_train, y_train)

y_train_pred = knn_model.predict(X_combined_tfidf_train)
y_val_pred = knn_model.predict(X_combined_tfidf_val)


train_f1_score = f1_score(y_train, y_train_pred)
test_f1_score = f1_score(y_val, y_val_pred)

print("Training F1 Score:", train_f1_score)
print("Testing F1 Score:", test_f1_score)
# Out:
# Training F1 Score: 0.9988285825849278
# Testing F1 Score: 0.7899343544857768

# %% [raw]
# Training F1 Score: 0.9988285825849278
# Testing F1 Score: 0.7899343544857768

# %%
# Classification report for training data
print("Classification Report for Training Data:")
print(final_metrics(y_train, y_train_pred))
# Out:
# Classification Report for Training Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3405
#            1       1.00      1.00      1.00      1281
#
#     accuracy                           1.00      4686
#    macro avg       1.00      1.00      1.00      4686
# weighted avg       1.00      1.00      1.00      4686
#
# [[3404    1]
#  [   2 1279]]
# None

# %%
# Classification report for validation data
print("Classification Report for Validation Data:")
print(final_metrics(y_val, y_val_pred))
# Out:
# Classification Report for Validation Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1135
#            1       0.74      0.85      0.79       427
#
#     accuracy                           0.88      1562
#    macro avg       0.84      0.87      0.85      1562
# weighted avg       0.88      0.88      0.88      1562
#
# [[1009  126]
#  [  66  361]]
# None

# %%
f1_knn = f1_score(y_val, y_val_pred)
accuracy_knn = accuracy_score(y_val, y_val_pred)
roc_knn = roc_auc_score(y_val, y_val_pred)
precision_knn = precision_score(y_val, y_val_pred)
recall_knn = recall_score(y_val, y_val_pred)

# %% [markdown]
# ### MLP Classifier

# %%
mlp_model = MLPClassifier(max_iter= 250, learning_rate_init=0.01, solver='sgd', learning_rate= 'adaptive', hidden_layer_sizes=(30,), batch_size=143, alpha=0.3593813663804629, activation='tanh', random_state=42)

mlp_model.fit(X_combined_tfidf_train, y_train)

y_train_pred = mlp_model.predict(X_combined_tfidf_train)
y_val_pred = mlp_model.predict(X_combined_tfidf_val)


train_f1_score = f1_score(y_train, y_train_pred)
test_f1_score = f1_score(y_val, y_val_pred)

print("Training F1 Score:", train_f1_score)
print("Testing F1 Score:", test_f1_score)
# Out:
# Training F1 Score: 0.9465828750981933
# Testing F1 Score: 0.8132875143184422

# %% [raw]
# Training F1 Score: 0.9465828750981933
# Testing F1 Score: 0.8132875143184422

# %%
# Classification report for training data
print("Classification Report for Training Data:")
print(final_metrics(y_train, y_train_pred))
# Out:
# Classification Report for Training Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3405
#            1       0.95      0.94      0.95      1281
#
#     accuracy                           0.97      4686
#    macro avg       0.97      0.96      0.96      4686
# weighted avg       0.97      0.97      0.97      4686
#
# [[3345   60]
#  [  76 1205]]
# None

# %%
# Classification report for validation data
print("Classification Report for Validation Data:")
print(final_metrics(y_val, y_val_pred))
# Out:
# Classification Report for Validation Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      1135
#            1       0.80      0.83      0.81       427
#
#     accuracy                           0.90      1562
#    macro avg       0.87      0.88      0.87      1562
# weighted avg       0.90      0.90      0.90      1562
#
# [[1044   91]
#  [  72  355]]
# None

# %%
f1_mlp = f1_score(y_val, y_val_pred)
accuracy_mlp = accuracy_score(y_val, y_val_pred)
roc_mlp = roc_auc_score(y_val, y_val_pred)
precision_mlp = precision_score(y_val, y_val_pred)
recall_mlp = recall_score(y_val, y_val_pred)

# %% [markdown]
# ### XGBoost Classifier

# %%
xgboost_model = XGBClassifier(random_state=19, objective='binary:logistic', eval_metric='logloss',subsample = 1.0, n_estimators=350, min_child_weight=5, max_depth=15, learning_rate=0.01)

xgboost_model.fit(X_combined_tfidf_train, y_train)

y_train_pred = xgboost_model.predict(X_combined_tfidf_train)
y_val_pred = xgboost_model.predict(X_combined_tfidf_val)


train_f1_score = f1_score(y_train, y_train_pred)
test_f1_score = f1_score(y_val, y_val_pred)

print("Training F1 Score:", train_f1_score)
print("Testing F1 Score:", test_f1_score)
# Out:
# Training F1 Score: 0.8744257274119449
# Testing F1 Score: 0.7809307604994324

# %% [raw]
# Training F1 Score: 0.8744257274119449
# Testing F1 Score: 0.7809307604994324

# %%
# Classification report for training data
print("Classification Report for Training Data:")
print(final_metrics(y_train, y_train_pred))
# Out:
# Classification Report for Training Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      3405
#            1       0.86      0.89      0.87      1281
#
#     accuracy                           0.93      4686
#    macro avg       0.91      0.92      0.91      4686
# weighted avg       0.93      0.93      0.93      4686
#
# [[3216  189]
#  [ 139 1142]]
# None

# %%
# Classification report for validation data
print("Classification Report for Validation Data:")
print(final_metrics(y_val, y_val_pred))
# Out:
# Classification Report for Validation Data:
# ___________________________________________________________________________________________________________
#                               Classification Report & Confusion Matrix
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1135
#            1       0.76      0.81      0.78       427
#
#     accuracy                           0.88      1562
#    macro avg       0.84      0.85      0.85      1562
# weighted avg       0.88      0.88      0.88      1562
#
# [[1025  110]
#  [  83  344]]
# None

# %%
f1_xgboost = f1_score(y_val, y_val_pred)
accuracy_xgboost = accuracy_score(y_val, y_val_pred)
roc_xgboost = roc_auc_score(y_val, y_val_pred)
precision_xgboost = precision_score(y_val, y_val_pred)
recall_xgboost = recall_score(y_val, y_val_pred)

# %% [markdown]
# ## RUC curve

# %%
models = [
    ('Logistic Regression', LogisticRegression(C=8.68511373751352, penalty='l2', solver='saga', random_state=42)),
    ('MLP Classifier', MLPClassifier(max_iter= 250, learning_rate_init=0.01, solver='sgd', learning_rate= 'adaptive', hidden_layer_sizes=(30,), batch_size=143, alpha=0.3593813663804629, activation='tanh', random_state=42)), 
    ('XGBoost',XGBClassifier(random_state=19, objective='binary:logistic', eval_metric='logloss',subsample = 1.0, n_estimators=350, min_child_weight=5, max_depth=15, learning_rate=0.01)),
    ('KNN Classifier', KNeighborsClassifier(weights= 'distance', p=2, n_neighbors= 25, algorithm= 'auto')), 
]

plt.figure(figsize=(10, 6))

plt.plot(fpr_transformer, tpr_transformer, lw=2, label='Transformer ROC (area = %0.2f)' % roc_auc_transformer)

for name, model in models:
    pipeline = ImbPipeline([('model', model)])
    
    stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=19)

    y_probas = cross_val_predict(pipeline, X_combined_tfidf_val, y_val, cv=stratified_kfold, method='predict_proba')
    fpr, tpr, thresholds = roc_curve(y_val, y_probas[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, lw=2, label='%s ROC (area = %0.2f)' % (name, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Table with  model's resuslts

# %%
models = pd.DataFrame({'Model': ['Logistic Regression', 'KNN Classifier', 'MLP Classifier', 'XGBoost Classifier', 'DistilBERT'],
                       'F1 Score - validation': [f1_logit, f1_knn, f1_mlp, f1_xgboost, f1_distilbert],
                       'Accuracy Score - validation': [accuracy_logit, accuracy_knn, accuracy_mlp, accuracy_xgboost, accuracy_distilbert],
                       'ROC-AUC Score - validation': [roc_logit, roc_knn, roc_mlp, roc_xgboost, roc_distilbert],
                       'Precision Score - validation': [precision_logit, precision_knn, precision_mlp, precision_xgboost, precision_distilbert],
                       'Recall Score - validation': [recall_logit, recall_knn, recall_mlp, recall_xgboost, recall_distilbert]})
models.sort_values(by='F1 Score - validation', ascending=False)
# Out:
#                  Model  F1 Score - validation  Accuracy Score - validation  \
# 2       MLP Classifier               0.813288                     0.895647
# 0  Logistic Regression               0.807870                     0.893726
# 1       KNN Classifier               0.789934                     0.877081
# 4           DistilBERT               0.784897                     0.879641
# 3   XGBoost Classifier               0.780931                     0.876440
#
#    ROC-AUC Score - validation  Precision Score - validation  \
# 2                    0.875603                      0.795964
# 0                    0.869899                      0.798627
# 1                    0.867210                      0.741273
# 4                    0.855824                      0.767338
# 3                    0.854352                      0.757709
#
#    Recall Score - validation
# 2                   0.831382
# 0                   0.817330
# 1                   0.845433
# 4                   0.803279
# 3                   0.805621

# %%
# Transform the Test data using the same vectorizers
X1_tfidf_test = tfidf_vectorizer1.transform(X1_test)
X2_tfidf_test = tfidf_vectorizer2.transform(X2_test)
X3_tfidf_test = tfidf_vectorizer3.transform(X3_test)

# Combine TF-IDF features for the validation data
X_combined_tfidf_test = hstack([X1_tfidf_test, X2_tfidf_test, X3_tfidf_test])

# Ensure that the number of features match
print(X_combined_tfidf_test.shape)  # Should output: (4686, 162797)
# Out:
# (695, 162797)

# %%
test_pred_array = mlp_model.predict(X_combined_tfidf_val)

# %%
test_pred = pd.Series(test_pred_array)
test_pred.to_csv('Test_predictions.csv', index=False)

# %%
test_pred.value_counts()
# Out:
# 0    1116
# 1     446
# Name: count, dtype: int64
